# %%
import sys
import os
import glob
sys.path.append("../NEAT")
from NEATModels import NEATDynamicSegFree, nets
from NEATModels.config import dynamic_config
from NEATUtils import helpers
from NEATUtils.helpers import load_json
from stardist.models import StarDist2D
os.environ["CUDA_VISIBLE_DEVICES"]="1"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
from pathlib import Path
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ScannerError                              Traceback (most recent call last)
# <ipython-input-1-c9ee3ee078a5> in <module>
#       3 import glob
#       4 sys.path.append("../NEAT")
# ----> 5 from NEATModels import NEATDynamicSegFree, nets
#       6 from NEATModels.config import dynamic_config
#       7 from NEATUtils import helpers
#
# ~/anaconda3/bin/Yoloneat/NEAT/NEATModels/__init__.py in <module>
#       4 #imports
#       5
# ----> 6 from NEATModels.neat_standard import NEATDynamic
#       7 from NEATModels.neat_segfree import NEATDynamicSegFree
#       8 from NEATModels.neat_microscope import NEATPredict
#
# ~/anaconda3/bin/Yoloneat/NEAT/NEATModels/neat_standard.py in <module>
#      19 from tifffile import imread, imwrite
#      20 import csv
# ---> 21 import napari
#      22 import glob
#      23 from scipy import spatial
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/napari/__init__.py in <module>
#      21 _magicgui.register_types_with_magicgui()
#      22
# ---> 23 from ._event_loop import gui_qt, run
#      24 from .plugins.io import save_layers
#      25 from .view_layers import (  # type: ignore
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/napari/_event_loop.py in <module>
#       1 try:
# ----> 2     from ._qt.qt_event_loop import gui_qt, run
#       3
#       4 # qtpy raises a RuntimeError if no Qt bindings can be found
#       5 except (ImportError, RuntimeError) as e:
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/napari/_qt/__init__.py in <module>
#      38
#      39
# ---> 40 from .qt_event_loop import get_app, gui_qt, quit_app, run
#      41 from .qt_main_window import Window
#      42 from .widgets.qt_range_slider import QHRangeSlider, QVRangeSlider
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/napari/_qt/qt_event_loop.py in <module>
#      18 )
#      19 from ..utils.perf import perf_config
# ---> 20 from ..utils.settings import SETTINGS
#      21 from .dialogs.qt_notification import NapariQtNotification
#      22 from .qt_resources import _register_napari_resources
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/napari/utils/settings/__init__.py in <module>
#       3
#       4 from ._defaults import CORE_SETTINGS
# ----> 5 from ._manager import SETTINGS
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/napari/utils/settings/_manager.py in <module>
#     185
#     186
# --> 187 SETTINGS = SettingsManager()
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/napari/utils/settings/_manager.py in __init__(self, config_path, save_to_disk)
#      74             os.makedirs(self._config_path)
#      75
# ---> 76         self._load()
#      77
#      78     def __getattr__(self, attr):
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/napari/utils/settings/_manager.py in _load(self)
#     121         if path.is_file():
#     122             with open(path) as fh:
# --> 123                 data = safe_load(fh.read()) or {}
#     124
#     125             # Check with models
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/__init__.py in safe_load(stream)
#     160     to be safe for untrusted input.
#     161     """
# --> 162     return load(stream, SafeLoader)
#     163
#     164 def safe_load_all(stream):
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/__init__.py in load(stream, Loader)
#     112     loader = Loader(stream)
#     113     try:
# --> 114         return loader.get_single_data()
#     115     finally:
#     116         loader.dispose()
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/constructor.py in get_single_data(self)
#      47     def get_single_data(self):
#      48         # Ensure that the stream contains a single document and construct it.
# ---> 49         node = self.get_single_node()
#      50         if node is not None:
#      51             return self.construct_document(node)
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/composer.py in get_single_node(self)
#      34         document = None
#      35         if not self.check_event(StreamEndEvent):
# ---> 36             document = self.compose_document()
#      37
#      38         # Ensure that the stream contains no more documents.
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/composer.py in compose_document(self)
#      53
#      54         # Compose the root node.
# ---> 55         node = self.compose_node(None, None)
#      56
#      57         # Drop the DOCUMENT-END event.
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      80             node = self.compose_scalar_node(anchor)
#      81         elif self.check_event(SequenceStartEvent):
# ---> 82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
#      84             node = self.compose_mapping_node(anchor)
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/composer.py in compose_sequence_node(self, anchor)
#     108             self.anchors[anchor] = node
#     109         index = 0
# --> 110         while not self.check_event(SequenceEndEvent):
#     111             node.value.append(self.compose_node(node, index))
#     112             index += 1
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/parser.py in check_event(self, *choices)
#      96         if self.current_event is None:
#      97             if self.state:
# ---> 98                 self.current_event = self.state()
#      99         if self.current_event is not None:
#     100             if not choices:
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/parser.py in parse_indentless_sequence_entry(self)
#     401
#     402     def parse_indentless_sequence_entry(self):
# --> 403         if self.check_token(BlockEntryToken):
#     404             token = self.get_token()
#     405             if not self.check_token(BlockEntryToken,
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/scanner.py in check_token(self, *choices)
#     113     def check_token(self, *choices):
#     114         # Check if the next token is one of the given types.
# --> 115         while self.need_more_tokens():
#     116             self.fetch_more_tokens()
#     117         if self.tokens:
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/scanner.py in need_more_tokens(self)
#     150         # The current token may be a potential simple key, so we
#     151         # need to look further.
# --> 152         self.stale_possible_simple_keys()
#     153         if self.next_possible_simple_key() == self.tokens_taken:
#     154             return True
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/yaml/scanner.py in stale_possible_simple_keys(self)
#     290                 if key.required:
#     291                     raise ScannerError("while scanning a simple key", key.mark,
# --> 292                             "could not find expected ':'", self.get_mark())
#     293                 del self.possible_simple_keys[level]
#     294
#
# ScannerError: while scanning a simple key
#   in "<unicode string>", line 30, column 1:
#     B5AGUAcgAgAGMAbwBuAHQAcgBvAGwAcw ...
#     ^
# could not find expected ':'
#   in "<unicode string>", line 31, column 19:
#       window_statusbar: true
#                       ^

# %%
imagedir = '/home/sancere/Kepler/FinalONEATTraining/NEATTest/'
model_dir = '/home/sancere/Kepler/FinalONEATTraining/PreMicroneatmodel/'
savedir= '/home/sancere/Kepler/FinalONEATTraining/NEATTest/Saved56l16/'
model_name = 'premicroseqnetbin2d56'
star_model_name = '/home/sancere/Kepler/FinalONEATTraining/Everydayneatmodel/bin2stardist/'
division_categories_json = model_dir + 'MicroscopeCategories.json'
catconfig = load_json(division_categories_json)
division_cord_json = model_dir + 'MicroscopeCord.json'
cordconfig = load_json(division_cord_json)
model = NEATDynamicSegFree(None, model_dir , model_name,catconfig, cordconfig)
starmodel = StarDist2D(config = None, name = star_model_name, basedir = model_dir)
Path(savedir).mkdir(exist_ok=True)
n_tiles = (1,1)
event_threshold = 1.0 - 1.0E-7
iou_threshold = 0.4
yolo_v2 = False

# %% [markdown]
# # In the code block below compute the markers and make a dictionary for each image

# %%
imagedir = '/home/sancere/Kepler/FinalONEATTraining/NEATTest/'
model_dir = '/home/sancere/Kepler/FinalONEATTraining/PreMicroneatmodel/'
savedir= '/home/sancere/Kepler/FinalONEATTraining/NEATTest/Saved56l16/'
model_name = 'premicroseqnetbin2d56'
star_model_name = '/home/sancere/Kepler/FinalONEATTraining/Everydayneatmodel/bin2stardist/'
division_categories_json = model_dir + 'MicroscopeCategories.json'
catconfig = load_json(division_categories_json)
division_cord_json = model_dir + 'MicroscopeCord.json'
cordconfig = load_json(division_cord_json)
model = NEATDynamicSegFree(None, model_dir , model_name,catconfig, cordconfig)
starmodel = StarDist2D(config = None, name = star_model_name, basedir = model_dir)
Path(savedir).mkdir(exist_ok=True)
n_tiles = (1,1)
event_threshold = 1.0 - 1.0E-7
iou_threshold = 0.4
yolo_v2 = False

# %% [markdown]
# # In the cell below use the computed dictionary and apply division model detection

# %%
Raw_path = os.path.join(imagedir, '*tif')
X = glob.glob(Raw_path)

for imagename in X:

     model.predict(imagename, savedir, n_tiles = n_tiles, event_threshold = event_threshold, iou_threshold = iou_threshold)
