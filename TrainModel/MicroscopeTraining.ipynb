# %%
import sys
import os
from glob import glob
sys.path.append("../NEAT")
from NEATModels import NEATDynamic, nets
from NEATModels.config import dynamic_config
from NEATUtils import helpers
from NEATUtils.helpers import save_json, load_json
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
# Out:
# Using TensorFlow backend.

# %%
npz_directory = '/home/sancere/Kepler/CurieTrainingDatasets/oneatnpz/'
npz_name = 'microbin2V1.npz'
npz_val_name = 'microbin2V1val.npz'

#Read and Write the h5 file, directory location and name
model_dir =  '/home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/'
model_name = 'micronetbin2d29f16.h5'

#Neural network parameters
division_categories_json = model_dir + 'MicroscopeCategories.json'
key_categories = load_json(division_categories_json)
division_cord_json = model_dir + 'MicroscopeCord.json'
key_cord = load_json(division_cord_json)

# %%
#For ORNET use residual = True and for OSNET use residual = False
residual = True
#NUmber of starting convolutional filters, is doubled down with increasing depth
startfilter = 16
#CNN network start layer, mid layers and lstm layer kernel size
start_kernel = 7
lstm_kernel = 3
mid_kernel = 3
#Network depth has to be 9n + 2, n= 3 or 4 is optimal for Notum dataset
depth = 29
#Size of the gradient descent length vector, start small and use callbacks to get smaller when reaching the minima
learning_rate = 1.0E-4
#For stochastic gradient decent, the batch size used for computing the gradients
batch_size = 8
# use softmax for single event per box, sigmoid for multi event per box
lstm_hidden_unit = 16
#Training epochs, longer the better with proper chosen learning rate
epochs = 250
nboxes = 1
#The inbuilt model stride which is equal to the nulber of times image was downsampled by the network
show = False
stage_number = 3
last_conv_factor = 4
size_tminus = 3
size_tplus = 0
imagex = 64
imagey = 64
yolo_v0 = False
yolo_v1 = True
yolo_v2 = False


# In[4]:


config = dynamic_config(npz_directory =npz_directory, npz_name = npz_name, npz_val_name = npz_val_name, 
                         key_categories = key_categories, key_cord = key_cord, nboxes = nboxes, imagex = imagex,
                         imagey = imagey, size_tminus = size_tminus, size_tplus =size_tplus, epochs = epochs, yolo_v0 = yolo_v0, yolo_v1 = yolo_v1, yolo_v2 = yolo_v2,
                         residual = residual, depth = depth, start_kernel = start_kernel, mid_kernel = mid_kernel, stage_number = stage_number, last_conv_factor = last_conv_factor,
                         lstm_kernel = lstm_kernel, lstm_hidden_unit = lstm_hidden_unit, show = show,
                         startfilter = startfilter, batch_size = batch_size, model_name = model_name)

config_json = config.to_json()

print(config)
save_json(config_json, model_dir + os.path.splitext(model_name)[0] + '_Parameter.json')
# In[ ]:


Train = NEATDynamic(config, model_dir, model_name)

Train.loadData()

Train.TrainModel()
# Out:
# dynamic_config(batch_size=8, box_vector=6, categories=2, depth=29, epochs=250, imagex=64, imagey=64, key_categories={'Normal': 0, 'Division': 1}, key_cord={'x': 0, 'y': 1, 't': 2, 'h': 3, 'w': 4, 'c': 5}, last_conv_factor=4, learning_rate=0.0001, lstm_hidden_unit=16, lstm_kernel=3, mid_kernel=3, model_name='micronetbin2d29f16.h5', multievent=False, nboxes=1, npz_directory='/home/sancere/Kepler/CurieTrainingDatasets/oneatnpz/', npz_name='microbin2V1.npz', npz_val_name='microbin2V1val.npz', residual=True, show=False, size_tminus=3, size_tplus=0, stage_number=3, start_kernel=7, startfilter=16, stride=4, yolo_v0=False, yolo_v1=True, yolo_v2=False)
# number of  images:	 17731
# image size (3D):		 (4, 64, 64)
# axes:				 STXYC
# channels in / out:		 1
# number of  images:	 934
# image size (3D):		 (4, 64, 64)
# axes:				 STXYC
# channels in / out:		 1
# (17731, 1, 1, 8) 1
# /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/sklearn/utils/validation.py:72: FutureWarning: Pass classes=[0], y=[0 0 0 ... 0 0 0] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# 2021-08-13 13:50:22.554231: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-08-13 13:50:22.623315: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:17:00.0 name: Quadro RTX 6000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.64GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-08-13 13:50:22.626101: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-13 13:50:22.688645: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-08-13 13:50:22.725137: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-08-13 13:50:22.733774: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-08-13 13:50:22.818653: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-08-13 13:50:22.828634: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-08-13 13:50:22.943321: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-13 13:50:22.958072: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-08-13 13:50:22.959700: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-08-13 13:50:22.988595: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2021-08-13 13:50:22.992347: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f6884000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-08-13 13:50:22.992378: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-08-13 13:50:23.273373: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55d26f392050 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-08-13 13:50:23.273423: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 6000, Compute Capability 7.5
# 2021-08-13 13:50:23.280679: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:17:00.0 name: Quadro RTX 6000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.64GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-08-13 13:50:23.280804: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-13 13:50:23.280847: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-08-13 13:50:23.280885: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-08-13 13:50:23.280921: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-08-13 13:50:23.280958: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-08-13 13:50:23.280994: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-08-13 13:50:23.281031: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-13 13:50:23.291692: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-08-13 13:50:23.293013: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-13 13:50:23.304044: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-13 13:50:23.304078: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2021-08-13 13:50:23.304095: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2021-08-13 13:50:23.318324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22029 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:17:00.0, compute capability: 7.5)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 4, None, None 0
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 4, None, None 800         input_1[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 4, None, None 5504        input_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 4, None, None 64          time_distributed_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 4, None, None 64          conv3d_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 4, None, None 0           time_distributed_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 4, None, None 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 4, None, None 272         time_distributed_3[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 4, None, None 272         activation_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 4, None, None 64          time_distributed_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 4, None, None 64          conv3d_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 4, None, None 0           time_distributed_6[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 4, None, None 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 4, None, None 2320        time_distributed_7[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 4, None, None 6928        activation_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 4, None, None 64          time_distributed_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4, None, None 64          conv3d_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 4, None, None 0           time_distributed_9[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 4, None, None 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 4, None, None 1088        time_distributed_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 4, None, None 1088        time_distributed_10[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 4, None, None 1088        activation_1[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 4, None, None 1088        activation_3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, None, None 0           time_distributed_11[0][0]
#                                                                  time_distributed_8[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4, None, None 0           conv3d_5[0][0]
#                                                                  conv3d_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 4, None, None 256         add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 4, None, None 256         add_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 4, None, None 0           time_distributed_13[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 4, None, None 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 4, None, None 1040        time_distributed_14[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 4, None, None 1040        activation_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 4, None, None 64          time_distributed_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 4, None, None 64          conv3d_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 4, None, None 0           time_distributed_16[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 4, None, None 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 4, None, None 2320        time_distributed_17[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 4, None, None 6928        activation_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 4, None, None 64          time_distributed_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, None, None 64          conv3d_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 4, None, None 0           time_distributed_19[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 4, None, None 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 4, None, None 1088        time_distributed_20[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 4, None, None 1088        activation_6[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, None, None 0           add_10[0][0]
#                                                                  time_distributed_18[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 4, None, None 0           add_1[0][0]
#                                                                  conv3d_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 4, None, None 256         add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, None, None 256         add_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 4, None, None 0           time_distributed_22[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, None, None 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 4, None, None 1040        time_distributed_23[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 4, None, None 1040        activation_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 4, None, None 64          time_distributed_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, None, None 64          conv3d_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 4, None, None 0           time_distributed_25[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, None, None 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 4, None, None 2320        time_distributed_26[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 4, None, None 6928        activation_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 4, None, None 64          time_distributed_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, None, None 64          conv3d_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 4, None, None 0           time_distributed_28[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, None, None 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 4, None, None 1088        time_distributed_29[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 4, None, None 1088        activation_9[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, None, None 0           add_11[0][0]
#                                                                  time_distributed_27[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4, None, None 0           add_2[0][0]
#                                                                  conv3d_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 4, None, None 256         add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, None, None 256         add_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 4, None, None 0           time_distributed_31[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, None, None 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 4, None, None 4160        time_distributed_32[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 4, None, None 4160        activation_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 4, None, None 256         time_distributed_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, None, None 256         conv3d_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 4, None, None 0           time_distributed_34[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, None, None 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 4, None, None 36928       time_distributed_35[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 4, None, None 110656      activation_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (None, 4, None, None 256         time_distributed_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, None, None 256         conv3d_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (None, 4, None, None 0           time_distributed_37[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, None, None 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (None, 4, None, None 8320        add_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (None, 4, None, None 8320        time_distributed_38[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 4, None, None 8320        add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 4, None, None 8320        activation_12[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 4, None, None 0           time_distributed_39[0][0]
#                                                                  time_distributed_36[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, None, None 0           conv3d_15[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (None, 4, None, None 512         add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, None, None 512         add_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (None, 4, None, None 0           time_distributed_41[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, None, None 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (None, 4, None, None 8256        time_distributed_42[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 4, None, None 8256        activation_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (None, 4, None, None 256         time_distributed_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, None, None 256         conv3d_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (None, 4, None, None 0           time_distributed_44[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, None, None 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (None, 4, None, None 36928       time_distributed_45[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 4, None, None 110656      activation_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (None, 4, None, None 256         time_distributed_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, None, None 256         conv3d_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_48 (TimeDistri (None, 4, None, None 0           time_distributed_47[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, None, None 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (None, 4, None, None 8320        time_distributed_48[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 4, None, None 8320        activation_15[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, None, None 0           add_13[0][0]
#                                                                  time_distributed_46[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, None, None 0           add_4[0][0]
#                                                                  conv3d_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_50 (TimeDistri (None, 4, None, None 512         add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, None, None 512         add_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (None, 4, None, None 0           time_distributed_50[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, None, None 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_49 (TimeDistri (None, 4, None, None 8256        time_distributed_51[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 4, None, None 8256        activation_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (None, 4, None, None 256         time_distributed_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, None, None 256         conv3d_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (None, 4, None, None 0           time_distributed_53[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, None, None 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (None, 4, None, None 36928       time_distributed_54[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 4, None, None 110656      activation_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (None, 4, None, None 256         time_distributed_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, None, None 256         conv3d_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_57 (TimeDistri (None, 4, None, None 0           time_distributed_56[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, None, None 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (None, 4, None, None 8320        time_distributed_57[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 4, None, None 8320        activation_18[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, None, None 0           add_14[0][0]
#                                                                  time_distributed_55[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, None, None 0           add_5[0][0]
#                                                                  conv3d_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_59 (TimeDistri (None, 4, None, None 512         add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, None, None 512         add_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_60 (TimeDistri (None, 4, None, None 0           time_distributed_59[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, None, None 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_58 (TimeDistri (None, 4, None, None 16512       time_distributed_60[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 4, None, None 16512       activation_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_62 (TimeDistri (None, 4, None, None 512         time_distributed_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 4, None, None 512         conv3d_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_63 (TimeDistri (None, 4, None, None 0           time_distributed_62[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, None, None 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_61 (TimeDistri (None, 4, None, None 147584      time_distributed_63[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 4, None, None 442496      activation_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_65 (TimeDistri (None, 4, None, None 512         time_distributed_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, None, None 512         conv3d_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_66 (TimeDistri (None, 4, None, None 0           time_distributed_65[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4, None, None 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_67 (TimeDistri (None, 4, None, None 33024       add_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_64 (TimeDistri (None, 4, None, None 33024       time_distributed_66[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 4, None, None 33024       add_6[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 4, None, None 33024       activation_21[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 4, None, None 0           time_distributed_67[0][0]
#                                                                  time_distributed_64[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, None, None 0           conv3d_25[0][0]
#                                                                  conv3d_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_69 (TimeDistri (None, 4, None, None 1024        add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, None, None 1024        add_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_70 (TimeDistri (None, 4, None, None 0           time_distributed_69[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 4, None, None 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_68 (TimeDistri (None, 4, None, None 32896       time_distributed_70[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 4, None, None 32896       activation_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_72 (TimeDistri (None, 4, None, None 512         time_distributed_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, None, None 512         conv3d_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_73 (TimeDistri (None, 4, None, None 0           time_distributed_72[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, None, None 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_71 (TimeDistri (None, 4, None, None 147584      time_distributed_73[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 4, None, None 442496      activation_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_75 (TimeDistri (None, 4, None, None 512         time_distributed_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 4, None, None 512         conv3d_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_76 (TimeDistri (None, 4, None, None 0           time_distributed_75[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, None, None 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_74 (TimeDistri (None, 4, None, None 33024       time_distributed_76[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 4, None, None 33024       activation_24[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 4, None, None 0           add_16[0][0]
#                                                                  time_distributed_74[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, None, None 0           add_7[0][0]
#                                                                  conv3d_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_78 (TimeDistri (None, 4, None, None 1024        add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 4, None, None 1024        add_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_79 (TimeDistri (None, 4, None, None 0           time_distributed_78[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 4, None, None 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_77 (TimeDistri (None, 4, None, None 32896       time_distributed_79[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 4, None, None 32896       activation_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_81 (TimeDistri (None, 4, None, None 512         time_distributed_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, None, None 512         conv3d_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_82 (TimeDistri (None, 4, None, None 0           time_distributed_81[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 4, None, None 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_80 (TimeDistri (None, 4, None, None 147584      time_distributed_82[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 4, None, None 442496      activation_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_84 (TimeDistri (None, 4, None, None 512         time_distributed_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, None, None 512         conv3d_30[0][0]
# __________________________________________________________________________________________________
# time_distributed_85 (TimeDistri (None, 4, None, None 0           time_distributed_84[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, None, None 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_83 (TimeDistri (None, 4, None, None 33024       time_distributed_85[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 4, None, None 33024       activation_27[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 4, None, None 0           add_17[0][0]
#                                                                  time_distributed_83[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 4, None, None 0           add_8[0][0]
#                                                                  conv3d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 4, None, None 1024        add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 4, None, None 1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 4, None, None 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 4, None, None 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 4, None, None 0           activation_56[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# newlstmdeep (ConvLSTM2D)        (None, None, None, 1 156736      add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 8 1160        newlstmdeep[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 8 32          conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 8 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None, 2 0           activation_57[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None, None, 6 0           activation_57[0][0]
# __________________________________________________________________________________________________
# yolo (Conv2D)                   (None, None, None, 2 1026        lambda_1[0][0]
# __________________________________________________________________________________________________
# secyolo (Conv2D)                (None, None, None, 6 9222        lambda_2[0][0]
# ...
# y [[0.49939385]]
# True positional value y 0.5
# t [[0.9992737]]
# True positional value t 1.0
# h [[0.07738691]]
# True positional value h 0.0625
# w [[0.07826734]]
# True positional value w 0.09375
# c [[0.9970294]]
# True positional value c 1.0
# Epoch 226/250
# 17731/17731 [==============================] - 333s 19ms/step - loss: 0.4001 - accuracy: 0.9285 - val_loss: 0.5624 - val_accuracy: 0.8715
#
# Epoch 00226: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Normal Probability: [[0.99999976]]
# True Cell type: Normal
# x [[0.49915797]]
# True positional value x 0.5
# y [[0.5004509]]
# True positional value y 0.5
# t [[0.99991417]]
# True positional value t 1.0
# h [[0.34125412]]
# True positional value h 0.375
# w [[0.29825267]]
# True positional value w 0.3125
# c [[0.99978834]]
# True positional value c 1.0
# Epoch 227/250
# 17731/17731 [==============================] - 333s 19ms/step - loss: 0.3998 - accuracy: 0.9254 - val_loss: 0.5631 - val_accuracy: 0.8694
#
# Epoch 00227: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.9999999]]
# True Cell type: Division
# x [[0.49985453]]
# True positional value x 0.5
# y [[0.5008223]]
# True positional value y 0.5
# t [[0.9996039]]
# True positional value t 1.0
# h [[0.35055676]]
# True positional value h 0.34375
# w [[0.39439225]]
# True positional value w 0.40625
# c [[0.9994727]]
# True positional value c 1.0
# Epoch 228/250
# 17731/17731 [==============================] - 333s 19ms/step - loss: 0.3995 - accuracy: 0.9279 - val_loss: 0.5622 - val_accuracy: 0.8694
#
# Epoch 00228: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.9999999]]
# True Cell type: Division
# x [[0.5010765]]
# True positional value x 0.5
# y [[0.49969155]]
# True positional value y 0.5
# t [[0.9998103]]
# True positional value t 1.0
# h [[0.5335615]]
# True positional value h 0.546875
# w [[0.45199025]]
# True positional value w 0.484375
# c [[0.99593157]]
# True positional value c 1.0
# Epoch 229/250
# 17731/17731 [==============================] - 334s 19ms/step - loss: 0.3994 - accuracy: 0.9269 - val_loss: 0.5635 - val_accuracy: 0.8704
#
# Epoch 00229: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.9999999]]
# True Cell type: Division
# x [[0.49993348]]
# True positional value x 0.5
# y [[0.49938315]]
# True positional value y 0.5
# t [[0.9998754]]
# True positional value t 1.0
# h [[0.49072063]]
# True positional value h 0.40625
# w [[0.50943077]]
# True positional value w 0.5
# c [[0.9998159]]
# True positional value c 1.0
# Epoch 230/250
# 17731/17731 [==============================] - 334s 19ms/step - loss: 0.3991 - accuracy: 0.9298 - val_loss: 0.5624 - val_accuracy: 0.8694
#
# Epoch 00230: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.99999976]]
# True Cell type: Division
# x [[0.500509]]
# True positional value x 0.5
# y [[0.5008466]]
# True positional value y 0.5
# t [[0.9995347]]
# True positional value t 1.0
# h [[0.3625468]]
# True positional value h 0.359375
# w [[0.41292754]]
# True positional value w 0.46875
# c [[0.9993754]]
# True positional value c 1.0
# Epoch 231/250
# 17731/17731 [==============================] - 333s 19ms/step - loss: 0.3989 - accuracy: 0.9318 - val_loss: 0.5637 - val_accuracy: 0.8704
#
# Epoch 00231: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.9999914]]
# True Cell type: Division
# x [[0.49916264]]
# True positional value x 0.5
# y [[0.49961883]]
# True positional value y 0.5
# t [[0.9993963]]
# True positional value t 1.0
# h [[0.42777705]]
# True positional value h 0.453125
# w [[0.5101967]]
# True positional value w 0.53125
# c [[0.99895453]]
# True positional value c 1.0
# Epoch 232/250
# 17731/17731 [==============================] - 333s 19ms/step - loss: 0.3986 - accuracy: 0.9340 - val_loss: 0.5622 - val_accuracy: 0.8683
#
# Epoch 00232: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Normal Probability: [[1.]]
# True Cell type: Normal
# x [[0.50024635]]
# True positional value x 0.5
# y [[0.5005209]]
# True positional value y 0.5
# t [[0.9990514]]
# True positional value t 1.0
# h [[0.37693375]]
# True positional value h 0.375
# w [[0.41909906]]
# True positional value w 0.34375
# c [[0.9999132]]
# True positional value c 1.0
# Epoch 233/250
# 17731/17731 [==============================] - 333s 19ms/step - loss: 0.3984 - accuracy: 0.9304 - val_loss: 0.5626 - val_accuracy: 0.8672
#
# Epoch 00233: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.99996495]]
# True Cell type: Division
# x [[0.4987468]]
# True positional value x 0.5
# y [[0.49967322]]
# True positional value y 0.5
# t [[0.9997845]]
# True positional value t 1.0
# h [[0.40544474]]
# True positional value h 0.40625
# w [[0.51941377]]
# True positional value w 0.53125
# c [[0.999424]]
# True positional value c 1.0
# Epoch 234/250
# 17731/17731 [==============================] - 335s 19ms/step - loss: 0.3981 - accuracy: 0.9300 - val_loss: 0.5638 - val_accuracy: 0.8694
#
# Epoch 00234: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.9999988]]
# True Cell type: Division
# x [[0.5009674]]
# True positional value x 0.5
# y [[0.49911976]]
# True positional value y 0.5
# t [[0.9999033]]
# True positional value t 1.0
# h [[0.6053983]]
# True positional value h 0.578125
# w [[0.5625926]]
# True positional value w 0.53125
# c [[0.9997769]]
# True positional value c 1.0
# Epoch 235/250
# 17731/17731 [==============================] - 335s 19ms/step - loss: 0.3979 - accuracy: 0.9300 - val_loss: 0.5636 - val_accuracy: 0.8683
#
# Epoch 00235: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Normal Probability: [[0.9787637]]
# True Cell type: Normal
# x [[0.5005566]]
# True positional value x 0.5
# y [[0.49975765]]
# True positional value y 0.5
# t [[0.9998944]]
# True positional value t 1.0
# h [[0.35409075]]
# True positional value h 0.34375
# w [[0.3183559]]
# True positional value w 0.28125
# c [[0.99998975]]
# True positional value c 1.0
# Epoch 236/250
# 17731/17731 [==============================] - 336s 19ms/step - loss: 0.3977 - accuracy: 0.9294 - val_loss: 0.5634 - val_accuracy: 0.8683
#
# Epoch 00236: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.99999905]]
# True Cell type: Division
# x [[0.49983668]]
# True positional value x 0.5
# y [[0.4995229]]
# True positional value y 0.5
# t [[0.99951756]]
# True positional value t 1.0
# h [[0.30717388]]
# True positional value h 0.390625
# w [[0.34964597]]
# True positional value w 0.359375
# c [[0.9990202]]
# True positional value c 1.0
# Epoch 237/250
# 17731/17731 [==============================] - 336s 19ms/step - loss: 0.3974 - accuracy: 0.9313 - val_loss: 0.5624 - val_accuracy: 0.8694
#
# Epoch 00237: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Normal Probability: [[0.9999943]]
# True Cell type: Normal
# x [[0.5004093]]
# True positional value x 0.5
# y [[0.5005463]]
# True positional value y 0.5
# t [[0.99991345]]
# True positional value t 1.0
# h [[0.4008482]]
# True positional value h 0.390625
# w [[0.32005793]]
# True positional value w 0.3125
# c [[0.9999603]]
# True positional value c 1.0
# Epoch 238/250
# 17731/17731 [==============================] - 335s 19ms/step - loss: 0.3972 - accuracy: 0.9345 - val_loss: 0.5630 - val_accuracy: 0.8704
#
# Epoch 00238: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Normal Probability: [[1.]]
# True Cell type: Normal
# x [[0.50008357]]
# True positional value x 0.5
# y [[0.5004784]]
# True positional value y 0.5
# t [[0.99979895]]
# True positional value t 1.0
# h [[0.4545508]]
# True positional value h 0.40625
# w [[0.49499413]]
# True positional value w 0.46875
# c [[0.9997676]]
# True positional value c 1.0
# Epoch 239/250
# 17731/17731 [==============================] - 335s 19ms/step - loss: 0.3970 - accuracy: 0.9328 - val_loss: 0.5608 - val_accuracy: 0.8704
#
# Epoch 00239: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.9998148]]
# True Cell type: Division
# x [[0.50070626]]
# True positional value x 0.5
# y [[0.50043076]]
# True positional value y 0.5
# t [[0.9978618]]
# True positional value t 1.0
# h [[0.21274169]]
# True positional value h 0.203125
# w [[0.22275554]]
# True positional value w 0.265625
# c [[0.99737215]]
# True positional value c 1.0
# Epoch 240/250
# 17731/17731 [==============================] - 334s 19ms/step - loss: 0.3968 - accuracy: 0.9329 - val_loss: 0.5621 - val_accuracy: 0.8737
#
# Epoch 00240: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.99999976]]
# True Cell type: Division
# x [[0.5001709]]
# True positional value x 0.5
# y [[0.50067794]]
# True positional value y 0.5
# t [[0.99930286]]
# True positional value t 1.0
# h [[0.24598067]]
# True positional value h 0.3125
# w [[0.5342667]]
# True positional value w 0.5
# c [[0.99431074]]
# True positional value c 1.0
# Epoch 241/250
# 17731/17731 [==============================] - 333s 19ms/step - loss: 0.3965 - accuracy: 0.9309 - val_loss: 0.5588 - val_accuracy: 0.8704
#
# Epoch 00241: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.99999976]]
# True Cell type: Division
# x [[0.49966347]]
# True positional value x 0.5
# y [[0.4990808]]
# True positional value y 0.5
# t [[0.9998523]]
# True positional value t 1.0
# h [[0.4827557]]
# True positional value h 0.515625
# w [[0.60215497]]
# True positional value w 0.625
# c [[0.99780804]]
# True positional value c 1.0
# Epoch 242/250
# 17731/17731 [==============================] - 334s 19ms/step - loss: 0.3962 - accuracy: 0.9341 - val_loss: 0.5582 - val_accuracy: 0.8704
#
# Epoch 00242: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.99999964]]
# True Cell type: Division
# x [[0.50024056]]
# True positional value x 0.5
# y [[0.49877366]]
# True positional value y 0.5
# t [[0.9996356]]
# True positional value t 1.0
# h [[0.5189605]]
# True positional value h 0.515625
# w [[0.46665806]]
# True positional value w 0.484375
# c [[0.99894315]]
# True positional value c 1.0
# Epoch 243/250
# 17731/17731 [==============================] - 333s 19ms/step - loss: 0.3960 - accuracy: 0.9327 - val_loss: 0.5597 - val_accuracy: 0.8694
#
# Epoch 00243: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[1.]]
# True Cell type: Division
# x [[0.49923193]]
# True positional value x 0.5
# y [[0.5002081]]
# True positional value y 0.5
# t [[0.9996433]]
# True positional value t 1.0
# h [[0.2545047]]
# True positional value h 0.28125
# w [[0.35697523]]
# True positional value w 0.390625
# c [[0.99960023]]
# True positional value c 1.0
# Epoch 244/250
# 17731/17731 [==============================] - 333s 19ms/step - loss: 0.3959 - accuracy: 0.9321 - val_loss: 0.5613 - val_accuracy: 0.8694
#
# Epoch 00244: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Normal Probability: [[0.9999999]]
# True Cell type: Normal
# x [[0.5001478]]
# True positional value x 0.5
# y [[0.49931625]]
# True positional value y 0.5
# t [[0.99976593]]
# True positional value t 1.0
# h [[0.35814553]]
# True positional value h 0.3125
# w [[0.30376375]]
# True positional value w 0.34375
# c [[0.99999154]]
# True positional value c 1.0
# Epoch 245/250
# 17731/17731 [==============================] - 334s 19ms/step - loss: 0.3956 - accuracy: 0.9333 - val_loss: 0.5594 - val_accuracy: 0.8704
#
# Epoch 00245: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.9999999]]
# True Cell type: Division
# x [[0.5018934]]
# True positional value x 0.5
# y [[0.5012144]]
# True positional value y 0.5
# t [[0.99984884]]
# True positional value t 1.0
# h [[0.46389696]]
# True positional value h 0.46875
# w [[0.42273405]]
# True positional value w 0.5
# c [[0.9963838]]
# True positional value c 1.0
# Epoch 246/250
# 17731/17731 [==============================] - 334s 19ms/step - loss: 0.3953 - accuracy: 0.9350 - val_loss: 0.5609 - val_accuracy: 0.8715
#
# Epoch 00246: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Normal Probability: [[0.9989064]]
# True Cell type: Normal
# x [[0.49914446]]
# True positional value x 0.5
# y [[0.5006406]]
# True positional value y 0.5
# t [[0.999506]]
# True positional value t 1.0
# h [[0.18874307]]
# True positional value h 0.234375
# w [[0.21779713]]
# True positional value w 0.296875
# c [[0.9972505]]
# True positional value c 1.0
# Epoch 247/250
# 17731/17731 [==============================] - 334s 19ms/step - loss: 0.3951 - accuracy: 0.9347 - val_loss: 0.5610 - val_accuracy: 0.8726
#
# Epoch 00247: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.9999969]]
# True Cell type: Division
# x [[0.49935257]]
# True positional value x 0.5
# y [[0.500567]]
# True positional value y 0.5
# t [[0.9993286]]
# True positional value t 1.0
# h [[0.3530353]]
# True positional value h 0.359375
# w [[0.40450114]]
# True positional value w 0.4375
# c [[0.9972869]]
# True positional value c 1.0
# Epoch 248/250
# 17731/17731 [==============================] - 333s 19ms/step - loss: 0.3949 - accuracy: 0.9334 - val_loss: 0.5585 - val_accuracy: 0.8683
#
# Epoch 00248: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.99999726]]
# True Cell type: Division
# x [[0.49865514]]
# True positional value x 0.5
# y [[0.5004938]]
# True positional value y 0.5
# t [[0.99950826]]
# True positional value t 1.0
# h [[0.3241986]]
# True positional value h 0.34375
# w [[0.39927256]]
# True positional value w 0.40625
# c [[0.9996269]]
# True positional value c 1.0
# Epoch 249/250
# 17731/17731 [==============================] - 334s 19ms/step - loss: 0.3947 - accuracy: 0.9353 - val_loss: 0.5594 - val_accuracy: 0.8726
#
# Epoch 00249: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.99999607]]
# True Cell type: Division
# x [[0.5009039]]
# True positional value x 0.5
# y [[0.49922255]]
# True positional value y 0.5
# t [[0.99924517]]
# True positional value t 1.0
# h [[0.24297337]]
# True positional value h 0.265625
# w [[0.26632392]]
# True positional value w 0.328125
# c [[0.9999131]]
# True positional value c 1.0
# Epoch 250/250
# 17731/17731 [==============================] - 334s 19ms/step - loss: 0.3944 - accuracy: 0.9332 - val_loss: 0.5589 - val_accuracy: 0.8726
#
# Epoch 00250: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16.h5
# Predicted cell: Division Probability: [[0.9999999]]
# True Cell type: Division
# x [[0.49927247]]
# True positional value x 0.5
# y [[0.49939433]]
# True positional value y 0.5
# t [[0.9997873]]
# True positional value t 1.0
# h [[0.5871326]]
# True positional value h 0.515625
# w [[0.6072653]]
# True positional value w 0.515625
# c [[0.9997222]]
# True positional value c 1.0
