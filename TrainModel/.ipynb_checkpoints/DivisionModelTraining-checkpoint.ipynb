# %%
import sys
import os
from glob import glob
sys.path.append("../NEAT")
from NEATModels import NEATDynamic, nets
from NEATModels.config  import dynamic_config
from NEATUtils import helpers
from NEATUtils.helpers import save_json, load_json
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
# Out:
# Using TensorFlow backend.

# %%
npz_directory = '/home/sancere/Kepler/FinalONEATTraining/Microneat/'
npz_name = 'microneatbin2.npz'
npz_val_name = 'microneatbin2val.npz'
model_dir = '/home/sancere/Kepler/FinalONEATTraining/Microneatmodel/'
#Model name based on wether it is residual or sequntial ONEAT network
model_name = 'microresnet.h5'

# %%
division_categories_json = model_dir + 'MicroscopeCategories.json'
key_categories = load_json(division_categories_json)
division_cord_json = model_dir + 'MicroscopeCord.json'
key_cord = load_json(division_cord_json)

#For ORNET use residual = True and for OSNET use residual = False
residual = True
#NUmber of starting convolutional filters, is doubled down with increasing depth
startfilter = 32
#CNN network start layer, mid layers and lstm layer kernel size
start_kernel = 3
lstm_kernel = 3
mid_kernel = 3
#Network depth has to be 9n + 2, n= 3 or 4 is optimal for Notum dataset
depth = 47
#Size of the gradient descent length vector, start small and use callbacks to get smaller when reaching the minima
learning_rate = 1.0E-6
#For stochastic gradient decent, the batch size used for computing the gradients
batch_size = 2
# use softmax for single event per box, sigmoid for multi event per box
lstm_hidden_unit = 16
#Training epochs, longer the better with proper chosen learning rate
epochs = 250
nboxes = 1
#The inbuilt model stride which is equal to the nulber of times image was downsampled by the network
show = True

size_tminus = 3
size_tplus = 0
imagex = 128
imagey = 128

# %%
config = dynamic_config(npz_directory =npz_directory, npz_name = npz_name, npz_val_name = npz_val_name, 
                         key_categories = key_categories, key_cord = key_cord, nboxes = nboxes, imagex = imagex,
                         imagey = imagey, size_tminus = size_tminus, size_tplus =size_tplus, 
                         residual = residual, depth = depth, start_kernel = start_kernel, mid_kernel = mid_kernel,
                         lstm_kernel = lstm_kernel, lstm_hidden_unit = lstm_hidden_unit, show = show,
                         startfiler = startfilter, batch_size = batch_size, model_name = model_name)

config_json = config.to_json()

print(config)
save_json(config_json, model_dir + os.path.splitext(model_name)[0] + '_Parameter.json')
# Out:
# dynamic_config(batch_size=2, box_vector=5, categories=2, depth=47, epochs=100, imagex=128, imagey=128, key_categories={'Normal': 0, 'Division': 1}, key_cord={'x': 0, 'y': 1, 't': 2, 'h': 3, 'w': 4}, learning_rate=0.0001, lstm_hidden_unit=16, lstm_kernel=3, mid_kernel=3, model_name='microresnet.h5', multievent=False, nboxes=1, npz_directory='/home/sancere/Kepler/FinalONEATTraining/Microneat/', npz_name='microneatbin2.npz', npz_val_name='microneatbin2val.npz', residual=True, show=True, size_tminus=3, size_tplus=0, start_kernel=3, startfilter=48, stride=4, yolo_v0=True, yolo_v1=False, yolo_v2=False)

# %%
Train = NEATDynamic(config, model_dir, model_name)

Train.loadData()

Train.TrainModel()
# Out:
# number of  images:	 12787
# image size (3D):		 (4, 128, 128)
# axes:				 STXYC
# channels in / out:		 1
# number of  images:	 674
# image size (3D):		 (4, 128, 128)
# axes:				 STXYC
# channels in / out:		 1
# 5
# (12787, 1, 1, 7) 1
# /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass classes=[0], y=[0 0 0 ... 0 0 0] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 4, None, None 0
# __________________________________________________________________________________________________
# time_distributed_140 (TimeDistr (None, 4, None, None 480         input_2[0][0]
# __________________________________________________________________________________________________
# conv3d_50 (Conv3D)              (None, 4, None, None 1344        input_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_141 (TimeDistr (None, 4, None, None 192         time_distributed_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 4, None, None 192         conv3d_50[0][0]
# __________________________________________________________________________________________________
# time_distributed_142 (TimeDistr (None, 4, None, None 0           time_distributed_141[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 4, None, None 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# time_distributed_143 (TimeDistr (None, 4, None, None 2352        time_distributed_142[0][0]
# __________________________________________________________________________________________________
# conv3d_51 (Conv3D)              (None, 4, None, None 2352        activation_93[0][0]
# __________________________________________________________________________________________________
# time_distributed_145 (TimeDistr (None, 4, None, None 192         time_distributed_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 4, None, None 192         conv3d_51[0][0]
# __________________________________________________________________________________________________
# time_distributed_146 (TimeDistr (None, 4, None, None 0           time_distributed_145[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 4, None, None 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# time_distributed_144 (TimeDistr (None, 4, None, None 20784       time_distributed_146[0][0]
# __________________________________________________________________________________________________
# conv3d_52 (Conv3D)              (None, 4, None, None 62256       activation_94[0][0]
# __________________________________________________________________________________________________
# time_distributed_148 (TimeDistr (None, 4, None, None 192         time_distributed_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 4, None, None 192         conv3d_52[0][0]
# __________________________________________________________________________________________________
# time_distributed_149 (TimeDistr (None, 4, None, None 0           time_distributed_148[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 4, None, None 0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# time_distributed_150 (TimeDistr (None, 4, None, None 9408        time_distributed_142[0][0]
# __________________________________________________________________________________________________
# time_distributed_147 (TimeDistr (None, 4, None, None 9408        time_distributed_149[0][0]
# __________________________________________________________________________________________________
# conv3d_54 (Conv3D)              (None, 4, None, None 9408        activation_93[0][0]
# __________________________________________________________________________________________________
# conv3d_53 (Conv3D)              (None, 4, None, None 9408        activation_95[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 4, None, None 0           time_distributed_150[0][0]
#                                                                  time_distributed_147[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 4, None, None 0           conv3d_54[0][0]
#                                                                  conv3d_53[0][0]
# __________________________________________________________________________________________________
# time_distributed_152 (TimeDistr (None, 4, None, None 768         add_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 4, None, None 768         add_32[0][0]
# __________________________________________________________________________________________________
# time_distributed_153 (TimeDistr (None, 4, None, None 0           time_distributed_152[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 4, None, None 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# time_distributed_151 (TimeDistr (None, 4, None, None 9264        time_distributed_153[0][0]
# __________________________________________________________________________________________________
# conv3d_55 (Conv3D)              (None, 4, None, None 9264        activation_96[0][0]
# __________________________________________________________________________________________________
# time_distributed_155 (TimeDistr (None, 4, None, None 192         time_distributed_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 4, None, None 192         conv3d_55[0][0]
# __________________________________________________________________________________________________
# time_distributed_156 (TimeDistr (None, 4, None, None 0           time_distributed_155[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 4, None, None 0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# time_distributed_154 (TimeDistr (None, 4, None, None 20784       time_distributed_156[0][0]
# __________________________________________________________________________________________________
# conv3d_56 (Conv3D)              (None, 4, None, None 62256       activation_97[0][0]
# __________________________________________________________________________________________________
# time_distributed_158 (TimeDistr (None, 4, None, None 192         time_distributed_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 4, None, None 192         conv3d_56[0][0]
# __________________________________________________________________________________________________
# time_distributed_159 (TimeDistr (None, 4, None, None 0           time_distributed_158[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 4, None, None 0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# time_distributed_157 (TimeDistr (None, 4, None, None 9408        time_distributed_159[0][0]
# __________________________________________________________________________________________________
# conv3d_57 (Conv3D)              (None, 4, None, None 9408        activation_98[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 4, None, None 0           add_47[0][0]
#                                                                  time_distributed_157[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 4, None, None 0           add_32[0][0]
#                                                                  conv3d_57[0][0]
# __________________________________________________________________________________________________
# time_distributed_161 (TimeDistr (None, 4, None, None 768         add_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 4, None, None 768         add_33[0][0]
# __________________________________________________________________________________________________
# time_distributed_162 (TimeDistr (None, 4, None, None 0           time_distributed_161[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 4, None, None 0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# time_distributed_160 (TimeDistr (None, 4, None, None 9264        time_distributed_162[0][0]
# __________________________________________________________________________________________________
# conv3d_58 (Conv3D)              (None, 4, None, None 9264        activation_99[0][0]
# __________________________________________________________________________________________________
# time_distributed_164 (TimeDistr (None, 4, None, None 192         time_distributed_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 4, None, None 192         conv3d_58[0][0]
# __________________________________________________________________________________________________
# time_distributed_165 (TimeDistr (None, 4, None, None 0           time_distributed_164[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 4, None, None 0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# time_distributed_163 (TimeDistr (None, 4, None, None 20784       time_distributed_165[0][0]
# __________________________________________________________________________________________________
# conv3d_59 (Conv3D)              (None, 4, None, None 62256       activation_100[0][0]
# __________________________________________________________________________________________________
# time_distributed_167 (TimeDistr (None, 4, None, None 192         time_distributed_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 4, None, None 192         conv3d_59[0][0]
# __________________________________________________________________________________________________
# time_distributed_168 (TimeDistr (None, 4, None, None 0           time_distributed_167[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 4, None, None 0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# time_distributed_166 (TimeDistr (None, 4, None, None 9408        time_distributed_168[0][0]
# __________________________________________________________________________________________________
# conv3d_60 (Conv3D)              (None, 4, None, None 9408        activation_101[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 4, None, None 0           add_48[0][0]
#                                                                  time_distributed_166[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 4, None, None 0           add_33[0][0]
#                                                                  conv3d_60[0][0]
# __________________________________________________________________________________________________
# time_distributed_170 (TimeDistr (None, 4, None, None 768         add_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 4, None, None 768         add_34[0][0]
# __________________________________________________________________________________________________
# time_distributed_171 (TimeDistr (None, 4, None, None 0           time_distributed_170[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 4, None, None 0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# time_distributed_169 (TimeDistr (None, 4, None, None 9264        time_distributed_171[0][0]
# __________________________________________________________________________________________________
# conv3d_61 (Conv3D)              (None, 4, None, None 9264        activation_102[0][0]
# __________________________________________________________________________________________________
# time_distributed_173 (TimeDistr (None, 4, None, None 192         time_distributed_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 4, None, None 192         conv3d_61[0][0]
# __________________________________________________________________________________________________
# time_distributed_174 (TimeDistr (None, 4, None, None 0           time_distributed_173[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 4, None, None 0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# time_distributed_172 (TimeDistr (None, 4, None, None 20784       time_distributed_174[0][0]
# __________________________________________________________________________________________________
# conv3d_62 (Conv3D)              (None, 4, None, None 62256       activation_103[0][0]
# __________________________________________________________________________________________________
# time_distributed_176 (TimeDistr (None, 4, None, None 192         time_distributed_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 4, None, None 192         conv3d_62[0][0]
# __________________________________________________________________________________________________
# time_distributed_177 (TimeDistr (None, 4, None, None 0           time_distributed_176[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 4, None, None 0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# time_distributed_175 (TimeDistr (None, 4, None, None 9408        time_distributed_177[0][0]
# __________________________________________________________________________________________________
# conv3d_63 (Conv3D)              (None, 4, None, None 9408        activation_104[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 4, None, None 0           add_49[0][0]
#                                                                  time_distributed_175[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 4, None, None 0           add_34[0][0]
#                                                                  conv3d_63[0][0]
# __________________________________________________________________________________________________
# time_distributed_179 (TimeDistr (None, 4, None, None 768         add_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 4, None, None 768         add_35[0][0]
# __________________________________________________________________________________________________
# time_distributed_180 (TimeDistr (None, 4, None, None 0           time_distributed_179[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 4, None, None 0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# time_distributed_178 (TimeDistr (None, 4, None, None 9264        time_distributed_180[0][0]
# __________________________________________________________________________________________________
# conv3d_64 (Conv3D)              (None, 4, None, None 9264        activation_105[0][0]
# __________________________________________________________________________________________________
# time_distributed_182 (TimeDistr (None, 4, None, None 192         time_distributed_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 4, None, None 192         conv3d_64[0][0]
# __________________________________________________________________________________________________
# time_distributed_183 (TimeDistr (None, 4, None, None 0           time_distributed_182[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 4, None, None 0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# time_distributed_181 (TimeDistr (None, 4, None, None 20784       time_distributed_183[0][0]
# __________________________________________________________________________________________________
# conv3d_65 (Conv3D)              (None, 4, None, None 62256       activation_106[0][0]
# __________________________________________________________________________________________________
# time_distributed_185 (TimeDistr (None, 4, None, None 192         time_distributed_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 4, None, None 192         conv3d_65[0][0]
# __________________________________________________________________________________________________
# time_distributed_186 (TimeDistr (None, 4, None, None 0           time_distributed_185[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 4, None, None 0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# time_distributed_184 (TimeDistr (None, 4, None, None 9408        time_distributed_186[0][0]
# __________________________________________________________________________________________________
# conv3d_66 (Conv3D)              (None, 4, None, None 9408        activation_107[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 4, None, None 0           add_50[0][0]
#                                                                  time_distributed_184[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 4, None, None 0           add_35[0][0]
#                                                                  conv3d_66[0][0]
# __________________________________________________________________________________________________
# time_distributed_188 (TimeDistr (None, 4, None, None 768         add_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 4, None, None 768         add_36[0][0]
# __________________________________________________________________________________________________
# time_distributed_189 (TimeDistr (None, 4, None, None 0           time_distributed_188[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 4, None, None 0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# time_distributed_187 (TimeDistr (None, 4, None, None 37056       time_distributed_189[0][0]
# __________________________________________________________________________________________________
# conv3d_67 (Conv3D)              (None, 4, None, None 37056       activation_108[0][0]
# __________________________________________________________________________________________________
# time_distributed_191 (TimeDistr (None, 4, None, None 768         time_distributed_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 4, None, None 768         conv3d_67[0][0]
# __________________________________________________________________________________________________
# time_distributed_192 (TimeDistr (None, 4, None, None 0           time_distributed_191[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 4, None, None 0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# time_distributed_190 (TimeDistr (None, 4, None, None 331968      time_distributed_192[0][0]
# __________________________________________________________________________________________________
# conv3d_68 (Conv3D)              (None, 4, None, None 995520      activation_109[0][0]
# __________________________________________________________________________________________________
# time_distributed_194 (TimeDistr (None, 4, None, None 768         time_distributed_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 4, None, None 768         conv3d_68[0][0]
# __________________________________________________________________________________________________
# time_distributed_195 (TimeDistr (None, 4, None, None 0           time_distributed_194[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 4, None, None 0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# time_distributed_196 (TimeDistr (None, 4, None, None 74112       add_51[0][0]
# __________________________________________________________________________________________________
# time_distributed_193 (TimeDistr (None, 4, None, None 74112       time_distributed_195[0][0]
# __________________________________________________________________________________________________
# conv3d_70 (Conv3D)              (None, 4, None, None 74112       add_36[0][0]
# __________________________________________________________________________________________________
# conv3d_69 (Conv3D)              (None, 4, None, None 74112       activation_110[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 4, None, None 0           time_distributed_196[0][0]
#                                                                  time_distributed_193[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 4, None, None 0           conv3d_70[0][0]
#                                                                  conv3d_69[0][0]
# __________________________________________________________________________________________________
# time_distributed_198 (TimeDistr (None, 4, None, None 1536        add_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 4, None, None 1536        add_37[0][0]
# __________________________________________________________________________________________________
# time_distributed_199 (TimeDistr (None, 4, None, None 0           time_distributed_198[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 4, None, None 0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# time_distributed_197 (TimeDistr (None, 4, None, None 73920       time_distributed_199[0][0]
# __________________________________________________________________________________________________
# conv3d_71 (Conv3D)              (None, 4, None, None 73920       activation_111[0][0]
# __________________________________________________________________________________________________
# time_distributed_201 (TimeDistr (None, 4, None, None 768         time_distributed_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 4, None, None 768         conv3d_71[0][0]
# __________________________________________________________________________________________________
# time_distributed_202 (TimeDistr (None, 4, None, None 0           time_distributed_201[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 4, None, None 0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# time_distributed_200 (TimeDistr (None, 4, None, None 331968      time_distributed_202[0][0]
# __________________________________________________________________________________________________
# conv3d_72 (Conv3D)              (None, 4, None, None 995520      activation_112[0][0]
# __________________________________________________________________________________________________
# time_distributed_204 (TimeDistr (None, 4, None, None 768         time_distributed_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 4, None, None 768         conv3d_72[0][0]
# __________________________________________________________________________________________________
# time_distributed_205 (TimeDistr (None, 4, None, None 0           time_distributed_204[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 4, None, None 0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# time_distributed_203 (TimeDistr (None, 4, None, None 74112       time_distributed_205[0][0]
# __________________________________________________________________________________________________
# conv3d_73 (Conv3D)              (None, 4, None, None 74112       activation_113[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 4, None, None 0           add_52[0][0]
#                                                                  time_distributed_203[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 4, None, None 0           add_37[0][0]
#                                                                  conv3d_73[0][0]
# __________________________________________________________________________________________________
# time_distributed_207 (TimeDistr (None, 4, None, None 1536        add_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 4, None, None 1536        add_38[0][0]
# __________________________________________________________________________________________________
# time_distributed_208 (TimeDistr (None, 4, None, None 0           time_distributed_207[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 4, None, None 0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# time_distributed_206 (TimeDistr (None, 4, None, None 73920       time_distributed_208[0][0]
# __________________________________________________________________________________________________
# conv3d_74 (Conv3D)              (None, 4, None, None 73920       activation_114[0][0]
# __________________________________________________________________________________________________
# time_distributed_210 (TimeDistr (None, 4, None, None 768         time_distributed_206[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 4, None, None 768         conv3d_74[0][0]
# __________________________________________________________________________________________________
# time_distributed_211 (TimeDistr (None, 4, None, None 0           time_distributed_210[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 4, None, None 0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# time_distributed_209 (TimeDistr (None, 4, None, None 331968      time_distributed_211[0][0]
# __________________________________________________________________________________________________
# conv3d_75 (Conv3D)              (None, 4, None, None 995520      activation_115[0][0]
# __________________________________________________________________________________________________
# time_distributed_213 (TimeDistr (None, 4, None, None 768         time_distributed_209[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 4, None, None 768         conv3d_75[0][0]
# __________________________________________________________________________________________________
# time_distributed_214 (TimeDistr (None, 4, None, None 0           time_distributed_213[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 4, None, None 0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# time_distributed_212 (TimeDistr (None, 4, None, None 74112       time_distributed_214[0][0]
# __________________________________________________________________________________________________
# conv3d_76 (Conv3D)              (None, 4, None, None 74112       activation_116[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 4, None, None 0           add_53[0][0]
#                                                                  time_distributed_212[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 4, None, None 0           add_38[0][0]
#                                                                  conv3d_76[0][0]
# __________________________________________________________________________________________________
# time_distributed_216 (TimeDistr (None, 4, None, None 1536        add_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 4, None, None 1536        add_39[0][0]
# __________________________________________________________________________________________________
# time_distributed_217 (TimeDistr (None, 4, None, None 0           time_distributed_216[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 4, None, None 0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# time_distributed_215 (TimeDistr (None, 4, None, None 73920       time_distributed_217[0][0]
# __________________________________________________________________________________________________
# conv3d_77 (Conv3D)              (None, 4, None, None 73920       activation_117[0][0]
# __________________________________________________________________________________________________
# time_distributed_219 (TimeDistr (None, 4, None, None 768         time_distributed_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 4, None, None 768         conv3d_77[0][0]
# __________________________________________________________________________________________________
# time_distributed_220 (TimeDistr (None, 4, None, None 0           time_distributed_219[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 4, None, None 0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# time_distributed_218 (TimeDistr (None, 4, None, None 331968      time_distributed_220[0][0]
# __________________________________________________________________________________________________
# conv3d_78 (Conv3D)              (None, 4, None, None 995520      activation_118[0][0]
# __________________________________________________________________________________________________
# time_distributed_222 (TimeDistr (None, 4, None, None 768         time_distributed_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 4, None, None 768         conv3d_78[0][0]
# __________________________________________________________________________________________________
# time_distributed_223 (TimeDistr (None, 4, None, None 0           time_distributed_222[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 4, None, None 0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# time_distributed_221 (TimeDistr (None, 4, None, None 74112       time_distributed_223[0][0]
# __________________________________________________________________________________________________
# conv3d_79 (Conv3D)              (None, 4, None, None 74112       activation_119[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 4, None, None 0           add_54[0][0]
#                                                                  time_distributed_221[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 4, None, None 0           add_39[0][0]
#                                                                  conv3d_79[0][0]
# __________________________________________________________________________________________________
# time_distributed_225 (TimeDistr (None, 4, None, None 1536        add_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 4, None, None 1536        add_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_226 (TimeDistr (None, 4, None, None 0           time_distributed_225[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 4, None, None 0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# time_distributed_224 (TimeDistr (None, 4, None, None 73920       time_distributed_226[0][0]
# __________________________________________________________________________________________________
# conv3d_80 (Conv3D)              (None, 4, None, None 73920       activation_120[0][0]
# __________________________________________________________________________________________________
# time_distributed_228 (TimeDistr (None, 4, None, None 768         time_distributed_224[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 4, None, None 768         conv3d_80[0][0]
# __________________________________________________________________________________________________
# time_distributed_229 (TimeDistr (None, 4, None, None 0           time_distributed_228[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 4, None, None 0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# time_distributed_227 (TimeDistr (None, 4, None, None 331968      time_distributed_229[0][0]
# __________________________________________________________________________________________________
# conv3d_81 (Conv3D)              (None, 4, None, None 995520      activation_121[0][0]
# __________________________________________________________________________________________________
# time_distributed_231 (TimeDistr (None, 4, None, None 768         time_distributed_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 4, None, None 768         conv3d_81[0][0]
# __________________________________________________________________________________________________
# time_distributed_232 (TimeDistr (None, 4, None, None 0           time_distributed_231[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 4, None, None 0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# time_distributed_230 (TimeDistr (None, 4, None, None 74112       time_distributed_232[0][0]
# __________________________________________________________________________________________________
# conv3d_82 (Conv3D)              (None, 4, None, None 74112       activation_122[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 4, None, None 0           add_55[0][0]
#                                                                  time_distributed_230[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 4, None, None 0           add_40[0][0]
#                                                                  conv3d_82[0][0]
# __________________________________________________________________________________________________
# time_distributed_234 (TimeDistr (None, 4, None, None 1536        add_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 4, None, None 1536        add_41[0][0]
# __________________________________________________________________________________________________
# time_distributed_235 (TimeDistr (None, 4, None, None 0           time_distributed_234[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 4, None, None 0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# time_distributed_233 (TimeDistr (None, 4, None, None 147840      time_distributed_235[0][0]
# __________________________________________________________________________________________________
# conv3d_83 (Conv3D)              (None, 4, None, None 147840      activation_123[0][0]
# __________________________________________________________________________________________________
# time_distributed_237 (TimeDistr (None, 4, None, None 1536        time_distributed_233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 4, None, None 1536        conv3d_83[0][0]
# __________________________________________________________________________________________________
# time_distributed_238 (TimeDistr (None, 4, None, None 0           time_distributed_237[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 4, None, None 0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# time_distributed_236 (TimeDistr (None, 4, None, None 1327488     time_distributed_238[0][0]
# __________________________________________________________________________________________________
# conv3d_84 (Conv3D)              (None, 4, None, None 3981696     activation_124[0][0]
# __________________________________________________________________________________________________
# time_distributed_240 (TimeDistr (None, 4, None, None 1536        time_distributed_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 4, None, None 1536        conv3d_84[0][0]
# __________________________________________________________________________________________________
# time_distributed_241 (TimeDistr (None, 4, None, None 0           time_distributed_240[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 4, None, None 0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# time_distributed_242 (TimeDistr (None, 4, None, None 295680      add_56[0][0]
# __________________________________________________________________________________________________
# time_distributed_239 (TimeDistr (None, 4, None, None 295680      time_distributed_241[0][0]
# __________________________________________________________________________________________________
# conv3d_86 (Conv3D)              (None, 4, None, None 295680      add_41[0][0]
# __________________________________________________________________________________________________
# conv3d_85 (Conv3D)              (None, 4, None, None 295680      activation_125[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 4, None, None 0           time_distributed_242[0][0]
#                                                                  time_distributed_239[0][0]
# ...
# __________________________________________________________________________________________________
# time_distributed_255 (TimeDistr (None, 4, None, None 1327488     time_distributed_257[0][0]
# __________________________________________________________________________________________________
# conv3d_91 (Conv3D)              (None, 4, None, None 3981696     activation_130[0][0]
# __________________________________________________________________________________________________
# time_distributed_259 (TimeDistr (None, 4, None, None 1536        time_distributed_255[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 4, None, None 1536        conv3d_91[0][0]
# __________________________________________________________________________________________________
# time_distributed_260 (TimeDistr (None, 4, None, None 0           time_distributed_259[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 4, None, None 0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# time_distributed_258 (TimeDistr (None, 4, None, None 295680      time_distributed_260[0][0]
# __________________________________________________________________________________________________
# conv3d_92 (Conv3D)              (None, 4, None, None 295680      activation_131[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 4, None, None 0           add_58[0][0]
#                                                                  time_distributed_258[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 4, None, None 0           add_43[0][0]
#                                                                  conv3d_92[0][0]
# __________________________________________________________________________________________________
# time_distributed_262 (TimeDistr (None, 4, None, None 3072        add_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 4, None, None 3072        add_44[0][0]
# __________________________________________________________________________________________________
# time_distributed_263 (TimeDistr (None, 4, None, None 0           time_distributed_262[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 4, None, None 0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# time_distributed_261 (TimeDistr (None, 4, None, None 295296      time_distributed_263[0][0]
# __________________________________________________________________________________________________
# conv3d_93 (Conv3D)              (None, 4, None, None 295296      activation_132[0][0]
# __________________________________________________________________________________________________
# time_distributed_265 (TimeDistr (None, 4, None, None 1536        time_distributed_261[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 4, None, None 1536        conv3d_93[0][0]
# __________________________________________________________________________________________________
# time_distributed_266 (TimeDistr (None, 4, None, None 0           time_distributed_265[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 4, None, None 0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# time_distributed_264 (TimeDistr (None, 4, None, None 1327488     time_distributed_266[0][0]
# __________________________________________________________________________________________________
# conv3d_94 (Conv3D)              (None, 4, None, None 3981696     activation_133[0][0]
# __________________________________________________________________________________________________
# time_distributed_268 (TimeDistr (None, 4, None, None 1536        time_distributed_264[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 4, None, None 1536        conv3d_94[0][0]
# __________________________________________________________________________________________________
# time_distributed_269 (TimeDistr (None, 4, None, None 0           time_distributed_268[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 4, None, None 0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# time_distributed_267 (TimeDistr (None, 4, None, None 295680      time_distributed_269[0][0]
# __________________________________________________________________________________________________
# conv3d_95 (Conv3D)              (None, 4, None, None 295680      activation_134[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 4, None, None 0           add_59[0][0]
#                                                                  time_distributed_267[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 4, None, None 0           add_44[0][0]
#                                                                  conv3d_95[0][0]
# __________________________________________________________________________________________________
# time_distributed_271 (TimeDistr (None, 4, None, None 3072        add_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 4, None, None 3072        add_45[0][0]
# __________________________________________________________________________________________________
# time_distributed_272 (TimeDistr (None, 4, None, None 0           time_distributed_271[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 4, None, None 0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# time_distributed_270 (TimeDistr (None, 4, None, None 295296      time_distributed_272[0][0]
# __________________________________________________________________________________________________
# conv3d_96 (Conv3D)              (None, 4, None, None 295296      activation_135[0][0]
# __________________________________________________________________________________________________
# time_distributed_274 (TimeDistr (None, 4, None, None 1536        time_distributed_270[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 4, None, None 1536        conv3d_96[0][0]
# __________________________________________________________________________________________________
# time_distributed_275 (TimeDistr (None, 4, None, None 0           time_distributed_274[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 4, None, None 0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# time_distributed_273 (TimeDistr (None, 4, None, None 1327488     time_distributed_275[0][0]
# __________________________________________________________________________________________________
# conv3d_97 (Conv3D)              (None, 4, None, None 3981696     activation_136[0][0]
# __________________________________________________________________________________________________
# time_distributed_277 (TimeDistr (None, 4, None, None 1536        time_distributed_273[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 4, None, None 1536        conv3d_97[0][0]
# __________________________________________________________________________________________________
# time_distributed_278 (TimeDistr (None, 4, None, None 0           time_distributed_277[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 4, None, None 0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# time_distributed_276 (TimeDistr (None, 4, None, None 295680      time_distributed_278[0][0]
# __________________________________________________________________________________________________
# conv3d_98 (Conv3D)              (None, 4, None, None 295680      activation_137[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 4, None, None 0           add_60[0][0]
#                                                                  time_distributed_276[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 4, None, None 0           add_45[0][0]
#                                                                  conv3d_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 4, None, None 3072        add_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 4, None, None 3072        add_46[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 4, None, None 0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 4, None, None 0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 4, None, None 0           activation_184[0][0]
#                                                                  activation_138[0][0]
# __________________________________________________________________________________________________
# newlstmdeep (ConvLSTM2D)        (None, None, None, 1 451648      add_62[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, None, None, 2 0           newlstmdeep[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, None, None, 1 0           newlstmdeep[0][0]
# __________________________________________________________________________________________________
# yolo (Conv2D)                   (None, None, None, 2 4098        lambda_4[0][0]
# __________________________________________________________________________________________________
# secyolo (Conv2D)                (None, None, None, 5 71685       lambda_5[0][0]
# __________________________________________________________________________________________________
# Concat (Concat)                 [(None, None, None,  0           yolo[0][0]
#                                                                  secyolo[0][0]
# ==================================================================================================
# Total params: 42,184,615
# Trainable params: 42,132,583
# Non-trainable params: 52,032
# __________________________________________________________________________________________________
# Train on 12787 samples, validate on 674 samples
# Epoch 1/100
#    92/12787 [..............................] - ETA: 2:17:53 - loss: 6.7735 - accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1d9694372ae4> in <module>
#       3 Train.loadData()
#       4
# ----> 5 Train.TrainModel()
#
# ~/anaconda3/bin/Yoloneat/NEAT/NEATModels/neat_standard.py in TrainModel(self)
#     247
#     248         #Train the model and save as a h5 file
# --> 249         self.Trainingmodel.fit(self.X,self.Y, class_weight = d_class_weights , batch_size = self.batch_size, epochs = self.epochs, validation_data=(self.X_val, self.Y_val), shuffle = True, callbacks = [lrate,hrate,srate,prate])
#     250
#     251
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
