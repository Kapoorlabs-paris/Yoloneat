# %%
import sys
import os
from glob import glob
sys.path.append("../NEAT")
from NEATModels import NEATStaticDetection, nets
from NEATModels.Staticconfig  import StaticNeatConfig
from NEATUtils import helpers
from NEATUtils.helpers import save_json, load_json
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
# Out:
# Using TensorFlow backend.

# %%
NpzDirectory = '/data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2OVoloneatV0/'
TrainModelName = 'Yolov0oneat.npz'
ValidationModelName = 'Yolov0oneatVal.npz'


ModelDir = '/data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/'
#Model name based on wether it is residual or sequntial ONEAT network
Model_Name = 'ResidualBin2NeatModel.h5'
StaticCategoriesJson = ModelDir + 'StaticCategories.json'
KeyCategories = load_json(StaticCategoriesJson)

StaticCordJson = ModelDir + 'StaticCord.json'
KeyCord = load_json(StaticCordJson)

#Neural network parameters
#For ORNET use residual = True and for OSNET use residual = False
#Neural network parameters
#For ORNET use residual = True and for OSNET use residual = False
residual = True
#NUmber of starting convolutional filters, is doubled down with increasing depth
startfilter = 32
#CNN network start layer, mid layers and lstm layer kernel size
start_kernel = 3
mid_kernel = 3
#Network depth has to be 9n + 2, n= 3 or 4 is optimal for Notum dataset
depth = 29


#Size of the gradient descent length vector, start small and use callbacks to get smaller when reaching the minima
learning_rate = 1.0E-4
#For stochastic gradient decent, the batch size used for computing the gradients
batch_size = 100
# use softmax for single event per box, sigmoid for multi event per box
multievent = False
# Trainng image size
yoloV0 = True
ImageX = 54
ImageY = 54
#Training epochs, longer the better with proper chosen learning rate
epochs = 250

# %%
config = StaticNeatConfig(residual = residual, depth = depth, start_kernel = start_kernel, mid_kernel = mid_kernel,
                         startfiler = startfilter, gridX = 1, gridY = 1, ImageX = ImageX, ImageY = ImageY, nboxes = 1, 
                         epochs = epochs, categories = len(KeyCategories), box_vector = len(KeyCord), learning_rate = learning_rate,
                         batch_size = batch_size, ModelName = Model_Name, multievent = multievent)

config_json = config.to_json()
show = True
print(config)
save_json(config_json, ModelDir + Model_Name + '_Parameter.json')
# Out:
# StaticNeatConfig(ImageX=54, ImageY=54, ModelName='ResidualBin2NeatModel.h5', batch_size=100, box_vector=4, categories=4, depth=29, epochs=250, gridX=1, gridY=1, learning_rate=1e-06, mid_kernel=3, multievent=False, nboxes=1, residual=True, start_kernel=3, startfilter=32)

# %%
Train = NEATStaticDetection(config, NpzDirectory,KeyCategories, KeyCord,TrainModelName,ValidationModelName, ModelDir, Model_Name, show = show, yoloV0 = yoloV0)

Train.loadData()

Train.TrainModel()
# Out:
# number of  images:	 18887
# image size (2D):		 (54, 54)
# axes:				 SXYC
# channels in / out:		 1
# number of  images:	 995
# image size (2D):		 (54, 54)
# axes:				 SXYC
# channels in / out:		 1
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 1 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 320         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 3 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 3 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 3 9248        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 3 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 3 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 4224        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 1 4224        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 1 0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 1 512         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 1 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 3 4128        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 3 128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 3 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 3 9248        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 3 128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 3 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 1 4224        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 1 0           add_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 1 512         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 1 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 3 4128        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 3 128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 3 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 3 9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 3 128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 3 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 1 4224        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 1 0           add_2[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 1 512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 1 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 1 16512       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 1 512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 1 512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 2 33024       add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 33024       activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 2 0           conv2d_15[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 2 1024        add_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 2 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 1 32896       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 1 512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 1 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 33024       activation_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 2 0           add_4[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 2 1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 2 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 1 32896       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 1 512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 1 512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 2 33024       activation_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 2 0           add_5[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 2 1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 2 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 2 65792       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 2 1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 2 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 2 590080      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 2 1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 2 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 5 131584      add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 5 131584      activation_21[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           conv2d_25[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 5 2048        add_7[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 2 1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 2 1024        conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 5 131584      activation_24[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 5 0           add_7[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 5 2048        add_8[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 5 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 2 131328      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 2 1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 2 1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 5 131584      activation_27[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 5 0           add_8[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 5 2048        add_9[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 5 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None, 4 0           activation_28[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None, None, 5 0           activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 4 3140        lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 4 398276      lambda_2[0][0]
# __________________________________________________________________________________________________
# Concat (Concat)                 [(None, None, None,  0           conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# ==================================================================================================
# Total params: 3,758,728
# Trainable params: 3,748,296
# Non-trainable params: 10,432
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 18887 samples, validate on 995 samples
# Epoch 1/250
# 18887/18887 [==============================] - 33s 2ms/step - loss: 3.1037 - acc: 0.0138 - val_loss: 2.9339 - val_acc: 0.0131
#
# Epoch 00001: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.933936703744246, 'val_acc': 0.013065326406653203, 'loss': 3.1037051049814828, 'acc': 0.013766082193754334, 'lr': 1e-06}
# Prediction : [[[0.20762548 0.42747566 0.19055572 0.1743431  0.75041676 0.32816324
#    0.47382727 0.49564525]]]
# True Label :  [0.         0.         0.         1.         0.87037037 0.87037037
#  0.2962963  0.33333333]
# Epoch 2/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.8094 - acc: 0.0183 - val_loss: 2.7140 - val_acc: 0.0251
#
# Epoch 00002: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.713993446311759, 'val_acc': 0.025125627897342843, 'loss': 2.8093609370201684, 'acc': 0.018319478647548387, 'lr': 1e-06}
# Prediction : [[[0.11856999 0.55743474 0.12383093 0.20016441 0.6935647  0.32380933
#    0.48300076 0.47044477]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.12962963
#  0.35185185 0.31481481]
# Epoch 3/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.6521 - acc: 0.0376 - val_loss: 2.6127 - val_acc: 0.0472
#
# Epoch 00003: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.612658395240055, 'val_acc': 0.0472361798861518, 'loss': 2.652092939171221, 'acc': 0.03764494067059841, 'lr': 1e-06}
# Prediction : [[[0.07602738 0.62484676 0.09812626 0.20099956 0.663076   0.29997718
#    0.45818818 0.44716838]]]
# True Label :  [0.         0.         0.         1.         0.87037037 0.87037037
#  0.35185185 0.35185185]
# Epoch 4/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.5709 - acc: 0.0534 - val_loss: 2.5486 - val_acc: 0.0653
#
# Epoch 00004: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.5485800079364873, 'val_acc': 0.0653266326416677, 'loss': 2.570876963616882, 'acc': 0.05342298903546755, 'lr': 1e-06}
# Prediction : [[[0.05889095 0.64799416 0.09341021 0.19970462 0.64389384 0.28575486
#    0.44162834 0.42292494]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.12962963
#  0.33333333 0.33333333]
# Epoch 5/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.5166 - acc: 0.0656 - val_loss: 2.4986 - val_acc: 0.0784
#
# Epoch 00005: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.4985526075315234, 'val_acc': 0.07839196036808455, 'loss': 2.5166000043909715, 'acc': 0.06560067777222743, 'lr': 1e-06}
# Prediction : [[[0.04938854 0.65621716 0.09654205 0.1978522  0.63830495 0.28587815
#    0.440661   0.4080867 ]]]
# True Label :  [0.         0.         1.         0.         0.5        0.5
#  0.35185185 0.40740741]
# Epoch 6/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.4722 - acc: 0.0759 - val_loss: 2.4563 - val_acc: 0.0884
#
# Epoch 00006: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.4562953476929783, 'val_acc': 0.08844221154948574, 'loss': 2.4722366585854965, 'acc': 0.0759252396178907, 'lr': 1e-06}
# Prediction : [[[0.04276197 0.6587182  0.10305557 0.19546424 0.6312176  0.27863944
#    0.44111323 0.40558314]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.12962963
#  0.27777778 0.27777778]
# Epoch 7/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.4344 - acc: 0.0872 - val_loss: 2.4207 - val_acc: 0.0995
#
# Epoch 00007: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.4207183895398625, 'val_acc': 0.0994974864487672, 'loss': 2.4343670406847497, 'acc': 0.08720283783420384, 'lr': 1e-06}
# Prediction : [[[0.03792329 0.6578787  0.10945413 0.19474384 0.64249337 0.27912349
#    0.43829423 0.3923003 ]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.5
#  0.48148148 0.7962963 ]
# Epoch 8/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.4032 - acc: 0.0982 - val_loss: 2.3904 - val_acc: 0.1085
#
# Epoch 00008: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.390401418484635, 'val_acc': 0.10854271368764752, 'loss': 2.403178764423446, 'acc': 0.09821570380893374, 'lr': 1e-06}
# Prediction : [[[0.03432396 0.65586096 0.11342756 0.1963875  0.6344762  0.28467125
#    0.4379044  0.3763943 ]]]
# True Label :  [0.         0.         0.         1.         0.87037037 0.5
#  0.33333333 0.31481481]
# Epoch 9/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.3754 - acc: 0.1126 - val_loss: 2.3622 - val_acc: 0.1216
#
# Epoch 00009: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.3621549043224084, 'val_acc': 0.12160804006622065, 'loss': 2.3753725357770654, 'acc': 0.11256419759110195, 'lr': 1e-06}
# Prediction : [[[0.03174441 0.64982086 0.11930431 0.19913036 0.6354018  0.2785926
#    0.4387917  0.366924  ]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.87037037
#  0.57407407 0.51851852]
# Epoch 10/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.3517 - acc: 0.1258 - val_loss: 2.3388 - val_acc: 0.1347
#
# Epoch 00010: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.3388117641659836, 'val_acc': 0.13467336711871564, 'loss': 2.3517157276709195, 'acc': 0.1258008155705293, 'lr': 1e-06}
# Prediction : [[[0.02994697 0.64292413 0.12353403 0.20359486 0.6366894  0.286471
#    0.43809956 0.36674753]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.5
#  0.27777778 0.37037037]
# Epoch 11/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.3297 - acc: 0.1410 - val_loss: 2.3183 - val_acc: 0.1538
#
# Epoch 00011: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.318307134973344, 'val_acc': 0.15376884434091387, 'loss': 2.32968580011479, 'acc': 0.14099645247440223, 'lr': 1e-06}
# Prediction : [[[0.02887121 0.6330326  0.12948881 0.20860729 0.62720895 0.28083217
#    0.4352721  0.353885  ]]]
# True Label :  [0.         0.         0.         1.         0.87037037 0.87037037
#  0.24074074 0.31481481]
# Epoch 12/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.3123 - acc: 0.1516 - val_loss: 2.3005 - val_acc: 0.1698
#
# Epoch 00012: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.300451737552432, 'val_acc': 0.1698492467403412, 'loss': 2.312346745125605, 'acc': 0.15163869366689617, 'lr': 1e-06}
# Prediction : [[[0.02789003 0.62696755 0.13335456 0.21178788 0.6227113  0.28401816
#    0.4313449  0.34415424]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.87037037
#  0.68518519 0.68518519]
# Epoch 13/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.2953 - acc: 0.1643 - val_loss: 2.2841 - val_acc: 0.1739
#
# Epoch 00013: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.2840616655110115, 'val_acc': 0.17386934872548185, 'loss': 2.2953386015792807, 'acc': 0.16434584629135196, 'lr': 1e-06}
# Prediction : [[[0.02723475 0.61790115 0.13740747 0.21745665 0.61798805 0.2969091
#    0.43055037 0.339051  ]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.87037037
#  0.51851852 0.37037037]
# Epoch 14/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.2801 - acc: 0.1756 - val_loss: 2.2688 - val_acc: 0.1849
#
# Epoch 00014: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.268841025817334, 'val_acc': 0.18492462504748722, 'loss': 2.2801310435784035, 'acc': 0.1755704983580502, 'lr': 1e-06}
# Prediction : [[[0.02663583 0.60950124 0.14129351 0.22256938 0.62244034 0.2979166
#    0.4327928  0.33899188]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.5
#  0.25925926 0.31481481]
# Epoch 15/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.2657 - acc: 0.1855 - val_loss: 2.2553 - val_acc: 0.2000
#
# Epoch 00015: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.2553422055651793, 'val_acc': 0.200000000359425, 'loss': 2.2656659845160396, 'acc': 0.18552443426544812, 'lr': 1e-06}
# Prediction : [[[0.02588849 0.6035123  0.14359076 0.2270084  0.6178299  0.29194736
#    0.43172905 0.339476  ]]]
# True Label :  [0.         1.         0.         0.         0.87037037 0.5
#  0.44444444 0.46296296]
# Epoch 16/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.2516 - acc: 0.1955 - val_loss: 2.2432 - val_acc: 0.2050
#
# Epoch 00016: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.2431587310292613, 'val_acc': 0.20502512419044072, 'loss': 2.2516249294990947, 'acc': 0.1955313173201058, 'lr': 1e-06}
# Prediction : [[[0.02568527 0.592869   0.14739932 0.23404644 0.6162191  0.29962212
#    0.42634842 0.33570328]]]
# True Label :  [0.         1.         0.         0.         0.5        0.87037037
#  0.33333333 0.40740741]
# Epoch 17/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.2398 - acc: 0.2049 - val_loss: 2.2313 - val_acc: 0.2101
#
# Epoch 00017: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.2312758052768418, 'val_acc': 0.21005025116642514, 'loss': 2.239758971723725, 'acc': 0.20490284285626392, 'lr': 1e-06}
# Prediction : [[[0.02526254 0.5827454  0.1500756  0.24191645 0.6172739  0.30824262
#    0.4306696  0.33682245]]]
# True Label :  [0.         0.         1.         0.         0.5        0.5
#  0.38888889 0.33333333]
# Epoch 18/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.2274 - acc: 0.2132 - val_loss: 2.2204 - val_acc: 0.2211
#
# Epoch 00018: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.220360287469835, 'val_acc': 0.2211055268893889, 'loss': 2.227442060663366, 'acc': 0.21321543899768178, 'lr': 1e-06}
# Prediction : [[[0.02491091 0.5751026  0.15303615 0.24695025 0.61896    0.306427
#    0.43144318 0.33664453]]]
# True Label :  [0.         0.         0.         1.         0.87037037 0.5
#  0.42592593 0.33333333]
# Epoch 19/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.2169 - acc: 0.2200 - val_loss: 2.2096 - val_acc: 0.2271
#
# Epoch 00019: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.2096027812766073, 'val_acc': 0.22713567863157647, 'loss': 2.2169463021245104, 'acc': 0.22004553353438694, 'lr': 1e-06}
# Prediction : [[[0.02439828 0.568709   0.15352386 0.25336888 0.6173332  0.30187324
#    0.43037647 0.3465628 ]]]
# True Label :  [0.         1.         0.         0.         0.87037037 0.5
#  0.31481481 0.35185185]
# Epoch 20/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.2064 - acc: 0.2284 - val_loss: 2.1997 - val_acc: 0.2332
#
# Epoch 00020: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.1997268223882323, 'val_acc': 0.2331658267795141, 'loss': 2.2064091318551307, 'acc': 0.2283581292710663, 'lr': 1e-06}
# Prediction : [[[0.02437515 0.55912554 0.15686706 0.25963226 0.61836743 0.3160547
#    0.42717004 0.33923462]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.5
#  0.18518519 0.18518519]
# Epoch 21/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.1970 - acc: 0.2332 - val_loss: 2.1903 - val_acc: 0.2372
#
# Epoch 00021: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.190330438278428, 'val_acc': 0.23718592868977456, 'loss': 2.1970142101152117, 'acc': 0.23322920445136813, 'lr': 1e-06}
# Prediction : [[[0.02415925 0.55154896 0.1572537  0.2670381  0.62059265 0.3187943
#    0.43131715 0.3421893 ]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.87037037
#  0.37037037 0.31481481]
# Epoch 22/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.1854 - acc: 0.2417 - val_loss: 2.1808 - val_acc: 0.2492
#
# Epoch 00022: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.1808389071843135, 'val_acc': 0.24924623367175386, 'loss': 2.185361193570426, 'acc': 0.24170063979627468, 'lr': 1e-06}
# Prediction : [[[0.02384429 0.5427287  0.15690602 0.27652097 0.6107414  0.31663692
#    0.42852232 0.34050098]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.12962963
#  0.5        0.48148148]
# Epoch 23/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.1756 - acc: 0.2453 - val_loss: 2.1721 - val_acc: 0.2563
#
# Epoch 00023: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.1721259145880465, 'val_acc': 0.2562814058370926, 'loss': 2.175617513380416, 'acc': 0.24530100041216676, 'lr': 1e-06}
# Prediction : [[[0.02352299 0.53535175 0.1569824  0.28414276 0.6103225  0.30940038
#    0.42860937 0.33699566]]]
# True Label :  [0.         0.         0.         1.         0.87037037 0.5
#  0.24074074 0.31481481]
# Epoch 24/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.1663 - acc: 0.2512 - val_loss: 2.1629 - val_acc: 0.2583
#
# Epoch 00024: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.1628500696402697, 'val_acc': 0.2582914535723739, 'loss': 2.1663132788499135, 'acc': 0.25123100517734914, 'lr': 1e-06}
# Prediction : [[[0.0232593  0.52431816 0.15760514 0.29481742 0.6069502  0.3180609
#    0.42661625 0.3350278 ]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.12962963
#  0.46296296 0.42592593]
# Epoch 25/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.1565 - acc: 0.2583 - val_loss: 2.1541 - val_acc: 0.2673
#
# Epoch 00025: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.154104340615584, 'val_acc': 0.2673366838064625, 'loss': 2.156506305552087, 'acc': 0.2583258331023966, 'lr': 1e-06}
# Prediction : [[[0.02299742 0.51668084 0.15762952 0.30269223 0.6103584  0.3182996
#    0.42037135 0.3298006 ]]]
# True Label :  [0.         1.         0.         0.         0.5        0.5
#  0.33333333 0.35185185]
# Epoch 26/250
# 18887/18887 [==============================] - 25s 1ms/step - loss: 2.1468 - acc: 0.2614 - val_loss: 2.1455 - val_acc: 0.2693
#
# Epoch 00026: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.1455074758385893, 'val_acc': 0.2693467351359938, 'loss': 2.146764024087774, 'acc': 0.2613967278907277, 'lr': 1e-06}
# Prediction : [[[0.02265918 0.5088035  0.15668207 0.3118553  0.6107721  0.33052388
#    0.41704103 0.3313753 ]]]
# True Label :  [0.         0.         0.         1.         0.5        0.12962963
#  0.37037037 0.40740741]
# Epoch 27/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.1363 - acc: 0.2686 - val_loss: 2.1370 - val_acc: 0.2734
#
# Epoch 00027: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.1370272181141914, 'val_acc': 0.2733668342008064, 'loss': 2.136251722957797, 'acc': 0.2685974483083011, 'lr': 1e-06}
# Prediction : [[[0.02240974 0.49968615 0.15680909 0.32109502 0.6093902  0.3250723
#    0.41305694 0.32360142]]]
# True Label :  [0.         0.         0.         1.         0.87037037 0.5
#  0.35185185 0.31481481]
# Epoch 28/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.1269 - acc: 0.2702 - val_loss: 2.1284 - val_acc: 0.2774
#
# Epoch 00028: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.128376559396485, 'val_acc': 0.2773869338646606, 'loss': 2.126941897475638, 'acc': 0.2701858426958785, 'lr': 1e-06}
# Prediction : [[[0.02198984 0.49279705 0.15575501 0.32945803 0.602043   0.32580638
#    0.4129162  0.3275801 ]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.87037037
#  0.94444444 0.94444444]
# Epoch 29/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.1169 - acc: 0.2761 - val_loss: 2.1201 - val_acc: 0.2864
#
# Epoch 00029: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.120121042932098, 'val_acc': 0.28643215885713474, 'loss': 2.1168802774444164, 'acc': 0.27611584745553813, 'lr': 1e-06}
# Prediction : [[[0.02155018 0.48611948 0.1543549  0.3379754  0.60051066 0.3227064
#    0.40924433 0.31567955]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.12962963
#  0.33333333 0.40740741]
# Epoch 30/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.1083 - acc: 0.2799 - val_loss: 2.1116 - val_acc: 0.2894
#
# Epoch 00030: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.111551891020195, 'val_acc': 0.28944723435382747, 'loss': 2.1082888458192572, 'acc': 0.2799279942683307, 'lr': 1e-06}
# Prediction : [[[0.02135207 0.4750014  0.15419622 0.3494503  0.5983801  0.324511
#    0.40597463 0.3232524 ]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.12962963
#  0.5        0.48148148]
# Epoch 31/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.0983 - acc: 0.2844 - val_loss: 2.1031 - val_acc: 0.2985
#
# Epoch 00031: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.103075721156058, 'val_acc': 0.2984924615927078, 'loss': 2.0983256963219974, 'acc': 0.2843754970059158, 'lr': 1e-06}
# Prediction : [[[0.02110647 0.4677476  0.15256882 0.35857713 0.5932432  0.3288441
#    0.3998979  0.31791896]]]
# True Label :  [0.         1.         0.         0.         0.5        0.87037037
#  0.48148148 0.7962963 ]
# Epoch 32/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.0895 - acc: 0.2872 - val_loss: 2.0948 - val_acc: 0.3075
#
# Epoch 00032: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.0947575844711994, 'val_acc': 0.30753769107799434, 'loss': 2.0894740317960636, 'acc': 0.28723460734884626, 'lr': 1e-06}
# Prediction : [[[0.02065422 0.46263188 0.15138394 0.36532995 0.5912958  0.32803202
#    0.39062944 0.31851834]]]
# True Label :  [0.         0.         1.         0.         0.5        0.12962963
#  0.44444444 0.42592593]
# Epoch 33/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.0797 - acc: 0.2918 - val_loss: 2.0861 - val_acc: 0.3106
#
# Epoch 00033: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.086123646204196, 'val_acc': 0.31055276597564546, 'loss': 2.079659313637261, 'acc': 0.29184094941457633, 'lr': 1e-06}
# Prediction : [[[0.02033328 0.4535659  0.14971328 0.3763875  0.5854667  0.32561138
#    0.3892627  0.31390807]]]
# True Label :  [0.         0.         1.         0.         0.12962963 0.5
#  0.31481481 0.33333333]
# Epoch 34/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.0701 - acc: 0.2980 - val_loss: 2.0780 - val_acc: 0.3156
#
# Epoch 00034: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.078004862195882, 'val_acc': 0.31557789804348396, 'loss': 2.0701358366929035, 'acc': 0.2980356869266733, 'lr': 1e-06}
# Prediction : [[[0.01996471 0.4488742  0.14795578 0.3832052  0.57396305 0.34654498
#    0.38491592 0.3042723 ]]]
# True Label :  [0.         0.         0.         1.         0.5        0.5
#  0.37037037 0.31481481]
# Epoch 35/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.0594 - acc: 0.3030 - val_loss: 2.0694 - val_acc: 0.3166
#
# Epoch 00035: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.0694372893577846, 'val_acc': 0.31658291921543713, 'loss': 2.0593633525120474, 'acc': 0.3030126556598686, 'lr': 1e-06}
# Prediction : [[[0.01977547 0.441797   0.14627723 0.3921504  0.5736025  0.34275013
#    0.38808507 0.31559348]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.12962963
#  0.27777778 0.35185185]
# Epoch 36/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.0491 - acc: 0.3073 - val_loss: 2.0599 - val_acc: 0.3186
#
# Epoch 00036: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.059879128058352, 'val_acc': 0.3185929699459268, 'loss': 2.049148892588819, 'acc': 0.30730132024802076, 'lr': 1e-06}
# Prediction : [[[0.01953517 0.43401036 0.14403637 0.40241817 0.5874624  0.3507498
#    0.38784927 0.30712187]]]
# True Label :  [0.         1.         0.         0.         0.87037037 0.87037037
#  0.51851852 0.48148148]
# Epoch 37/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.0399 - acc: 0.3099 - val_loss: 2.0505 - val_acc: 0.3216
#
# Epoch 00037: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.0505029040964406, 'val_acc': 0.3216080416986092, 'loss': 2.039917450102148, 'acc': 0.3099486431395982, 'lr': 1e-06}
# Prediction : [[[0.01930482 0.42780283 0.14138989 0.41150245 0.5777846  0.35352302
#    0.39193478 0.3124926 ]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.5
#  0.27777778 0.35185185]
# Epoch 38/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.0307 - acc: 0.3168 - val_loss: 2.0415 - val_acc: 0.3286
#
# Epoch 00038: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.0414604242123553, 'val_acc': 0.3286432138639479, 'loss': 2.03074810085437, 'acc': 0.31683168515019416, 'lr': 1e-06}
# Prediction : [[[0.01918542 0.42122203 0.13954265 0.42004988 0.5714021  0.36707562
#    0.3868191  0.30374706]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.87037037
#  0.40740741 0.42592593]
# Epoch 39/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.0201 - acc: 0.3215 - val_loss: 2.0320 - val_acc: 0.3367
#
# Epoch 00039: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.0319849827780794, 'val_acc': 0.3366834125926147, 'loss': 2.020109830099827, 'acc': 0.32154392062996, 'lr': 1e-06}
# Prediction : [[[0.01885721 0.41561368 0.13768093 0.42784813 0.56037146 0.36742324
#    0.377239   0.30364984]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.12962963
#  0.5        0.48148148]
# Epoch 40/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.0111 - acc: 0.3259 - val_loss: 2.0226 - val_acc: 0.3387
#
# Epoch 00040: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.0225759852471663, 'val_acc': 0.33869346616855217, 'loss': 2.011125226848152, 'acc': 0.3258855313483975, 'lr': 1e-06}
# Prediction : [[[0.01878578 0.41015035 0.13612287 0.43494105 0.56559503 0.37162125
#    0.3783434  0.30666003]]]
# True Label :  [0.         1.         0.         0.         0.5        0.87037037
#  0.46296296 0.38888889]
# Epoch 41/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 2.0014 - acc: 0.3323 - val_loss: 2.0124 - val_acc: 0.3417
#
# Epoch 00041: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.0123777413488035, 'val_acc': 0.3417085446604532, 'loss': 2.00142608123402, 'acc': 0.3322920547844134, 'lr': 1e-06}
# Prediction : [[[0.0185857  0.40293923 0.13421485 0.4442603  0.57641584 0.37381727
#    0.37445194 0.30286875]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.12962963
#  0.31481481 0.35185185]
# Epoch 42/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 1.9911 - acc: 0.3366 - val_loss: 2.0032 - val_acc: 0.3598
#
# Epoch 00042: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 2.003232119670465, 'val_acc': 0.3597989938965994, 'loss': 1.9911098762294983, 'acc': 0.3365807176778711, 'lr': 1e-06}
# Prediction : [[[0.01838    0.39835054 0.13277614 0.45049337 0.5599937  0.3788949
#    0.37456417 0.29511717]]]
# True Label :  [0.         0.         0.         1.         0.87037037 0.87037037
#  0.44444444 0.25925926]
# Epoch 43/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 1.9801 - acc: 0.3426 - val_loss: 1.9936 - val_acc: 0.3588
#
# Epoch 00043: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 1.993612181601213, 'val_acc': 0.3587939727246462, 'loss': 1.98010407943562, 'acc': 0.3425636692171334, 'lr': 1e-06}
# Prediction : [[[0.01815247 0.3927423  0.12989917 0.45920599 0.5675508  0.39195955
#    0.38063845 0.30676845]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.12962963
#  0.59259259 0.57407407]
# Epoch 44/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 1.9697 - acc: 0.3494 - val_loss: 1.9839 - val_acc: 0.3668
#
# Epoch 00044: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 1.983924185211335, 'val_acc': 0.3668341720523547, 'loss': 1.9697059125249405, 'acc': 0.3494467096703146, 'lr': 1e-06}
# Prediction : [[[0.01793409 0.38670933 0.12959847 0.46575812 0.5589985  0.39606693
#    0.37142172 0.30532703]]]
# True Label :  [0.         1.         0.         0.         0.87037037 0.87037037
#  0.94444444 0.98148148]
# Epoch 45/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 1.9599 - acc: 0.3562 - val_loss: 1.9749 - val_acc: 0.3688
#
# Epoch 00045: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 1.9748694207800093, 'val_acc': 0.36884422338188594, 'loss': 1.9599192891623576, 'acc': 0.3562238589090914, 'lr': 1e-06}
# Prediction : [[[0.01791517 0.3833597  0.12749885 0.47122633 0.5540112  0.40017816
#    0.36810803 0.3007486 ]]]
# True Label :  [0.         0.         0.         1.         0.12962963 0.87037037
#  0.33333333 0.2962963 ]
# Epoch 46/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 1.9509 - acc: 0.3613 - val_loss: 1.9649 - val_acc: 0.3779
#
# Epoch 00046: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 1.9649254431077583, 'val_acc': 0.37788944627771426, 'loss': 1.9508720149293044, 'acc': 0.36125377334968733, 'lr': 1e-06}
# Prediction : [[[0.0175952  0.37615234 0.1247056  0.48154685 0.5465893  0.40093276
#    0.36226177 0.2992398 ]]]
# True Label :  [0.         1.         0.         0.         0.5        0.87037037
#  0.51851852 0.51851852]
# Epoch 47/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 1.9402 - acc: 0.3654 - val_loss: 1.9555 - val_acc: 0.3839
#
# Epoch 00047: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 1.955502055398184, 'val_acc': 0.38391959727109976, 'loss': 1.940230604294099, 'acc': 0.36543654404569154, 'lr': 1e-06}
# Prediction : [[[0.01739864 0.37077555 0.12313715 0.48868868 0.5490664  0.40221968
#    0.36543533 0.30416498]]]
# True Label :  [0.         0.         0.         1.         0.87037037 0.87037037
#  0.38888889 0.2962963 ]
# Epoch 48/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 1.9300 - acc: 0.3743 - val_loss: 1.9459 - val_acc: 0.3839
#
# Epoch 00048: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 1.945868387294175, 'val_acc': 0.38391959727109976, 'loss': 1.9299778828974619, 'acc': 0.374278602568476, 'lr': 1e-06}
# Prediction : [[[0.0170572  0.3639575  0.12062386 0.49836138 0.55111706 0.41031173
#    0.3600781  0.30695775]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.87037037
#  0.83333333 0.7962963 ]
# Epoch 49/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 1.9190 - acc: 0.3803 - val_loss: 1.9365 - val_acc: 0.3960
#
# Epoch 00049: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 1.936495716847367, 'val_acc': 0.39597989925787075, 'loss': 1.9190299113949176, 'acc': 0.3803145009686041, 'lr': 1e-06}
# Prediction : [[[0.01689135 0.35741642 0.11884718 0.50684506 0.54591286 0.40836656
#    0.3457335  0.3027706 ]]]
# True Label :  [0.         1.         0.         0.         0.12962963 0.12962963
#  0.55555556 0.44444444]
# Epoch 50/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 1.9104 - acc: 0.3879 - val_loss: 1.9264 - val_acc: 0.3960
#
# Epoch 00050: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 1.9264409302467078, 'val_acc': 0.39597989985691245, 'loss': 1.910420450316204, 'acc': 0.38788584606860954, 'lr': 1e-06}
# Prediction : [[[0.01655375 0.3508453  0.11744049 0.51516044 0.5498116  0.4121786
#    0.34575278 0.31360856]]]
# True Label :  [0.         0.         0.         1.         0.87037037 0.87037037
#  0.5        0.35185185]
# Epoch 51/250
# 18887/18887 [==============================] - 24s 1ms/step - loss: 1.9013 - acc: 0.3950 - val_loss: 1.9172 - val_acc: 0.4010
#
# Epoch 00051: saving model to /data/u934/service_imagerie/v_kapoor/FinalONEATTraining/Bin2ONeatModel/ResidualBin2NeatModel.h5
# {'val_loss': 1.9172105914983317, 'val_acc': 0.4010050260840948, 'loss': 1.9012513180145636, 'acc': 0.39503361972157064, 'lr': 1e-06}
# Prediction : [[[0.01627966 0.34291092 0.11518006 0.52562934 0.5485695  0.41857603
#    0.3522783  0.31600675]]]
# True Label :  [0.         0.         1.         0.         0.5        0.87037037
#  0.42592593 0.33333333]
# Epoch 52/250
#  6700/18887 [=========>....................] - ETA: 15s - loss: 1.9042 - acc: 0.3901
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-483d7ffec102> in <module>
#       3 Train.loadData()
#       4
# ----> 5 Train.TrainModel()
#
# ~/Yoloneat/NEAT/NEATModels/neat_static_standard.py in TrainModel(self)
#     182
#     183         #Train the model and save as a h5 file
# --> 184         self.Trainingmodel.fit(self.X,self.Y, class_weight = d_class_weights , batch_size = self.batch_size, epochs = self.epochs, validation_data=(self.X_val, self.Y_val), shuffle = True, callbacks = [lrate,hrate,srate,prate])
#     185         #clear_output(wait=True)
#     186
#
# /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /data/usr_app/VarunAnaconda/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
