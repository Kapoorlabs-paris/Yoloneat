# %%
import sys
import os
from glob import glob
sys.path.append("../NEAT")
from NEATModels import NEATStatic, nets
from NEATModels.Staticconfig  import static_config
from NEATUtils import helpers
from NEATUtils.helpers import save_json, load_json
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
# Out:
# Using TensorFlow backend.

# %%
npz_directory = '/home/sancere/Kepler/Incucyte/dataIncuExtraGrand/'
npz_name = 'Incucyte256.npz'
npz_val_name = 'Incucyte256Val.npz'


model_dir = '/home/sancere/Kepler/Incucyte/model/'
#Model name based on wether it is residual or sequntial ONEAT network
model_name = 'incucyteseqnetd38ExtraGRAND.h5'

# %%
static_categories_json = model_dir + 'StaticCategories.json'
key_categories = load_json(static_categories_json)
static_cord_json = model_dir + 'StaticCord.json'
key_cord = load_json(static_cord_json)

#For ORNET use residual = True and for OSNET use residual = False
residual = False
#NUmber of starting convolutional filters, is doubled down with increasing depth
startfilter = 48
#CNN network start layer, mid layers and lstm layer kernel size
start_kernel = 7
mid_kernel = 7
#Network depth has to be 9n + 2, n= 3 or 4 is optimal for Notum dataset
depth = 38
#Size of the gradient descent length vector, start small and use callbacks to get smaller when reaching the minima
learning_rate = 1.0E-6
#For stochastic gradient decent, the batch size used for computing the gradients
batch_size = 10
# use softmax for single event per box, sigmoid for multi event per box
multievent = False
# Trainng image size
yolo_v0 = True
show = True
#Training epochs, longer the better with proper chosen learning rate
epochs = 250
nboxes = 1
#The inbuilt model stride which is equal to the nulber of times image was downsampled by the network
stride = 4
show = True
imagex = 256
imagey = 256

# %%
config = static_config(npz_directory =npz_directory, npz_name = npz_name, npz_val_name = npz_val_name, 
                         key_categories = key_categories, key_cord = key_cord, 
                         residual = residual, depth = depth, start_kernel = start_kernel, stride = stride, mid_kernel = mid_kernel,
                         startfiler = startfilter, nboxes = nboxes, gridx = 1, gridy = 1, show = show,
                         epochs = epochs, learning_rate = learning_rate, imagex = imagex, imagey = imagey,
                         batch_size = batch_size, model_name = model_name, yolo_v0 = yolo_v0, multievent = multievent)

config_json = config.to_json()

print(config)
save_json(config_json, model_dir + os.path.splitext(model_name)[0] + '_Parameter.json')
# Out:
# static_config(batch_size=10, box_vector=2, categories=2, depth=38, epochs=250, gridx=1, gridy=1, imagex=128, imagey=128, key_categories={'Normal': 0, 'Cells': 1}, key_cord={'x': 0, 'y': 1}, learning_rate=1e-06, mid_kernel=7, model_name='incucyteseqnetd38ExtraGRAND.h5', multievent=False, nboxes=1, npz_directory='/home/sancere/Kepler/Incucyte/dataIncuExtraGrand/', npz_name='Incucyte256.npz', npz_val_name='Incucyte256Val.npz', residual=False, show=True, start_kernel=7, startfilter=32, stride=(4,), yolo_v0=True)

# %%
static_model = NEATStatic(config, model_dir, model_name)

static_model.loadData()

static_model.TrainModel()
# Out:
# number of  images:	 3914
# image size (2D):		 (256, 256)
# axes:				 SXYC
# channels in / out:		 1
# number of  images:	 207
# image size (2D):		 (256, 256)
# axes:				 SXYC
# channels in / out:		 1
# (3914, 1, 1, 4) 1
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 1 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 1600        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 50208       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 3 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 3 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 3 50208       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 3 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 3 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 3 50208       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 3 128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 3 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 3 50208       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 3 128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 3 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 1 200832      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 1 512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 1 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 802944      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 1 512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 1 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 1 802944      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 1 512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 1 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 802944      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 1 512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 1 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 2 1605888     activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 2 1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 2 3211520     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 2 1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 2 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 2 3211520     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 2 1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 2 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 2 3211520     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 2 1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 2 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None, 2 0           activation_13[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None, None, 2 0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 16386       lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 2 2080770     lambda_2[0][0]
# __________________________________________________________________________________________________
# Concat (Concat)                 [(None, None, None,  0           conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
# ==================================================================================================
# Total params: 16,156,484
# Trainable params: 16,153,092
# Non-trainable params: 3,392
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 3914 samples, validate on 207 samples
# Epoch 1/250
# 3914/3914 [==============================] - 177s 45ms/step - loss: 0.8790 - acc: 0.8421 - val_loss: 0.8511 - val_acc: 0.8986
#
# Epoch 00001: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.8511432199086544, 'val_acc': 0.8985507191667235, 'loss': 0.8789787501416526, 'acc': 0.8421052564459001, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.9815336]]
# True Cell type: Cells
# x [[0.49912208]]
# True positional value x 0.4609375
# y [[0.32342872]]
# True positional value y 0.4609375
# Epoch 2/250
# 3914/3914 [==============================] - 172s 44ms/step - loss: 0.7010 - acc: 0.9244 - val_loss: 0.8058 - val_acc: 0.9034
#
# Epoch 00002: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.8058359525053973, 'val_acc': 0.9033816381929002, 'loss': 0.7010277532227623, 'acc': 0.9243740331596663, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.9974274]]
# True Cell type: Cells
# x [[0.13796237]]
# True positional value x 0.4609375
# y [[0.64544773]]
# True positional value y 0.4609375
# Epoch 3/250
# 3914/3914 [==============================] - 173s 44ms/step - loss: 0.6825 - acc: 0.9290 - val_loss: 0.7754 - val_acc: 0.9130
#
# Epoch 00003: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.7753778638471152, 'val_acc': 0.9130434748055278, 'loss': 0.6824514810595514, 'acc': 0.9289729108479051, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.9980434]]
# True Cell type: Cells
# x [[0.39147303]]
# True positional value x 0.4609375
# y [[0.4087257]]
# True positional value y 0.5
# Epoch 4/250
# 3914/3914 [==============================] - 173s 44ms/step - loss: 0.6507 - acc: 0.9318 - val_loss: 0.7020 - val_acc: 0.9372
#
# Epoch 00004: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.7020443410113237, 'val_acc': 0.937198061298057, 'loss': 0.6506738764598897, 'acc': 0.9317833339613679, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.9995746]]
# True Cell type: Cells
# x [[0.69304156]]
# True positional value x 0.5
# y [[0.2944339]]
# True positional value y 0.5
# Epoch 5/250
# 3914/3914 [==============================] - 173s 44ms/step - loss: 0.6255 - acc: 0.9351 - val_loss: 0.7001 - val_acc: 0.9179
#
# Epoch 00005: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.7000744498294332, 'val_acc': 0.9178743923919789, 'loss': 0.625495137763864, 'acc': 0.9351047449228894, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.9504919]]
# True Cell type: Normal
# x [[0.5474036]]
# True positional value x 0.5
# y [[0.68384916]]
# True positional value y 0.5
# Epoch 6/250
# 3914/3914 [==============================] - 173s 44ms/step - loss: 0.5949 - acc: 0.9361 - val_loss: 0.6815 - val_acc: 0.9227
#
# Epoch 00006: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.6814989294982763, 'val_acc': 0.9227053099784298, 'loss': 0.5948905092176273, 'acc': 0.936126717634206, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.99927074]]
# True Cell type: Cells
# x [[0.35068437]]
# True positional value x 0.4609375
# y [[0.6365855]]
# True positional value y 0.5
# Epoch 7/250
# 3914/3914 [==============================] - 173s 44ms/step - loss: 0.5680 - acc: 0.9407 - val_loss: 0.6573 - val_acc: 0.9469
#
# Epoch 00007: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.6573256896313838, 'val_acc': 0.946859896470959, 'loss': 0.5680045828444042, 'acc': 0.9407255928249584, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.76059204]]
# True Cell type: Cells
# x [[0.4243515]]
# True positional value x 0.5
# y [[0.46971667]]
# True positional value y 0.5390625
# Epoch 8/250
# 3914/3914 [==============================] - 173s 44ms/step - loss: 0.5378 - acc: 0.9609 - val_loss: 0.6306 - val_acc: 0.9130
#
# Epoch 00008: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.6306356586119979, 'val_acc': 0.9130434719260764, 'loss': 0.5378402308901171, 'acc': 0.9609095496246872, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.9979074]]
# True Cell type: Cells
# x [[0.41480166]]
# True positional value x 0.4609375
# y [[0.5187414]]
# True positional value y 0.5390625
# Epoch 9/250
# 3914/3914 [==============================] - 173s 44ms/step - loss: 0.5031 - acc: 0.9819 - val_loss: 0.6065 - val_acc: 0.9662
#
# Epoch 00009: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.6065415763048734, 'val_acc': 0.9661835696962144, 'loss': 0.5031485793599073, 'acc': 0.981859986369075, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.9983596]]
# True Cell type: Cells
# x [[0.44980377]]
# True positional value x 0.5390625
# y [[0.5455779]]
# True positional value y 0.5390625
# Epoch 10/250
# 3914/3914 [==============================] - 173s 44ms/step - loss: 0.4759 - acc: 0.9913 - val_loss: 0.5869 - val_acc: 0.9710
#
# Epoch 00010: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.5868610696516176, 'val_acc': 0.9710144858429397, 'loss': 0.47593008841430284, 'acc': 0.9913132324715811, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.99643457]]
# True Cell type: Cells
# x [[0.7287448]]
# True positional value x 0.5
# y [[0.34692344]]
# True positional value y 0.5390625
# Epoch 11/250
# 3914/3914 [==============================] - 173s 44ms/step - loss: 0.4544 - acc: 0.9923 - val_loss: 0.5818 - val_acc: 0.9662
#
# Epoch 00011: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.5818326897955172, 'val_acc': 0.966183566816763, 'loss': 0.4543874501024635, 'acc': 0.9923352052742691, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.99927324]]
# True Cell type: Cells
# x [[0.34570488]]
# True positional value x 0.4609375
# y [[0.35325044]]
# True positional value y 0.5
# Epoch 12/250
# 3914/3914 [==============================] - 174s 44ms/step - loss: 0.4367 - acc: 0.9941 - val_loss: 0.5564 - val_acc: 0.9710
#
# Epoch 00012: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.5564451347226682, 'val_acc': 0.9710144858429397, 'loss': 0.4367074734042601, 'acc': 0.9941236577170445, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.989504]]
# True Cell type: Cells
# x [[0.28929663]]
# True positional value x 0.5
# y [[0.27157018]]
# True positional value y 0.5
# Epoch 13/250
# 3914/3914 [==============================] - 177s 45ms/step - loss: 0.4221 - acc: 0.9939 - val_loss: 0.5453 - val_acc: 0.9710
#
# Epoch 00013: saving model to /home/sancere/Kepler/Incucyte/model/incucyteseqnetd38ExtraGRAND.h5
# {'val_loss': 0.5453219032230009, 'val_acc': 0.9710144858429397, 'loss': 0.42213683245312394, 'acc': 0.9938681642498723, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.99981827]]
# True Cell type: Cells
# x [[0.73241407]]
# True positional value x 0.5
# y [[0.37076625]]
# True positional value y 0.5390625
# Epoch 14/250
# 1200/3914 [========>.....................] - ETA: 1:59 - loss: 0.4115 - acc: 0.9950
