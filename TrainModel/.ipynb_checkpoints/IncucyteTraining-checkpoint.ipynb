# %%
import sys
import os
from glob import glob
sys.path.append("../NEAT")
from NEATModels import NEATStatic, nets
from NEATModels.Staticconfig  import static_config
from NEATUtils import helpers
from NEATUtils.helpers import save_json, load_json
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
# Out:
# Using TensorFlow backend.

# %%
npz_directory = '/home/sancere/Kepler/Incucyte/data/'
npz_name = 'Incucyte64.npz'
npz_val_name = 'Incucyte64Val.npz'


model_dir = '/home/sancere/Kepler/Incucyte/model/'
#Model name based on wether it is residual or sequntial ONEAT network
model_name = 'incucyteseqnet.h5'

# %%
static_categories_json = model_dir + 'StaticCategories.json'
key_categories = load_json(static_categories_json)
static_cord_json = model_dir + 'StaticCord.json'
key_cord = load_json(static_cord_json)

#For ORNET use residual = True and for OSNET use residual = False
residual = False
#NUmber of starting convolutional filters, is doubled down with increasing depth
startfilter = 48
#CNN network start layer, mid layers and lstm layer kernel size
start_kernel = 7
mid_kernel = 7
#Network depth has to be 9n + 2, n= 3 or 4 is optimal for Notum dataset
depth = 38
#Size of the gradient descent length vector, start small and use callbacks to get smaller when reaching the minima
learning_rate = 1.0E-6
#For stochastic gradient decent, the batch size used for computing the gradients
batch_size = 100
# use softmax for single event per box, sigmoid for multi event per box
multievent = False
# Trainng image size
yolo_v0 = True
show = True
#Training epochs, longer the better with proper chosen learning rate
epochs = 250
nboxes = 10
#The inbuilt model stride which is equal to the nulber of times image was downsampled by the network
stride = 4
show = True
imagex = 64
imagey = 64

# %%
config = static_config(npz_directory =npz_directory, npz_name = npz_name, npz_val_name = npz_val_name, 
                         key_categories = key_categories, key_cord = key_cord, stride = stride,
                         residual = residual, depth = depth, start_kernel = start_kernel, mid_kernel = mid_kernel,
                         startfiler = startfilter, nboxes = nboxes, gridx = 1, gridy = 1, show = show,
                         epochs = epochs, learning_rate = learning_rate, imagex = imagex, imagey = imagey,
                         batch_size = batch_size, model_name = model_name, yolo_v0 = yolo_v0, multievent = multievent)

config_json = config.to_json()

print(config)
save_json(config_json, model_dir + os.path.splitext(model_name)[0] + '_Parameter.json')
# Out:
# static_config(batch_size=100, box_vector=4, categories=2, depth=38, epochs=250, gridx=1, gridy=1, imagex=64, imagey=64, key_categories={'Normal': 0, 'Cells': 1}, key_cord={'x': 0, 'y': 1, 'h': 2, 'w': 3}, learning_rate=1e-06, mid_kernel=7, model_name='incucyteresnet.h5', multievent=False, nboxes=10, npz_directory='/home/sancere/Kepler/Incucyte/data/', npz_name='Incucyte64.npz', npz_val_name='Incucyte64Val.npz', residual=True, show=True, start_kernel=7, startfilter=32, stride=(4,), yolo_v0=True)

# %%
static_model = NEATStatic(config, model_dir, model_name)

static_model.loadData()

static_model.TrainModel()
# Out:
# number of  images:	 1121
# image size (2D):		 (64, 64)
# axes:				 SXYC
# channels in / out:		 1
# number of  images:	 59
# image size (2D):		 (64, 64)
# axes:				 SXYC
# channels in / out:		 1
# (1121, 1, 1, 42) 10
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass classes=[0], y=[0 0 0 ... 0 0 0] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 1 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 1600        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 3 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 3 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 3 50208       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 3 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 3 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 4224        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 1 4224        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 1 0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 1 512         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 1 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 3 4128        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 3 128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 3 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 3 50208       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 3 128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 3 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 1 4224        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 1 0           add_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 1 512         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 1 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 3 4128        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 3 128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 3 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 3 50208       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 3 128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 3 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 1 4224        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 1 0           add_2[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 1 512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 1 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 3 4128        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 3 128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 3 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 3 50208       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 3 128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 3 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 1 4224        activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 1 0           add_3[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 1 512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 1 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 1 16512       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 1 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 1 802944      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 1 512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 33024       add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 2 33024       activation_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 2 0           conv2d_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 2 1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 2 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 1 32896       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 1 512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 1 802944      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 1 512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 2 33024       activation_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 2 0           add_5[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 2 1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 2 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 1 32896       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 1 512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 1 802944      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 1 512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 2 33024       activation_21[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 2 0           add_6[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 2 1024        add_7[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 2 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 1 32896       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 1 512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 1 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 1 802944      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 1 512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 1 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 2 33024       activation_24[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 2 0           add_7[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 2 1024        add_8[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 2 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 2 65792       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 2 1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 2 3211520     activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 2 1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 5 131584      add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 5 131584      activation_27[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 5 0           conv2d_31[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 5 2048        add_9[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 5 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 2 131328      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 2 1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 2 3211520     activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 2 1024        conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 5 131584      activation_30[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 5 0           add_9[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 5 2048        add_10[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 5 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 2 131328      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 2 1024        conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 2 3211520     activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 2 1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 5 131584      activation_33[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 5 0           add_10[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 5 2048        add_11[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 5 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 2 131328      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 2 1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 2 3211520     activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 2 1024        conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 5 131584      activation_36[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 5 0           add_11[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 5 2048        add_12[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 5 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None, 2 0           activation_37[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None, None, 5 0           activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 2 1026        lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 4 5222440     lambda_2[0][0]
# __________________________________________________________________________________________________
# Concat (Concat)                 [(None, None, None,  0           conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
# ==================================================================================================
# Total params: 22,944,106
# Trainable params: 22,930,218
# Non-trainable params: 13,888
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1121 samples, validate on 59 samples
# Epoch 1/250
# 1121/1121 [==============================] - 225s 201ms/step - loss: 12.2551 - accuracy: 0.0571 - val_loss: 39.9704 - val_accuracy: 0.0000e+00
#
# Epoch 00001: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 39.97037887573242, 'val_accuracy': 0.0, 'loss': 12.255105563937075, 'accuracy': 0.05709188, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.75327176]]
# True Cell type: Cells
# x [[0.49553585]]
# True positional value x 0.5
# y [[0.70491046]]
# True positional value y 0.34375
# h [[0.78156555]]
# True positional value h 0.390625
# w [[0.44218308]]
# True positional value w 0.390625
# Epoch 2/250
# 1121/1121 [==============================] - 220s 196ms/step - loss: 10.3190 - accuracy: 0.1186 - val_loss: 28.0648 - val_accuracy: 0.0000e+00
#
# Epoch 00002: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 28.064762115478516, 'val_accuracy': 0.0, 'loss': 10.319005064407063, 'accuracy': 0.118644066, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.60838294]]
# True Cell type: Cells
# x [[0.49280643]]
# True positional value x 0.65625
# y [[0.6850584]]
# True positional value y 0.65625
# h [[0.54617715]]
# True positional value h 0.390625
# w [[0.2511549]]
# True positional value w 0.390625
# Epoch 3/250
# 1121/1121 [==============================] - 221s 197ms/step - loss: 10.8783 - accuracy: 0.1035 - val_loss: 17.2760 - val_accuracy: 0.0000e+00
#
# Epoch 00003: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 17.275999069213867, 'val_accuracy': 0.0, 'loss': 10.878318573086524, 'accuracy': 0.103479035, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.6330727]]
# True Cell type: Normal
# x [[0.5393946]]
# True positional value x 0.5
# y [[0.53781164]]
# True positional value y 0.5
# h [[0.48190132]]
# True positional value h 0.390625
# w [[0.2992134]]
# True positional value w 0.0
# Epoch 4/250
# 1121/1121 [==============================] - 220s 196ms/step - loss: 10.4291 - accuracy: 0.1508 - val_loss: 10.7312 - val_accuracy: 0.0000e+00
#
# Epoch 00004: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 10.731195449829102, 'val_accuracy': 0.0, 'loss': 10.429090943961777, 'accuracy': 0.15075825, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.52880603]]
# True Cell type: Cells
# x [[0.5140104]]
# True positional value x 0.5
# y [[0.5602982]]
# True positional value y 0.34375
# h [[0.3937304]]
# True positional value h 0.390625
# w [[0.26375353]]
# True positional value w 0.390625
# Epoch 5/250
# 1121/1121 [==============================] - 221s 198ms/step - loss: 9.4827 - accuracy: 0.1748 - val_loss: 8.9284 - val_accuracy: 0.0169
#
# Epoch 00005: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 8.92835807800293, 'val_accuracy': 0.016949152573943138, 'loss': 9.482669975798009, 'accuracy': 0.17484389, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.5644194]]
# True Cell type: Cells
# x [[0.48091158]]
# True positional value x 0.65625
# y [[0.5358861]]
# True positional value y 0.34375
# h [[0.43326214]]
# True positional value h 0.390625
# w [[0.34138715]]
# True positional value w 0.390625
# Epoch 6/250
# 1121/1121 [==============================] - 224s 200ms/step - loss: 9.0657 - accuracy: 0.1945 - val_loss: 8.3525 - val_accuracy: 0.0678
#
# Epoch 00006: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 8.3524751663208, 'val_accuracy': 0.06779661029577255, 'loss': 9.065697789085858, 'accuracy': 0.19446923, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.7039771]]
# True Cell type: Normal
# x [[0.5153403]]
# True positional value x 0.5
# y [[0.55362976]]
# True positional value y 0.5
# h [[0.4651588]]
# True positional value h 0.390625
# w [[0.34967142]]
# True positional value w 0.0
# Epoch 7/250
# 1121/1121 [==============================] - 222s 198ms/step - loss: 8.8161 - accuracy: 0.2079 - val_loss: 7.8912 - val_accuracy: 0.0339
#
# Epoch 00007: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 7.891208171844482, 'val_accuracy': 0.033898305147886276, 'loss': 8.816123069130237, 'accuracy': 0.20785013, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.5269684]]
# True Cell type: Cells
# x [[0.5697449]]
# True positional value x 0.5
# y [[0.51639]]
# True positional value y 0.34375
# h [[0.4269114]]
# True positional value h 0.390625
# w [[0.40426084]]
# True positional value w 0.390625
# Epoch 8/250
# 1121/1121 [==============================] - 221s 197ms/step - loss: 8.2028 - accuracy: 0.2409 - val_loss: 7.4275 - val_accuracy: 0.1186
#
# Epoch 00008: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 7.4274773597717285, 'val_accuracy': 0.11864406615495682, 'loss': 8.202763767565711, 'accuracy': 0.24085638, 'lr': 1e-06}
# Predicted cell: Normal Probability: [[0.6124824]]
# True Cell type: Cells
# x [[0.5371089]]
# True positional value x 0.65625
# y [[0.55051595]]
# True positional value y 0.65625
# h [[0.48539102]]
# True positional value h 0.390625
# w [[0.33682045]]
# True positional value w 0.390625
# Epoch 9/250
# 1121/1121 [==============================] - 222s 198ms/step - loss: 7.7519 - accuracy: 0.2988 - val_loss: 7.2028 - val_accuracy: 0.1525
#
# Epoch 00009: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 7.202795028686523, 'val_accuracy': 0.1525423675775528, 'loss': 7.751893455273971, 'accuracy': 0.2988403, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.5008488]]
# True Cell type: Cells
# x [[0.5396354]]
# True positional value x 0.34375
# y [[0.46499744]]
# True positional value y 0.65625
# h [[0.46138573]]
# True positional value h 0.390625
# w [[0.26575163]]
# True positional value w 0.390625
# Epoch 10/250
# 1121/1121 [==============================] - 222s 198ms/step - loss: 7.6349 - accuracy: 0.3265 - val_loss: 7.1043 - val_accuracy: 0.2034
#
# Epoch 00010: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 7.104302883148193, 'val_accuracy': 0.20338982343673706, 'loss': 7.634859934542245, 'accuracy': 0.3264942, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.6974197]]
# True Cell type: Normal
# x [[0.50181717]]
# True positional value x 0.5
# y [[0.59197783]]
# True positional value y 0.5
# h [[0.48571503]]
# True positional value h 0.390625
# w [[0.19428763]]
# True positional value w 0.0
# Epoch 11/250
# 1121/1121 [==============================] - 223s 199ms/step - loss: 7.2275 - accuracy: 0.3443 - val_loss: 7.0628 - val_accuracy: 0.1525
#
# Epoch 00011: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 7.062783718109131, 'val_accuracy': 0.1525423675775528, 'loss': 7.2274787189915815, 'accuracy': 0.3443354, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.7413123]]
# True Cell type: Normal
# x [[0.5033035]]
# True positional value x 0.5
# y [[0.5607505]]
# True positional value y 0.5
# h [[0.49927533]]
# True positional value h 0.390625
# w [[0.3223143]]
# True positional value w 0.0
# Epoch 12/250
# 1121/1121 [==============================] - 224s 200ms/step - loss: 7.0201 - accuracy: 0.3657 - val_loss: 7.0660 - val_accuracy: 0.1017
#
# Epoch 00012: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 7.066012859344482, 'val_accuracy': 0.10169491171836853, 'loss': 7.0200569691347505, 'accuracy': 0.36574486, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.7044213]]
# True Cell type: Normal
# x [[0.5546113]]
# True positional value x 0.5
# y [[0.5685807]]
# True positional value y 0.5
# h [[0.49592263]]
# True positional value h 0.390625
# w [[0.22721036]]
# True positional value w 0.0
# Epoch 13/250
# 1121/1121 [==============================] - 222s 198ms/step - loss: 6.9179 - accuracy: 0.3880 - val_loss: 6.9213 - val_accuracy: 0.1695
#
# Epoch 00013: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 6.921329021453857, 'val_accuracy': 0.16949152946472168, 'loss': 6.917893609226441, 'accuracy': 0.38804638, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.78510827]]
# True Cell type: Cells
# x [[0.5044704]]
# True positional value x 0.5
# y [[0.52514774]]
# True positional value y 0.34375
# h [[0.4291947]]
# True positional value h 0.390625
# w [[0.385416]]
# True positional value w 0.390625
# Epoch 14/250
# 1121/1121 [==============================] - 222s 198ms/step - loss: 6.6443 - accuracy: 0.4371 - val_loss: 6.7181 - val_accuracy: 0.2542
#
# Epoch 00014: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 6.71813440322876, 'val_accuracy': 0.2542372941970825, 'loss': 6.644339586133727, 'accuracy': 0.4371097, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.5913964]]
# True Cell type: Cells
# x [[0.52906823]]
# True positional value x 0.65625
# y [[0.5085606]]
# True positional value y 0.34375
# h [[0.47139698]]
# True positional value h 0.390625
# w [[0.37221214]]
# True positional value w 0.390625
# Epoch 15/250
# 1121/1121 [==============================] - 222s 198ms/step - loss: 6.5425 - accuracy: 0.4621 - val_loss: 6.6065 - val_accuracy: 0.2881
#
# Epoch 00015: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 6.60646915435791, 'val_accuracy': 0.2881355881690979, 'loss': 6.542535675943801, 'accuracy': 0.46208742, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.7065721]]
# True Cell type: Cells
# x [[0.6202204]]
# True positional value x 0.65625
# y [[0.54265106]]
# True positional value y 0.5
# h [[0.43263203]]
# True positional value h 0.390625
# w [[0.32246444]]
# True positional value w 0.390625
# Epoch 16/250
# 1121/1121 [==============================] - 222s 198ms/step - loss: 6.4065 - accuracy: 0.5004 - val_loss: 6.5105 - val_accuracy: 0.3390
#
# Epoch 00016: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 6.510519504547119, 'val_accuracy': 0.33898305892944336, 'loss': 6.406451526441072, 'accuracy': 0.500446, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.68832874]]
# True Cell type: Cells
# x [[0.44864708]]
# True positional value x 0.34375
# y [[0.53221583]]
# True positional value y 0.5
# h [[0.44968945]]
# True positional value h 0.390625
# w [[0.3801036]]
# True positional value w 0.390625
# Epoch 17/250
# 1121/1121 [==============================] - 225s 200ms/step - loss: 6.2282 - accuracy: 0.5263 - val_loss: 6.4594 - val_accuracy: 0.4237
#
# Epoch 00017: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 6.459374904632568, 'val_accuracy': 0.4237288236618042, 'loss': 6.228214483405734, 'accuracy': 0.5263158, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.7590658]]
# True Cell type: Normal
# x [[0.46164575]]
# True positional value x 0.5
# y [[0.52254593]]
# True positional value y 0.5
# h [[0.40494654]]
# True positional value h 0.390625
# w [[0.23516995]]
# True positional value w 0.0
# Epoch 18/250
# 1121/1121 [==============================] - 223s 199ms/step - loss: 6.0749 - accuracy: 0.5424 - val_loss: 6.3722 - val_accuracy: 0.4576
#
# Epoch 00018: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 6.372192859649658, 'val_accuracy': 0.4576271176338196, 'loss': 6.074901884948431, 'accuracy': 0.5423729, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.74542373]]
# True Cell type: Cells
# x [[0.50499123]]
# True positional value x 0.5
# y [[0.4263449]]
# True positional value y 0.34375
# h [[0.4597196]]
# True positional value h 0.390625
# w [[0.3115543]]
# True positional value w 0.390625
# Epoch 19/250
# 1121/1121 [==============================] - 218s 195ms/step - loss: 5.9505 - accuracy: 0.5611 - val_loss: 6.3254 - val_accuracy: 0.4576
#
# Epoch 00019: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 6.325447082519531, 'val_accuracy': 0.4576271176338196, 'loss': 5.9504700617318065, 'accuracy': 0.56110615, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.6619762]]
# True Cell type: Cells
# x [[0.4749873]]
# True positional value x 0.65625
# y [[0.6001506]]
# True positional value y 0.65625
# h [[0.45077455]]
# True positional value h 0.390625
# w [[0.37426993]]
# True positional value w 0.390625
# Epoch 20/250
# 1121/1121 [==============================] - 215s 192ms/step - loss: 5.7867 - accuracy: 0.5905 - val_loss: 6.2646 - val_accuracy: 0.4915
#
# Epoch 00020: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 6.264641761779785, 'val_accuracy': 0.49152541160583496, 'loss': 5.786733242361595, 'accuracy': 0.59054416, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.7781798]]
# True Cell type: Cells
# x [[0.49389187]]
# True positional value x 0.5
# y [[0.4212987]]
# True positional value y 0.34375
# h [[0.45213372]]
# True positional value h 0.390625
# w [[0.28671914]]
# True positional value w 0.390625
# Epoch 21/250
# 1121/1121 [==============================] - 218s 194ms/step - loss: 5.6720 - accuracy: 0.6039 - val_loss: 6.2337 - val_accuracy: 0.5424
#
# Epoch 00021: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnet.h5
# {'val_loss': 6.233669281005859, 'val_accuracy': 0.5423728823661804, 'loss': 5.6719892890617105, 'accuracy': 0.60392505, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.7829386]]
# True Cell type: Normal
# x [[0.5292903]]
# True positional value x 0.5
# y [[0.47854212]]
# True positional value y 0.5
# h [[0.43649337]]
# True positional value h 0.390625
# w [[0.10787596]]
# True positional value w 0.0
# Epoch 22/250
#  700/1121 [=================>............] - ETA: 1:21 - loss: 5.4492 - accuracy: 0.6186
