# %%
import sys
import os
from glob import glob
sys.path.append("../NEAT")
from NEATModels import NEATDynamic, nets
from NEATModels.config import dynamic_config
from NEATUtils import helpers
from NEATUtils.helpers import save_json, load_json
os.environ["CUDA_VISIBLE_DEVICES"]="1"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
# Out:
# Using TensorFlow backend.

# %%
npz_directory = '/home/sancere/VKepler/CurieTrainingDatasets/oneatnpz/'
npz_name = 'apoptosismodelbin2.npz'
npz_val_name = 'apoptosismodelbin2val.npz'

#Read and Write the h5 file, directory location and name
model_dir =  '/home/sancere/VKepler/CurieDeepLearningModels/OneatModels/ApoptosisBinning2V1Models/'
model_name = 'apoptosisd29s3f32.h5'

# %%
#Neural network parameters
division_categories_json = model_dir + 'ApoptosisCategories.json'
key_categories = load_json(division_categories_json)
division_cord_json = model_dir + 'ApoptosisCord.json'
key_cord = load_json(division_cord_json)

#For ORNET use residual = True and for OSNET use residual = False
residual = True
#NUmber of starting convolutional filters, is doubled down with increasing depth
startfilter = 32
#CNN network start layer, mid layers and lstm layer kernel size
start_kernel = 7
lstm_kernel = 3
mid_kernel = 3
#Network depth has to be 9n + 2, n= 3 or 4 is optimal for Notum dataset
depth = 29
#Size of the gradient descent length vector, start small and use callbacks to get smaller when reaching the minima
learning_rate = 1.0E-3
#For stochastic gradient decent, the batch size used for computing the gradients
batch_size = 4
# use softmax for single event per box, sigmoid for multi event per box
lstm_hidden_unit = 8
#Training epochs, longer the better with proper chosen learning rate
epochs = 250
nboxes = 1
#The inbuilt model stride which is equal to the nulber of times image was downsampled by the network
show = True
stage_number = 3
last_conv_factor = 4
size_tminus = 3
size_tplus = 3
imagex = 64
imagey = 64
yolo_v0 = False
yolo_v1 = True
yolo_v2 = False
multievent = False

# %%
config = dynamic_config(npz_directory =npz_directory, npz_name = npz_name, npz_val_name = npz_val_name,
                         multievent = multievent,
                         key_categories = key_categories, key_cord = key_cord, nboxes = nboxes, imagex = imagex,
                         imagey = imagey, size_tminus = size_tminus, size_tplus =size_tplus, epochs = epochs, yolo_v0 = yolo_v0, yolo_v1 = yolo_v1, yolo_v2 = yolo_v2,
                         residual = residual, depth = depth, start_kernel = start_kernel, mid_kernel = mid_kernel, stage_number = stage_number, last_conv_factor = last_conv_factor,
                         lstm_kernel = lstm_kernel, lstm_hidden_unit = lstm_hidden_unit, show = show,
                         startfilter = startfilter, batch_size = batch_size, model_name = model_name)

config_json = config.to_json()

print(config)
save_json(config_json, model_dir + os.path.splitext(model_name)[0] + '_Parameter.json')
# Out:
# dynamic_config(batch_size=4, box_vector=6, categories=2, depth=29, epochs=250, imagex=64, imagey=64, key_categories={'Normal': 0, 'Apoptosis': 1}, key_cord={'x': 0, 'y': 1, 't': 2, 'h': 3, 'w': 4, 'c': 5}, last_conv_factor=4, learning_rate=0.0001, lstm_hidden_unit=8, lstm_kernel=3, mid_kernel=3, model_name='apoptosisd29s3f32l8.h5', multievent=False, nboxes=1, npz_directory='/home/sancere/VKepler/CurieTrainingDatasets/oneatnpz/', npz_name='apoptosismodelbin2.npz', npz_val_name='apoptosismodelbin2val.npz', residual=True, show=True, size_tminus=3, size_tplus=3, stage_number=3, start_kernel=7, startfilter=32, stride=4, yolo_v0=False, yolo_v1=True, yolo_v2=False)

# %%
Train = NEATDynamic(config, model_dir, model_name)

Train.loadData()

Train.TrainModel()
# Out:
# number of  images:	 3364
# image size (3D):		 (7, 64, 64)
# axes:				 STXYC
# channels in / out:		 1
# number of  images:	 178
# image size (3D):		 (7, 64, 64)
# axes:				 STXYC
# channels in / out:		 1
# (3364, 1, 1, 8) 1
# /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/sklearn/utils/validation.py:72: FutureWarning: Pass classes=[0], y=[0 0 0 ... 0 0 0] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# 2021-09-05 13:33:13.035074: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-09-05 13:33:13.104946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:73:00.0 name: Quadro RTX 6000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-09-05 13:33:13.105165: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-05 13:33:13.106664: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-09-05 13:33:13.108219: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-09-05 13:33:13.108487: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-09-05 13:33:13.110251: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-09-05 13:33:13.111231: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-09-05 13:33:13.114972: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-09-05 13:33:13.117219: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-09-05 13:33:13.118007: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-09-05 13:33:13.128232: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2021-09-05 13:33:13.132088: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fcc04000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-09-05 13:33:13.132128: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-09-05 13:33:13.243636: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5627a0664210 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-09-05 13:33:13.243684: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 6000, Compute Capability 7.5
# 2021-09-05 13:33:13.247642: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:73:00.0 name: Quadro RTX 6000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-09-05 13:33:13.247764: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-05 13:33:13.247805: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-09-05 13:33:13.247841: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-09-05 13:33:13.247877: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-09-05 13:33:13.247913: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-09-05 13:33:13.247949: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-09-05 13:33:13.247985: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-09-05 13:33:13.254786: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-09-05 13:33:13.254885: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-05 13:33:13.260314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-05 13:33:13.260334: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2021-09-05 13:33:13.260345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2021-09-05 13:33:13.265143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22611 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:73:00.0, compute capability: 7.5)
# notbinary
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 7, None, None 0
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 7, None, None 1600        input_1[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 7, None, None 11008       input_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 7, None, None 128         time_distributed_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 7, None, None 128         conv3d_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 7, None, None 0           time_distributed_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 7, None, None 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 7, None, None 1056        time_distributed_3[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 7, None, None 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 7, None, None 128         time_distributed_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 7, None, None 128         conv3d_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 7, None, None 0           time_distributed_6[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 7, None, None 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 7, None, None 9248        time_distributed_7[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 7, None, None 27680       activation_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 7, None, None 128         time_distributed_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 7, None, None 128         conv3d_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 7, None, None 0           time_distributed_9[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 7, None, None 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 7, None, None 4224        time_distributed_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 7, None, None 4224        time_distributed_10[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 7, None, None 4224        activation_1[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 7, None, None 4224        activation_3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 7, None, None 0           time_distributed_11[0][0]
#                                                                  time_distributed_8[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 7, None, None 0           conv3d_5[0][0]
#                                                                  conv3d_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 7, None, None 512         add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 7, None, None 512         add_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 7, None, None 0           time_distributed_13[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 7, None, None 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 7, None, None 4128        time_distributed_14[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 7, None, None 4128        activation_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 7, None, None 128         time_distributed_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 7, None, None 128         conv3d_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 7, None, None 0           time_distributed_16[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 7, None, None 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 7, None, None 9248        time_distributed_17[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 7, None, None 27680       activation_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 7, None, None 128         time_distributed_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 7, None, None 128         conv3d_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 7, None, None 0           time_distributed_19[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, None, None 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 7, None, None 4224        time_distributed_20[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 7, None, None 4224        activation_6[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 7, None, None 0           add_10[0][0]
#                                                                  time_distributed_18[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 7, None, None 0           add_1[0][0]
#                                                                  conv3d_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 7, None, None 512         add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 7, None, None 512         add_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 7, None, None 0           time_distributed_22[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, None, None 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 7, None, None 4128        time_distributed_23[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 7, None, None 4128        activation_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 7, None, None 128         time_distributed_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 7, None, None 128         conv3d_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 7, None, None 0           time_distributed_25[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, None, None 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 7, None, None 9248        time_distributed_26[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 7, None, None 27680       activation_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 7, None, None 128         time_distributed_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 7, None, None 128         conv3d_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 7, None, None 0           time_distributed_28[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, None, None 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 7, None, None 4224        time_distributed_29[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 7, None, None 4224        activation_9[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 7, None, None 0           add_11[0][0]
#                                                                  time_distributed_27[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 7, None, None 0           add_2[0][0]
#                                                                  conv3d_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 7, None, None 512         add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 7, None, None 512         add_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 7, None, None 0           time_distributed_31[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 7, None, None 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 7, None, None 16512       time_distributed_32[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 7, None, None 16512       activation_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 7, None, None 512         time_distributed_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, None, None 512         conv3d_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 7, None, None 0           time_distributed_34[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, None, None 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 7, None, None 147584      time_distributed_35[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 7, None, None 442496      activation_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (None, 7, None, None 512         time_distributed_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, None, None 512         conv3d_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (None, 7, None, None 0           time_distributed_37[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, None, None 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (None, 7, None, None 33024       add_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (None, 7, None, None 33024       time_distributed_38[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 7, None, None 33024       add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 7, None, None 33024       activation_12[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 7, None, None 0           time_distributed_39[0][0]
#                                                                  time_distributed_36[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, None, None 0           conv3d_15[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (None, 7, None, None 1024        add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 7, None, None 1024        add_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (None, 7, None, None 0           time_distributed_41[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, None, None 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (None, 7, None, None 32896       time_distributed_42[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 7, None, None 32896       activation_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (None, 7, None, None 512         time_distributed_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, None, None 512         conv3d_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (None, 7, None, None 0           time_distributed_44[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, None, None 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (None, 7, None, None 147584      time_distributed_45[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 7, None, None 442496      activation_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (None, 7, None, None 512         time_distributed_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, None, None 512         conv3d_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_48 (TimeDistri (None, 7, None, None 0           time_distributed_47[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, None, None 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (None, 7, None, None 33024       time_distributed_48[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 7, None, None 33024       activation_15[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, None, None 0           add_13[0][0]
#                                                                  time_distributed_46[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 7, None, None 0           add_4[0][0]
#                                                                  conv3d_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_50 (TimeDistri (None, 7, None, None 1024        add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 7, None, None 1024        add_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (None, 7, None, None 0           time_distributed_50[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 7, None, None 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_49 (TimeDistri (None, 7, None, None 32896       time_distributed_51[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 7, None, None 32896       activation_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (None, 7, None, None 512         time_distributed_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, None, None 512         conv3d_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (None, 7, None, None 0           time_distributed_53[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 7, None, None 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (None, 7, None, None 147584      time_distributed_54[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 7, None, None 442496      activation_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (None, 7, None, None 512         time_distributed_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, None, None 512         conv3d_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_57 (TimeDistri (None, 7, None, None 0           time_distributed_56[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 7, None, None 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (None, 7, None, None 33024       time_distributed_57[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 7, None, None 33024       activation_18[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, None, None 0           add_14[0][0]
#                                                                  time_distributed_55[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, None, None 0           add_5[0][0]
#                                                                  conv3d_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_59 (TimeDistri (None, 7, None, None 1024        add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 7, None, None 1024        add_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_60 (TimeDistri (None, 7, None, None 0           time_distributed_59[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 7, None, None 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_58 (TimeDistri (None, 7, None, None 65792       time_distributed_60[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 7, None, None 65792       activation_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_62 (TimeDistri (None, 7, None, None 1024        time_distributed_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 7, None, None 1024        conv3d_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_63 (TimeDistri (None, 7, None, None 0           time_distributed_62[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 7, None, None 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_61 (TimeDistri (None, 7, None, None 590080      time_distributed_63[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 7, None, None 1769728     activation_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_65 (TimeDistri (None, 7, None, None 1024        time_distributed_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 7, None, None 1024        conv3d_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_66 (TimeDistri (None, 7, None, None 0           time_distributed_65[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 7, None, None 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_67 (TimeDistri (None, 7, None, None 131584      add_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_64 (TimeDistri (None, 7, None, None 131584      time_distributed_66[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 7, None, None 131584      add_6[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 7, None, None 131584      activation_21[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 7, None, None 0           time_distributed_67[0][0]
#                                                                  time_distributed_64[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, None, None 0           conv3d_25[0][0]
#                                                                  conv3d_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_69 (TimeDistri (None, 7, None, None 2048        add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 7, None, None 2048        add_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_70 (TimeDistri (None, 7, None, None 0           time_distributed_69[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 7, None, None 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_68 (TimeDistri (None, 7, None, None 131328      time_distributed_70[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 7, None, None 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_72 (TimeDistri (None, 7, None, None 1024        time_distributed_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 7, None, None 1024        conv3d_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_73 (TimeDistri (None, 7, None, None 0           time_distributed_72[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 7, None, None 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_71 (TimeDistri (None, 7, None, None 590080      time_distributed_73[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 7, None, None 1769728     activation_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_75 (TimeDistri (None, 7, None, None 1024        time_distributed_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 7, None, None 1024        conv3d_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_76 (TimeDistri (None, 7, None, None 0           time_distributed_75[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 7, None, None 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_74 (TimeDistri (None, 7, None, None 131584      time_distributed_76[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 7, None, None 131584      activation_24[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 7, None, None 0           add_16[0][0]
#                                                                  time_distributed_74[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 7, None, None 0           add_7[0][0]
#                                                                  conv3d_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_78 (TimeDistri (None, 7, None, None 2048        add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 7, None, None 2048        add_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_79 (TimeDistri (None, 7, None, None 0           time_distributed_78[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 7, None, None 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_77 (TimeDistri (None, 7, None, None 131328      time_distributed_79[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 7, None, None 131328      activation_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_81 (TimeDistri (None, 7, None, None 1024        time_distributed_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 7, None, None 1024        conv3d_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_82 (TimeDistri (None, 7, None, None 0           time_distributed_81[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 7, None, None 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_80 (TimeDistri (None, 7, None, None 590080      time_distributed_82[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 7, None, None 1769728     activation_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_84 (TimeDistri (None, 7, None, None 1024        time_distributed_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 7, None, None 1024        conv3d_30[0][0]
# __________________________________________________________________________________________________
# time_distributed_85 (TimeDistri (None, 7, None, None 0           time_distributed_84[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 7, None, None 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_83 (TimeDistri (None, 7, None, None 131584      time_distributed_85[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 7, None, None 131584      activation_27[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 7, None, None 0           add_17[0][0]
#                                                                  time_distributed_83[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 7, None, None 0           add_8[0][0]
#                                                                  conv3d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 7, None, None 2048        add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 7, None, None 2048        add_9[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 7, None, None 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 7, None, None 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 7, None, None 0           activation_56[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# newlstmdeep (ConvLSTM2D)        (None, None, None, 8 149792      add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 8 584         newlstmdeep[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 8 32          conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 8 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None, 2 0           activation_57[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None, None, 6 0           activation_57[0][0]
# __________________________________________________________________________________________________
# yolo (Conv2D)                   (None, None, None, 2 1026        lambda_1[0][0]
# __________________________________________________________________________________________________
# secyolo (Conv2D)                (None, None, None, 6 9222        lambda_2[0][0]
# __________________________________________________________________________________________________
# Concat (Concat)                 [(None, None, None,  0           yolo[0][0]
#                                                                  secyolo[0][0]
# ==================================================================================================
# Total params: 11,366,224
# Trainable params: 11,345,344
# Non-trainable params: 20,880
# __________________________________________________________________________________________________
# 32
# Train on 3364 samples, validate on 178 samples
# Epoch 1/250
# 2021-09-05 13:33:51.756361: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-09-05 13:33:52.992896: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 3364/3364 [==============================] - 243s 72ms/step - loss: 3.1839 - accuracy: 0.1751 - val_loss: 3.0098 - val_accuracy: 0.3596
#
# Epoch 00001: saving model to /home/sancere/VKepler/CurieDeepLearningModels/OneatModels/ApoptosisBinning2V1Models/apoptosisd29s3f32l8.h5
# Predicted cell: Normal Probability: [[0.50692713]]
# True Cell type: Apoptosis
# x [[0.56981325]]
# True positional value x 0.5
# y [[0.4872797]]
# True positional value y 0.5
# t [[0.6003438]]
# True positional value t 0.5
# h [[0.51270616]]
# True positional value h 0.5
# w [[0.41212997]]
# True positional value w 0.5
# c [[0.8960115]]
# True positional value c 1.0
# Epoch 2/250
# 3364/3364 [==============================] - 221s 66ms/step - loss: 2.9962 - accuracy: 0.3927 - val_loss: 2.9439 - val_accuracy: 0.4719
#
# Epoch 00002: saving model to /home/sancere/VKepler/CurieDeepLearningModels/OneatModels/ApoptosisBinning2V1Models/apoptosisd29s3f32l8.h5
# Predicted cell: Apoptosis Probability: [[0.5097841]]
# True Cell type: Apoptosis
# x [[0.73579705]]
# True positional value x 0.5
# y [[0.4631714]]
# True positional value y 0.5
# t [[0.50491744]]
# True positional value t 0.5
# h [[0.49228272]]
# True positional value h 0.5
# w [[0.4971634]]
# True positional value w 0.5
# c [[0.6044096]]
# True positional value c 1.0
# Epoch 3/250
# 3364/3364 [==============================] - 222s 66ms/step - loss: 2.9486 - accuracy: 0.4590 - val_loss: 2.9073 - val_accuracy: 0.5112
#
# Epoch 00003: saving model to /home/sancere/VKepler/CurieDeepLearningModels/OneatModels/ApoptosisBinning2V1Models/apoptosisd29s3f32l8.h5
# Predicted cell: Normal Probability: [[0.5857848]]
# True Cell type: Normal
# x [[0.72274476]]
# True positional value x 0.5
# y [[0.50646967]]
# True positional value y 0.5
# t [[0.51263386]]
# True positional value t 0.5
# h [[0.4754657]]
# True positional value h 0.5
# w [[0.46960434]]
# True positional value w 0.5
# c [[0.6876366]]
# True positional value c 1.0
# Epoch 4/250
# 3364/3364 [==============================] - 220s 65ms/step - loss: 2.9215 - accuracy: 0.4831 - val_loss: 2.9210 - val_accuracy: 0.5955
#
# Epoch 00004: saving model to /home/sancere/VKepler/CurieDeepLearningModels/OneatModels/ApoptosisBinning2V1Models/apoptosisd29s3f32l8.h5
# Predicted cell: Apoptosis Probability: [[0.6043628]]
# True Cell type: Apoptosis
# x [[0.6939446]]
# True positional value x 0.5
# y [[0.46245903]]
# True positional value y 0.5
# t [[0.54581153]]
# True positional value t 0.5
# h [[0.5253227]]
# True positional value h 0.5
# w [[0.5514385]]
# True positional value w 0.5
# c [[0.85667056]]
# True positional value c 0.0
# Epoch 5/250
# 3364/3364 [==============================] - 222s 66ms/step - loss: 2.9044 - accuracy: 0.4979 - val_loss: 3.0483 - val_accuracy: 0.5618
#
# Epoch 00005: saving model to /home/sancere/VKepler/CurieDeepLearningModels/OneatModels/ApoptosisBinning2V1Models/apoptosisd29s3f32l8.h5
# Predicted cell: Normal Probability: [[0.9997526]]
# True Cell type: Normal
# x [[0.60919464]]
# True positional value x 0.5
# y [[0.5089863]]
# True positional value y 0.5
# t [[0.5194725]]
# True positional value t 0.5
# h [[0.5001986]]
# True positional value h 0.5
# w [[0.4975176]]
# True positional value w 0.5
# c [[0.80684733]]
# True positional value c 1.0
# Epoch 6/250
# 3364/3364 [==============================] - 222s 66ms/step - loss: 2.8892 - accuracy: 0.4691 - val_loss: 2.9726 - val_accuracy: 0.5787
#
# Epoch 00006: saving model to /home/sancere/VKepler/CurieDeepLearningModels/OneatModels/ApoptosisBinning2V1Models/apoptosisd29s3f32l8.h5
# Predicted cell: Apoptosis Probability: [[0.75539035]]
# True Cell type: Apoptosis
# x [[0.66312236]]
# True positional value x 0.5
# y [[0.4870276]]
# True positional value y 0.5
# t [[0.52110565]]
# True positional value t 0.5
# h [[0.48056036]]
# True positional value h 0.5
# w [[0.48568425]]
# True positional value w 0.5
# c [[0.76269126]]
# True positional value c 1.0
# Epoch 7/250
# 3364/3364 [==============================] - 223s 66ms/step - loss: 2.8710 - accuracy: 0.5003 - val_loss: 2.8675 - val_accuracy: 0.5337
#
# Epoch 00007: saving model to /home/sancere/VKepler/CurieDeepLearningModels/OneatModels/ApoptosisBinning2V1Models/apoptosisd29s3f32l8.h5
# Predicted cell: Normal Probability: [[0.9998512]]
# True Cell type: Normal
# x [[0.6226276]]
# True positional value x 0.5
# y [[0.5000556]]
# True positional value y 0.5
# t [[0.5023185]]
# True positional value t 0.5
# h [[0.48615992]]
# True positional value h 0.5
# w [[0.490097]]
# True positional value w 0.5
# c [[0.61913675]]
# True positional value c 1.0
# Epoch 8/250
# 2572/3364 [=====================>........] - ETA: 50s - loss: 2.8521 - accuracy: 0.5101
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_45976/192463004.py in <module>
#       3 Train.loadData()
#       4
# ----> 5 Train.TrainModel()
#
# ~/anaconda3/bin/Yoloneat/NEAT/NEATModels/neat_goldstandard.py in TrainModel(self)
#     279         self.Trainingmodel.fit(self.X, self.Y, class_weight=d_class_weights, batch_size=self.batch_size,
#     280                                epochs=self.epochs, validation_data=(self.X_val, self.Y_val), shuffle=True,
# --> 281                                callbacks=[lrate, hrate, srate, prate])
#     282
#     283         # Removes the old model to be replaced with new model, if old one exists
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3790         value = math_ops.cast(value, tensor.dtype)
#    3791       converted_inputs.append(value)
# -> 3792     outputs = self._graph_fn(*converted_inputs)
#    3793
#    3794     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    1603       TypeError: For invalid positional/keyword argument combinations.
#    1604     """
# -> 1605     return self._call_impl(args, kwargs)
#    1606
#    1607   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1643       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1644           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1645     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1646
#    1647   def _filtered_call(self, args, kwargs):
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
