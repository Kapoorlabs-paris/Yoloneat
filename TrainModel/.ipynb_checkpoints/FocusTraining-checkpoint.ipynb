# %%
import sys
import os
from glob import glob
sys.path.append("../NEAT")
from NEATModels import NEATFocus, nets
from NEATModels.config import dynamic_config
from NEATUtils import helpers
from NEATUtils.helpers import save_json, load_json
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
# Out:
# Using TensorFlow backend.

# %%
npz_directory = '/home/sancere/Kepler/CurieTrainingDatasets/foconeatnpz/'
npz_name = 'Foconeat.npz'
npz_val_name = 'FoconeatVal.npz'

#Read and Write the h5 file, directory location and name
model_dir =  '/home/sancere/Kepler/CurieDeepLearningModels/OneatModels/Focusoneatmodels/'
model_name = 'cadhistoned29s4f32res.h5'

# %%
#Neural network parameters
focus_categories_json = model_dir + 'FocusCategories.json'
key_categories = load_json(focus_categories_json)
focus_cord_json = model_dir + 'FocusCord.json'
key_cord = load_json(focus_cord_json)

#For ORNET use residual = True and for OSNET use residual = False
residual = True
#NUmber of starting convolutional filters, is doubled down with increasing depth
startfilter = 32
#CNN network start layer, mid layers and lstm layer kernel size
start_kernel = 7

mid_kernel = 3
#Network depth has to be 9n + 2, n= 3 or 4 is optimal for Notum dataset
depth = 29
#Size of the gradient descent length vector, start small and use callbacks to get smaller when reaching the minima
learning_rate = 1.0E-3
#For stochastic gradient decent, the batch size used for computing the gradients
batch_size = 10

#Training epochs, longer the better with proper chosen learning rate
epochs = 250
nboxes = 1
#The inbuilt model stride which is equal to the nulber of times image was downsampled by the network
show = True
stage_number = 4
last_conv_factor = 8
size_tminus = 1
size_tplus = 1
imagex = 96
imagey = 96
multievent = True

# %%
config = dynamic_config(npz_directory =npz_directory, npz_name = npz_name, npz_val_name = npz_val_name, 
                         key_categories = key_categories, key_cord = key_cord,  imagex = imagex,
                         imagey = imagey, size_tminus = size_tminus, size_tplus =size_tplus, epochs = epochs, multievent = multievent,
                         residual = residual, depth = depth, start_kernel = start_kernel, mid_kernel = mid_kernel, stage_number = stage_number, last_conv_factor = last_conv_factor,
                         show = show, startfilter = startfilter, batch_size = batch_size, model_name = model_name)

config_json = config.to_json()

print(config)
save_json(config_json, model_dir + os.path.splitext(model_name)[0] + '_Parameter.json')
# Out:
# dynamic_config(batch_size=10, box_vector=6, categories=3, depth=29, epochs=250, imagex=96, imagey=96, key_categories={'Totaloff': 0, 'BestCad': 1, 'BestNuclei': 2}, key_cord={'x': 0, 'y': 1, 'z': 2, 'h': 3, 'w': 4, 'c': 5}, last_conv_factor=8, learning_rate=0.0001, lstm_hidden_unit=16, lstm_kernel=3, mid_kernel=3, model_name='cadhistoned29s4f32res.h5', multievent=False, nboxes=1, npz_directory='/home/sancere/Kepler/CurieTrainingDatasets/foconeatnpz/', npz_name='Foconeat.npz', npz_val_name='FoconeatVal.npz', residual=True, show=True, size_tminus=1, size_tplus=1, stage_number=4, start_kernel=7, startfilter=32, stride=8, yolo_v0=True, yolo_v1=False, yolo_v2=False)

# %%
Train = NEATFocus(config, model_dir, model_name)

Train.loadData()

Train.TrainModel()
# Out:
# number of  images:	 10819
# image size (3D):		 (3, 96, 96)
# axes:				 SZYXC
# channels in / out:		 1
# number of  images:	 570
# image size (3D):		 (3, 96, 96)
# axes:				 SZYXC
# channels in / out:		 1
# (3, 96, 96, 1)
# 2021-08-27 11:26:12.635758: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-08-27 11:26:12.690308: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:17:00.0 name: Quadro RTX 6000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-08-27 11:26:12.690560: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-27 11:26:12.692123: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-08-27 11:26:12.693869: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-08-27 11:26:12.694147: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-08-27 11:26:12.695885: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-08-27 11:26:12.696826: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-08-27 11:26:12.700527: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-27 11:26:12.702951: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-08-27 11:26:12.704317: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-08-27 11:26:12.717288: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2021-08-27 11:26:12.720872: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7efbd8000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-08-27 11:26:12.720912: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-08-27 11:26:12.836379: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x563f5153b6e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-08-27 11:26:12.836431: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 6000, Compute Capability 7.5
# 2021-08-27 11:26:12.840366: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:17:00.0 name: Quadro RTX 6000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-08-27 11:26:12.840524: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-27 11:26:12.840577: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-08-27 11:26:12.840623: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-08-27 11:26:12.840669: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-08-27 11:26:12.840715: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-08-27 11:26:12.840760: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-08-27 11:26:12.840805: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-27 11:26:12.847661: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-08-27 11:26:12.847788: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-27 11:26:12.853872: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-27 11:26:12.853894: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2021-08-27 11:26:12.853907: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2021-08-27 11:26:12.858508: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 21720 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:17:00.0, compute capability: 7.5)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, None, None 0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 3, None, None 11008       input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 3, None, None 128         conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 3, None, None 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 3, None, None 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 3, None, None 128         conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 3, None, None 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 3, None, None 27680       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 3, None, None 128         conv3d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 3, None, None 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 3, None, None 4224        activation_1[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 3, None, None 4224        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 3, None, None 0           conv3d_5[0][0]
#                                                                  conv3d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 3, None, None 512         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 3, None, None 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 3, None, None 4128        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 3, None, None 128         conv3d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 3, None, None 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 3, None, None 27680       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 3, None, None 128         conv3d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 3, None, None 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 3, None, None 4224        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 3, None, None 0           add_1[0][0]
#                                                                  conv3d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 3, None, None 512         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 3, None, None 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 3, None, None 4128        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 3, None, None 128         conv3d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 3, None, None 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 3, None, None 27680       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 3, None, None 128         conv3d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 3, None, None 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 3, None, None 4224        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 3, None, None 0           add_2[0][0]
#                                                                  conv3d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 3, None, None 512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 3, None, None 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 3, None, None 16512       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 3, None, None 512         conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 3, None, None 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 3, None, None 442496      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 3, None, None 512         conv3d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 3, None, None 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 3, None, None 33024       add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 3, None, None 33024       activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 3, None, None 0           conv3d_15[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 3, None, None 1024        add_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 3, None, None 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 3, None, None 32896       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 3, None, None 512         conv3d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 3, None, None 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 3, None, None 442496      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 3, None, None 512         conv3d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 3, None, None 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 3, None, None 33024       activation_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 3, None, None 0           add_4[0][0]
#                                                                  conv3d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 3, None, None 1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 3, None, None 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 3, None, None 32896       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 3, None, None 512         conv3d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 3, None, None 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 3, None, None 442496      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 3, None, None 512         conv3d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 3, None, None 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 3, None, None 33024       activation_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 3, None, None 0           add_5[0][0]
#                                                                  conv3d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 3, None, None 1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 3, None, None 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 3, None, None 65792       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 3, None, None 1024        conv3d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 3, None, None 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 3, None, None 1769728     activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 3, None, None 1024        conv3d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 3, None, None 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 3, None, None 131584      add_6[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 3, None, None 131584      activation_21[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 3, None, None 0           conv3d_25[0][0]
#                                                                  conv3d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 3, None, None 2048        add_7[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 3, None, None 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 3, None, None 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 3, None, None 1024        conv3d_26[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 3, None, None 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 3, None, None 1769728     activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 3, None, None 1024        conv3d_27[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 3, None, None 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 3, None, None 131584      activation_24[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 3, None, None 0           add_7[0][0]
#                                                                  conv3d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 3, None, None 2048        add_8[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 3, None, None 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 3, None, None 131328      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 3, None, None 1024        conv3d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 3, None, None 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 3, None, None 1769728     activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 3, None, None 1024        conv3d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 3, None, None 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 3, None, None 131584      activation_27[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 3, None, None 0           add_8[0][0]
#                                                                  conv3d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 3, None, None 2048        add_9[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 3, None, None 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 3, None, None 262656      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 3, None, None 2048        conv3d_32[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 3, None, None 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 3, None, None 7078400     activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 3, None, None 2048        conv3d_33[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 3, None, None 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv3d_35 (Conv3D)              (None, 3, None, None 525312      add_9[0][0]
# __________________________________________________________________________________________________
# conv3d_34 (Conv3D)              (None, 3, None, None 525312      activation_30[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 3, None, None 0           conv3d_35[0][0]
#                                                                  conv3d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 3, None, None 4096        add_10[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 3, None, None 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv3d_36 (Conv3D)              (None, 3, None, None 524800      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 3, None, None 2048        conv3d_36[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 3, None, None 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv3d_37 (Conv3D)              (None, 3, None, None 7078400     activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 3, None, None 2048        conv3d_37[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 3, None, None 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv3d_38 (Conv3D)              (None, 3, None, None 525312      activation_33[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 3, None, None 0           add_10[0][0]
#                                                                  conv3d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 3, None, None 4096        add_11[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 3, None, None 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv3d_39 (Conv3D)              (None, 3, None, None 524800      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 3, None, None 2048        conv3d_39[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 3, None, None 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv3d_40 (Conv3D)              (None, 3, None, None 7078400     activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 3, None, None 2048        conv3d_40[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 3, None, None 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv3d_41 (Conv3D)              (None, 3, None, None 525312      activation_36[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 3, None, None 0           add_11[0][0]
#                                                                  conv3d_41[0][0]
# __________________________________________________________________________________________________
# conv3d_42 (Conv3D)              (None, 3, None, None 248841      add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 3, None, None 36          conv3d_42[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 3, None, None 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 3, None, None 0           activation_37[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 3, None, None 0           activation_37[0][0]
# __________________________________________________________________________________________________
# conv3d_43 (Conv3D)              (None, 1, None, None 3891        lambda_1[0][0]
# __________________________________________________________________________________________________
# conv3d_44 (Conv3D)              (None, 1, None, None 15558       lambda_2[0][0]
# __________________________________________________________________________________________________
# Concat (Concat)                 [(None, 1, None, Non 0           conv3d_43[0][0]
#                                                                  conv3d_44[0][0]
# ==================================================================================================
# Total params: 32,784,486
# Trainable params: 32,763,796
# Non-trainable params: 20,690
# __________________________________________________________________________________________________
# Train on 10819 samples, validate on 570 samples
# Epoch 1/250
# 2021-08-27 11:26:32.940035: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-27 11:26:34.176378: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 10819/10819 [==============================] - 426s 39ms/step - loss: 2.9813 - accuracy: 0.0602 - val_loss: 4.7339 - val_accuracy: 0.0789
#
# Epoch 00001: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/Focusoneatmodels/cadhistoned29s4f32res.h5
# [[8.1540556e-06 1.2478894e-02 9.8751301e-01 4.7834817e-01 5.5277467e-01
#   5.0102347e-01 9.9936599e-01 9.9988532e-01 4.7416648e-01]]
# True Cell type: BestCad
# x [[[0.47834817]]]
# True positional value x 0.5
# y [[[0.55277467]]]
# True positional value y 0.5
# z [[[0.5010235]]]
# True positional value z 0.5
# h [[[0.999366]]]
# True positional value h 1.0
# w [[[0.9998853]]]
# True positional value w 1.0
# c [[[0.47416648]]]
# True positional value c 1.0
# Epoch 2/250
# 10819/10819 [==============================] - 411s 38ms/step - loss: 2.7242 - accuracy: 0.2345 - val_loss: 10.5040 - val_accuracy: 0.1105
#
# Epoch 00002: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/Focusoneatmodels/cadhistoned29s4f32res.h5
# [[4.6144138e-05 3.4238581e-02 9.6571535e-01 4.7290370e-01 4.9413431e-01
#   5.0323588e-01 9.9976796e-01 9.9996531e-01 4.5908555e-01]]
# True Cell type: Totaloff
# x [[[0.4729037]]]
# True positional value x 0.5
# y [[[0.4941343]]]
# True positional value y 0.5
# z [[[0.5032359]]]
# True positional value z 0.5
# h [[[0.99976796]]]
# True positional value h 1.0
# w [[[0.9999653]]]
# True positional value w 1.0
# c [[[0.45908555]]]
# True positional value c 1.0
# Epoch 3/250
# 10819/10819 [==============================] - 405s 37ms/step - loss: 2.6603 - accuracy: 0.4814 - val_loss: 4.3349 - val_accuracy: 0.1193
#
# Epoch 00003: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/Focusoneatmodels/cadhistoned29s4f32res.h5
# [[1.4053419e-01 8.5877240e-01 6.9333089e-04 5.0278783e-01 4.9612015e-01
#   5.1554871e-01 9.9971491e-01 9.9996507e-01 4.6035165e-01]]
# True Cell type: Totaloff
# x [[[0.5027878]]]
# True positional value x 0.5
# y [[[0.49612015]]]
# True positional value y 0.5
# z [[[0.5155487]]]
# True positional value z 0.5
# h [[[0.9997149]]]
# True positional value h 1.0
# w [[[0.9999651]]]
# True positional value w 1.0
# c [[[0.46035165]]]
# True positional value c 1.0
# Epoch 4/250
# 10819/10819 [==============================] - 406s 38ms/step - loss: 2.6361 - accuracy: 0.5803 - val_loss: 3.2139 - val_accuracy: 0.1930
#
# Epoch 00004: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/Focusoneatmodels/cadhistoned29s4f32res.h5
# [[9.9951184e-01 4.7561163e-04 1.2476422e-05 5.0630236e-01 5.0925463e-01
#   5.0146794e-01 9.9980778e-01 9.9997711e-01 4.7698006e-01]]
# True Cell type: Totaloff
# x [[[0.50630236]]]
# True positional value x 0.5
# y [[[0.50925463]]]
# True positional value y 0.5
# z [[[0.50146794]]]
# True positional value z 0.5
# h [[[0.9998078]]]
# True positional value h 1.0
# w [[[0.9999771]]]
# True positional value w 1.0
# c [[[0.47698006]]]
# True positional value c 1.0
# Epoch 5/250
# 10819/10819 [==============================] - 407s 38ms/step - loss: 2.6244 - accuracy: 0.6667 - val_loss: 2.6417 - val_accuracy: 0.1860
#
# Epoch 00005: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/Focusoneatmodels/cadhistoned29s4f32res.h5
# [[9.99884963e-01 1.15069364e-04 3.68733183e-10 4.94456738e-01
#   5.04868150e-01 5.01389205e-01 9.99715030e-01 9.99956727e-01
#   4.56068814e-01]]
# True Cell type: Totaloff
# x [[[0.49445674]]]
# True positional value x 0.5
# y [[[0.50486815]]]
# True positional value y 0.5
# z [[[0.5013892]]]
# True positional value z 0.5
# h [[[0.99971503]]]
# True positional value h 1.0
# w [[[0.9999567]]]
# True positional value w 1.0
# c [[[0.4560688]]]
# True positional value c 1.0
# Epoch 6/250
# 10819/10819 [==============================] - 408s 38ms/step - loss: 2.6114 - accuracy: 0.6679 - val_loss: 2.7334 - val_accuracy: 0.2140
#
# Epoch 00006: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/Focusoneatmodels/cadhistoned29s4f32res.h5
# [[6.1107893e-03 9.9297982e-01 9.0943574e-04 5.0598109e-01 4.9224523e-01
#   4.9985340e-01 9.9963725e-01 9.9994910e-01 4.5782828e-01]]
# True Cell type: BestCad
# x [[[0.5059811]]]
# True positional value x 0.5
# y [[[0.49224523]]]
# True positional value y 0.5
# z [[[0.4998534]]]
# True positional value z 0.5
# h [[[0.99963725]]]
# True positional value h 1.0
# w [[[0.9999491]]]
# True positional value w 1.0
# c [[[0.45782828]]]
# True positional value c 1.0
# Epoch 7/250
#  3530/10819 [========>.....................] - ETA: 4:30 - loss: 2.6009 - accuracy: 0.7040
