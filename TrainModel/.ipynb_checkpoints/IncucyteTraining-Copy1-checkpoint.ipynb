# %%
import sys
import os
from glob import glob
sys.path.append("../NEAT")
from NEATModels import NEATStatic, nets
from NEATModels.Staticconfig  import static_config
from NEATUtils import helpers
from NEATUtils.helpers import save_json, load_json
os.environ["CUDA_VISIBLE_DEVICES"]="1"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
# Out:
# Using TensorFlow backend.

# %%
npz_directory = '/home/sancere/Kepler/Incucyte/data/'
npz_name = 'Incucyte64.npz'
npz_val_name = 'Incucyte64Val.npz'


model_dir = '/home/sancere/Kepler/Incucyte/model/'
#Model name based on wether it is residual or sequntial ONEAT network
model_name = 'incucyteresnetd74.h5'

# %%
static_categories_json = model_dir + 'StaticCategories.json'
key_categories = load_json(static_categories_json)
static_cord_json = model_dir + 'StaticCord.json'
key_cord = load_json(static_cord_json)

#For ORNET use residual = True and for OSNET use residual = False
residual = True
#NUmber of starting convolutional filters, is doubled down with increasing depth
startfilter = 48
#CNN network start layer, mid layers and lstm layer kernel size
start_kernel = 7
mid_kernel = 3
#Network depth has to be 9n + 2, n= 3 or 4 is optimal for Notum dataset
depth = 74
#Size of the gradient descent length vector, start small and use callbacks to get smaller when reaching the minima
learning_rate = 1.0E-6
#For stochastic gradient decent, the batch size used for computing the gradients
batch_size = 100
# use softmax for single event per box, sigmoid for multi event per box
multievent = False
# Trainng image size
yolo_v0 = True
show = True
#Training epochs, longer the better with proper chosen learning rate
epochs = 250
nboxes = 5
#The inbuilt model stride which is equal to the nulber of times image was downsampled by the network
stride = 4
show = True
imagex = 64
imagey = 64

# %%
config = static_config(npz_directory =npz_directory, npz_name = npz_name, npz_val_name = npz_val_name, 
                         key_categories = key_categories, key_cord = key_cord, 
                         stride = stride,
                         residual = residual, depth = depth, start_kernel = start_kernel, mid_kernel = mid_kernel,
                         startfiler = startfilter, nboxes = nboxes, gridx = 1, gridy = 1, show = show,
                         epochs = epochs, learning_rate = learning_rate, imagex = imagex, imagey = imagey,
                         batch_size = batch_size, model_name = model_name, yolo_v0 = yolo_v0, multievent = multievent)

config_json = config.to_json()

print(config)
save_json(config_json, model_dir + os.path.splitext(model_name)[0] + '_Parameter.json')
# Out:
# static_config(batch_size=100, box_vector=2, categories=2, depth=74, epochs=250, gridx=1, gridy=1, imagex=64, imagey=64, key_categories={'Normal': 0, 'Cells': 1}, key_cord={'x': 0, 'y': 1}, learning_rate=1e-06, mid_kernel=7, model_name='incucyteresnetd74.h5', multievent=False, nboxes=5, npz_directory='/home/sancere/Kepler/Incucyte/data/', npz_name='Incucyte64.npz', npz_val_name='Incucyte64Val.npz', residual=True, show=True, start_kernel=7, startfilter=32, stride=(4,), yolo_v0=True)

# %%
static_model = NEATStatic(config, model_dir, model_name)

static_model.loadData()

static_model.TrainModel()
# Out:
# number of  images:	 262
# image size (2D):		 (64, 64)
# axes:				 SXYC
# channels in / out:		 1
# number of  images:	 14
# image size (2D):		 (64, 64)
# axes:				 SXYC
# channels in / out:		 1
# (262, 1, 1, 12) 5
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 1 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 1600        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 3 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 3 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 3 50208       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 3 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 3 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 4224        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 1 4224        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 1 0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 1 512         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 1 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 3 4128        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 3 128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 3 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 3 50208       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 3 128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 3 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 1 4224        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 1 0           add_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 1 512         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 1 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 3 4128        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 3 128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 3 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 3 50208       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 3 128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 3 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 1 4224        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 1 0           add_2[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 1 512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 1 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 3 4128        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 3 128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 3 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 3 50208       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 3 128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 3 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 1 4224        activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 1 0           add_3[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 1 512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 1 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 3 4128        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 3 128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 3 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 3 50208       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 3 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 3 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 4224        activation_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 1 0           add_4[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 1 512         add_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 1 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 3 4128        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 3 128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 3 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 3 50208       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 3 128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 3 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 1 4224        activation_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 1 0           add_5[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 1 512         add_6[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 1 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 3 4128        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 3 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 3 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 3 50208       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 3 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 3 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 1 4224        activation_21[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 1 0           add_6[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 1 512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 1 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 3 4128        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 3 128         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 3 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 3 50208       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 3 128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 3 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 1 4224        activation_24[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           add_7[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 1 512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 1 16512       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 1 512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 1 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 1 802944      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 1 512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 1 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 2 33024       add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 2 33024       activation_27[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 2 0           conv2d_30[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 2 1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 2 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 1 32896       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 1 512         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 1 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 1 802944      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 1 512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 1 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 2 33024       activation_30[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 2 0           add_9[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 2 1024        add_10[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 2 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 1 32896       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 1 512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 1 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 1 802944      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 1 512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 1 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 2 33024       activation_33[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 2 0           add_10[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 2 1024        add_11[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 2 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 1 32896       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 1 512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 1 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 1 802944      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 1 512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 1 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 2 33024       activation_36[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 2 0           add_11[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 2 1024        add_12[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 2 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 1 32896       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 1 512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 1 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 1 802944      activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 1 512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 1 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 2 33024       activation_39[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 2 0           add_12[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 2 1024        add_13[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 2 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 1 32896       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 1 512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, None, None, 1 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 1 802944      activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 1 512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, None, None, 1 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 2 33024       activation_42[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, None, 2 0           add_13[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 2 1024        add_14[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, None, None, 2 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 1 32896       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 1 512         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, None, None, 1 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 1 802944      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 1 512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 1 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 2 33024       activation_45[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, None, None, 2 0           add_14[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 2 1024        add_15[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, None, None, 2 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 1 32896       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 1 512         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, None, None, 1 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 1 802944      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 1 512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, None, None, 1 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 2 33024       activation_48[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, None, 2 0           add_15[0][0]
#                                                                  conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 2 1024        add_16[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, None, None, 2 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 2 65792       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 2 1024        conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 2 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 2 3211520     activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 2 1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 2 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 5 131584      add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 5 131584      activation_51[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 5 0           conv2d_55[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 5 2048        add_17[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 5 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 2 131328      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 2 1024        conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 2 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 2 3211520     activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 2 1024        conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 2 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 5 131584      activation_54[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 5 0           add_17[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 5 2048        add_18[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 5 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 2 131328      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 2 1024        conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 2 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 2 3211520     activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 2 1024        conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 2 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 5 131584      activation_57[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 5 0           add_18[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 5 2048        add_19[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 5 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 2 131328      activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 2 1024        conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 2 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 2 3211520     activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 2 1024        conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 2 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 5 131584      activation_60[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 5 0           add_19[0][0]
#                                                                  conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, None, None, 5 2048        add_20[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 5 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 2 131328      activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 2 1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 2 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 2 3211520     activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, None, None, 2 1024        conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 2 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 5 131584      activation_63[0][0]
# ...
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 5 0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None, 2 0           activation_73[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None, None, 5 0           activation_73[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, None, None, 2 1026        lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, None, None, 1 1305610     lambda_2[0][0]
# __________________________________________________________________________________________________
# Concat (Concat)                 [(None, None, None,  0           conv2d_77[0][0]
#                                                                  conv2d_78[0][0]
# ==================================================================================================
# Total params: 36,662,348
# Trainable params: 36,634,636
# Non-trainable params: 27,712
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 262 samples, validate on 14 samples
# Epoch 1/250
# 262/262 [==============================] - 24s 92ms/step - loss: 6.2657 - acc: 0.0420 - val_loss: 5.9378 - val_acc: 0.0000e+00
#
# Epoch 00001: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.937771797180176, 'val_acc': 0.0, 'loss': 6.265711737043075, 'acc': 0.041984734018795364, 'lr': 1e-06}
# Predicted cell: Normal Probability: [[0.63207114]]
# True Cell type: Normal
# x [[0.3734529]]
# True positional value x 0.5
# y [[0.43737555]]
# True positional value y 0.5
# Epoch 2/250
# 262/262 [==============================] - 2s 7ms/step - loss: 6.1287 - acc: 0.0420 - val_loss: 5.7087 - val_acc: 0.0000e+00
#
# Epoch 00002: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.70868444442749, 'val_acc': 0.0, 'loss': 6.128667074305411, 'acc': 0.04198473180068358, 'lr': 1e-06}
# Predicted cell: Normal Probability: [[0.65651023]]
# True Cell type: Normal
# x [[0.5762116]]
# True positional value x 0.5
# y [[0.36281893]]
# True positional value y 0.5
# Epoch 3/250
# 262/262 [==============================] - 2s 7ms/step - loss: 5.8448 - acc: 0.0534 - val_loss: 5.4546 - val_acc: 0.0000e+00
#
# Epoch 00003: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.454620838165283, 'val_acc': 0.0, 'loss': 5.844806958700865, 'acc': 0.05343511393507018, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.5374963]]
# True Cell type: Cells
# x [[0.6464336]]
# True positional value x 0.5
# y [[0.45358709]]
# True positional value y 0.5
# Epoch 4/250
# 262/262 [==============================] - 2s 7ms/step - loss: 5.5943 - acc: 0.0725 - val_loss: 5.2199 - val_acc: 0.0714
#
# Epoch 00004: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.219904899597168, 'val_acc': 0.0714285746216774, 'loss': 5.594306530843254, 'acc': 0.07251908442446293, 'lr': 1e-06}
# Predicted cell: Normal Probability: [[0.8016571]]
# True Cell type: Cells
# x [[0.5547154]]
# True positional value x 0.5
# y [[0.5391186]]
# True positional value y 0.5
# Epoch 5/250
# 262/262 [==============================] - 2s 7ms/step - loss: 5.2861 - acc: 0.0725 - val_loss: 5.0830 - val_acc: 0.0714
#
# Epoch 00005: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.083038330078125, 'val_acc': 0.0714285746216774, 'loss': 5.286138512706029, 'acc': 0.07251908357134303, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.61768645]]
# True Cell type: Cells
# x [[0.47437507]]
# True positional value x 0.5
# y [[0.54108465]]
# True positional value y 0.5
# Epoch 6/250
# 262/262 [==============================] - 2s 7ms/step - loss: 5.1159 - acc: 0.1031 - val_loss: 5.0898 - val_acc: 0.0000e+00
#
# Epoch 00006: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.089785099029541, 'val_acc': 0.0, 'loss': 5.1158824221778465, 'acc': 0.10305343409075991, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.5369766]]
# True Cell type: Cells
# x [[0.65226513]]
# True positional value x 0.5
# y [[0.54494584]]
# True positional value y 0.5
# Epoch 7/250
# 262/262 [==============================] - 2s 7ms/step - loss: 5.0981 - acc: 0.1031 - val_loss: 5.2266 - val_acc: 0.0000e+00
#
# Epoch 00007: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.226552486419678, 'val_acc': 0.0, 'loss': 5.098121697666081, 'acc': 0.1030534339770106, 'lr': 1e-06}
# Predicted cell: Cells Probability: [[0.6160099]]
# True Cell type: Cells
# x [[0.47562367]]
# True positional value x 0.5
# y [[0.5921601]]
# True positional value y 0.5
# Epoch 8/250
# 262/262 [==============================] - 2s 8ms/step - loss: 5.2180 - acc: 0.0763 - val_loss: 5.4177 - val_acc: 0.0714
#
# Epoch 00008: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.417696475982666, 'val_acc': 0.0714285746216774, 'loss': 5.2180119543585155, 'acc': 0.07633587604260626, 'lr': 1e-06}
# Predicted cell: Normal Probability: [[0.6896785]]
# True Cell type: Normal
# x [[0.42319316]]
# True positional value x 0.5
# y [[0.4678296]]
# True positional value y 0.5
# Epoch 9/250
# 262/262 [==============================] - 2s 7ms/step - loss: 5.4081 - acc: 0.0649 - val_loss: 5.5892 - val_acc: 0.0000e+00
#
# Epoch 00009: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.589166164398193, 'val_acc': 0.0, 'loss': 5.408082849196806, 'acc': 0.06488549538696085, 'lr': 1e-06}
# Predicted cell: Normal Probability: [[0.6910274]]
# True Cell type: Normal
# x [[0.41405168]]
# True positional value x 0.5
# y [[0.69380826]]
# True positional value y 0.5
# Epoch 10/250
# 262/262 [==============================] - 2s 7ms/step - loss: 5.5823 - acc: 0.0382 - val_loss: 5.6893 - val_acc: 0.0000e+00
#
# Epoch 00010: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.689280986785889, 'val_acc': 0.0, 'loss': 5.582321600149606, 'acc': 0.038167938078177796, 'lr': 1e-06}
# Predicted cell: Normal Probability: [[0.6760813]]
# True Cell type: Cells
# x [[0.5054787]]
# True positional value x 0.5
# y [[0.5707251]]
# True positional value y 0.5
# Epoch 11/250
# 262/262 [==============================] - 2s 7ms/step - loss: 5.6120 - acc: 0.0534 - val_loss: 5.6993 - val_acc: 0.0000e+00
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00011: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.699285984039307, 'val_acc': 0.0, 'loss': 5.611954576186552, 'acc': 0.05343511470287811, 'lr': 1e-06}
# Predicted cell: Normal Probability: [[0.6508589]]
# True Cell type: Normal
# x [[0.42956924]]
# True positional value x 0.5
# y [[0.37081358]]
# True positional value y 0.5
# Epoch 12/250
# 262/262 [==============================] - 2s 7ms/step - loss: 5.6447 - acc: 0.0802 - val_loss: 5.6997 - val_acc: 0.0000e+00
#
# Epoch 00012: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.699733734130859, 'val_acc': 0.0, 'loss': 5.6447368687345785, 'acc': 0.0801526705613573, 'lr': 1e-07}
# Predicted cell: Normal Probability: [[0.57594204]]
# True Cell type: Normal
# x [[0.45949292]]
# True positional value x 0.5
# y [[0.53134227]]
# True positional value y 0.5
# Epoch 13/250
# 262/262 [==============================] - 2s 7ms/step - loss: 5.6054 - acc: 0.0496 - val_loss: 5.6944 - val_acc: 0.0000e+00
#
# Epoch 00013: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# {'val_loss': 5.6943769454956055, 'val_acc': 0.0, 'loss': 5.605448213242393, 'acc': 0.04961831941631914, 'lr': 1e-07}
# Predicted cell: Normal Probability: [[0.6497784]]
# True Cell type: Normal
# x [[0.5567739]]
# True positional value x 0.5
# y [[0.48555544]]
# True positional value y 0.5
# Epoch 14/250
# 262/262 [==============================] - 2s 7ms/step - loss: 5.5854 - acc: 0.0420 - val_loss: 5.6831 - val_acc: 0.0000e+00
#
# Epoch 00014: saving model to /home/sancere/Kepler/Incucyte/model/incucyteresnetd74.h5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-fb63f56cd560> in <module>
#       3 static_model.loadData()
#       4
# ----> 5 static_model.TrainModel()
#
# ~/anaconda3/bin/Yoloneat/NEAT/NEATModels/neat_static_standard.py in TrainModel(self)
#     253
#     254         #Train the model and save as a h5 file
# --> 255         self.Trainingmodel.fit(self.X,self.Y,  batch_size = self.batch_size, epochs = self.epochs, validation_data=(self.X_val, self.Y_val), shuffle = True, callbacks = [lrate,hrate,srate,prate])
#     256         #clear_output(wait=True)
#     257
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     222                         epoch_logs['val_' + l] = o
#     223
# --> 224         callbacks.on_epoch_end(epoch, epoch_logs)
#     225         if callbacks.model.stop_training:
#     226             break
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     150         logs = logs or {}
#     151         for callback in self.callbacks:
# --> 152             callback.on_epoch_end(epoch, logs)
#     153
#     154     def on_train_batch_begin(self, batch, logs=None):
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     728                     self.model.save_weights(filepath, overwrite=True)
#     729                 else:
# --> 730                     self.model.save(filepath, overwrite=True)
#     731
#     732
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1137             raise NotImplementedError
#    1138         from ..models import save_model
# -> 1139         save_model(self, filepath, overwrite, include_optimizer)
#    1140
#    1141     @saving.allow_write_to_gcs
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/engine/saving.py in save_wrapper(obj, filepath, overwrite, *args, **kwargs)
#     413                 os.remove(tmp_filepath)
#     414         else:
# --> 415             save_function(obj, filepath, overwrite, *args, **kwargs)
#     416
#     417     return save_wrapper
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     505                 return
#     506         with H5Dict(filepath, mode='w') as h5dict:
# --> 507             _serialize_model(model, h5dict, include_optimizer)
#     508     elif hasattr(filepath, 'write') and callable(filepath.write):
#     509         # write as binary stream
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/engine/saving.py in _serialize_model(model, h5dict, include_optimizer)
#     112         layer_group = model_weights_group[layer.name]
#     113         symbolic_weights = layer.weights
# --> 114         weight_values = K.batch_get_value(symbolic_weights)
#     115         weight_names = []
#     116         for i, (w, val) in enumerate(zip(symbolic_weights, weight_values)):
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in batch_get_value(ops)
#    2680     """
#    2681     if ops:
# -> 2682         return get_session().run(ops)
#    2683     else:
#    2684         return []
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1163     # Create a fetch handler to take care of the structure of fetches.
#    1164     fetch_handler = _FetchHandler(
# -> 1165         self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1166
#    1167     # Run request and get response.
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in __init__(self, graph, fetches, feeds, feed_handles)
#     472     """
#     473     with graph.as_default():
# --> 474       self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     475     self._fetches = []
#     476     self._targets = []
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in get_controller(self, default)
#    5478       with super(_DefaultGraphStack,
#    5479                  self).get_controller(default) as g, context.graph_mode():
# -> 5480         yield g
#    5481     finally:
#    5482       # If an exception is raised here it may be hiding a related exception in
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in get_controller(self, default)
#    5294                 "Nesting violated for default stack of %s objects" %
#    5295                 type(default))
# -> 5296           self.stack.pop()
#    5297         else:
#    5298           self.stack.remove(default)
#
# KeyboardInterrupt:
