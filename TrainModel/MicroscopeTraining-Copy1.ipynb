# %%
import sys
import os
from glob import glob
sys.path.append("../NEAT")
from NEATModels import NEATDynamic, nets
from NEATModels.config import dynamic_config
from NEATUtils import helpers
from NEATUtils.helpers import save_json, load_json
os.environ["CUDA_VISIBLE_DEVICES"]="1"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
# Out:
# Using TensorFlow backend.

# %%
npz_directory = '/home/sancere/Kepler/CurieTrainingDatasets/oneatnpz/'
npz_name = 'microbin2V1.npz'
npz_val_name = 'microbin2V1val.npz'

#Read and Write the h5 file, directory location and name
model_dir =  '/home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/'
model_name = 'micronetbin2d29f16s4.h5'

#Neural network parameters
division_categories_json = model_dir + 'MicroscopeCategories.json'
key_categories = load_json(division_categories_json)
division_cord_json = model_dir + 'MicroscopeCord.json'
key_cord = load_json(division_cord_json)

# %%
#For ORNET use residual = True and for OSNET use residual = False
residual = True
#NUmber of starting convolutional filters, is doubled down with increasing depth
startfilter = 16
#CNN network start layer, mid layers and lstm layer kernel size
start_kernel = 7
lstm_kernel = 3
mid_kernel = 3
#Network depth has to be 9n + 2, n= 3 or 4 is optimal for Notum dataset
depth = 29
#Size of the gradient descent length vector, start small and use callbacks to get smaller when reaching the minima
learning_rate = 1.0E-4
#For stochastic gradient decent, the batch size used for computing the gradients
batch_size = 8
# use softmax for single event per box, sigmoid for multi event per box
lstm_hidden_unit = 16
#Training epochs, longer the better with proper chosen learning rate
epochs = 250
nboxes = 1
#The inbuilt model stride which is equal to the nulber of times image was downsampled by the network
show = False
stage_number = 4
last_conv_factor = 8
size_tminus = 3
size_tplus = 0
imagex = 64
imagey = 64
yolo_v0 = False
yolo_v1 = True
yolo_v2 = False


# In[4]:


config = dynamic_config(npz_directory =npz_directory, npz_name = npz_name, npz_val_name = npz_val_name, 
                         key_categories = key_categories, key_cord = key_cord, nboxes = nboxes, imagex = imagex,
                         imagey = imagey, size_tminus = size_tminus, size_tplus =size_tplus, epochs = epochs, yolo_v0 = yolo_v0, yolo_v1 = yolo_v1, yolo_v2 = yolo_v2,
                         residual = residual, depth = depth, start_kernel = start_kernel, mid_kernel = mid_kernel, stage_number = stage_number, last_conv_factor = last_conv_factor,
                         lstm_kernel = lstm_kernel, lstm_hidden_unit = lstm_hidden_unit, show = show,
                         startfilter = startfilter, batch_size = batch_size, model_name = model_name)

config_json = config.to_json()

print(config)
save_json(config_json, model_dir + os.path.splitext(model_name)[0] + '_Parameter.json')
# In[ ]:


Train = NEATDynamic(config, model_dir, model_name)

Train.loadData()

Train.TrainModel()
# Out:
# dynamic_config(batch_size=8, box_vector=6, categories=2, depth=29, epochs=250, imagex=64, imagey=64, key_categories={'Normal': 0, 'Division': 1}, key_cord={'x': 0, 'y': 1, 't': 2, 'h': 3, 'w': 4, 'c': 5}, last_conv_factor=8, learning_rate=0.0001, lstm_hidden_unit=16, lstm_kernel=3, mid_kernel=3, model_name='micronetbin2d29f16s4.h5', multievent=False, nboxes=1, npz_directory='/home/sancere/Kepler/CurieTrainingDatasets/oneatnpz/', npz_name='microbin2V1.npz', npz_val_name='microbin2V1val.npz', residual=True, show=False, size_tminus=3, size_tplus=0, stage_number=4, start_kernel=7, startfilter=16, stride=8, yolo_v0=False, yolo_v1=True, yolo_v2=False)
# number of  images:	 17731
# image size (3D):		 (4, 64, 64)
# axes:				 STXYC
# channels in / out:		 1
# number of  images:	 934
# image size (3D):		 (4, 64, 64)
# axes:				 STXYC
# channels in / out:		 1
# (17731, 1, 1, 8) 1
# /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.7/site-packages/sklearn/utils/validation.py:72: FutureWarning: Pass classes=[0], y=[0 0 0 ... 0 0 0] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# 2021-08-13 13:50:22.554496: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-08-13 13:50:22.648417: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:73:00.0 name: Quadro RTX 6000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-08-13 13:50:22.648756: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-13 13:50:22.688629: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-08-13 13:50:22.725149: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-08-13 13:50:22.733759: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-08-13 13:50:22.818659: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-08-13 13:50:22.828635: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-08-13 13:50:22.943297: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-13 13:50:22.957933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-08-13 13:50:22.959701: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-08-13 13:50:22.988592: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2021-08-13 13:50:22.991634: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f6e90000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-08-13 13:50:22.991661: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-08-13 13:50:23.273456: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56035586b100 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-08-13 13:50:23.273512: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 6000, Compute Capability 7.5
# 2021-08-13 13:50:23.280870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:73:00.0 name: Quadro RTX 6000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-08-13 13:50:23.281020: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-13 13:50:23.281065: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-08-13 13:50:23.281103: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-08-13 13:50:23.281140: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-08-13 13:50:23.281177: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-08-13 13:50:23.281213: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-08-13 13:50:23.281251: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-13 13:50:23.294873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-08-13 13:50:23.294993: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-13 13:50:23.304151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-13 13:50:23.304174: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2021-08-13 13:50:23.304189: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2021-08-13 13:50:23.314941: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22611 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:73:00.0, compute capability: 7.5)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 4, None, None 0
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 4, None, None 800         input_1[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 4, None, None 5504        input_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 4, None, None 64          time_distributed_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 4, None, None 64          conv3d_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 4, None, None 0           time_distributed_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 4, None, None 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 4, None, None 272         time_distributed_3[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 4, None, None 272         activation_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 4, None, None 64          time_distributed_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 4, None, None 64          conv3d_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 4, None, None 0           time_distributed_6[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 4, None, None 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 4, None, None 2320        time_distributed_7[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 4, None, None 6928        activation_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 4, None, None 64          time_distributed_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4, None, None 64          conv3d_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 4, None, None 0           time_distributed_9[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 4, None, None 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 4, None, None 1088        time_distributed_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 4, None, None 1088        time_distributed_10[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 4, None, None 1088        activation_1[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 4, None, None 1088        activation_3[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 4, None, None 0           time_distributed_11[0][0]
#                                                                  time_distributed_8[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4, None, None 0           conv3d_5[0][0]
#                                                                  conv3d_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 4, None, None 256         add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 4, None, None 256         add_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 4, None, None 0           time_distributed_13[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 4, None, None 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 4, None, None 1040        time_distributed_14[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 4, None, None 1040        activation_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 4, None, None 64          time_distributed_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 4, None, None 64          conv3d_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 4, None, None 0           time_distributed_16[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 4, None, None 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 4, None, None 2320        time_distributed_17[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 4, None, None 6928        activation_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 4, None, None 64          time_distributed_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, None, None 64          conv3d_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 4, None, None 0           time_distributed_19[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 4, None, None 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 4, None, None 1088        time_distributed_20[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 4, None, None 1088        activation_6[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, None, None 0           add_13[0][0]
#                                                                  time_distributed_18[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 4, None, None 0           add_1[0][0]
#                                                                  conv3d_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 4, None, None 256         add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, None, None 256         add_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 4, None, None 0           time_distributed_22[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, None, None 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 4, None, None 1040        time_distributed_23[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 4, None, None 1040        activation_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 4, None, None 64          time_distributed_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, None, None 64          conv3d_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 4, None, None 0           time_distributed_25[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, None, None 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 4, None, None 2320        time_distributed_26[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 4, None, None 6928        activation_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 4, None, None 64          time_distributed_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, None, None 64          conv3d_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 4, None, None 0           time_distributed_28[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, None, None 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 4, None, None 1088        time_distributed_29[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 4, None, None 1088        activation_9[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, None, None 0           add_14[0][0]
#                                                                  time_distributed_27[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4, None, None 0           add_2[0][0]
#                                                                  conv3d_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 4, None, None 256         add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, None, None 256         add_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 4, None, None 0           time_distributed_31[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, None, None 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 4, None, None 4160        time_distributed_32[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 4, None, None 4160        activation_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 4, None, None 256         time_distributed_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, None, None 256         conv3d_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 4, None, None 0           time_distributed_34[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, None, None 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 4, None, None 36928       time_distributed_35[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 4, None, None 110656      activation_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (None, 4, None, None 256         time_distributed_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, None, None 256         conv3d_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (None, 4, None, None 0           time_distributed_37[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, None, None 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (None, 4, None, None 8320        add_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (None, 4, None, None 8320        time_distributed_38[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 4, None, None 8320        add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 4, None, None 8320        activation_12[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 4, None, None 0           time_distributed_39[0][0]
#                                                                  time_distributed_36[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, None, None 0           conv3d_15[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (None, 4, None, None 512         add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, None, None 512         add_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (None, 4, None, None 0           time_distributed_41[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, None, None 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (None, 4, None, None 8256        time_distributed_42[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 4, None, None 8256        activation_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (None, 4, None, None 256         time_distributed_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, None, None 256         conv3d_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (None, 4, None, None 0           time_distributed_44[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, None, None 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (None, 4, None, None 36928       time_distributed_45[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 4, None, None 110656      activation_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (None, 4, None, None 256         time_distributed_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, None, None 256         conv3d_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_48 (TimeDistri (None, 4, None, None 0           time_distributed_47[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, None, None 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (None, 4, None, None 8320        time_distributed_48[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 4, None, None 8320        activation_15[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 4, None, None 0           add_16[0][0]
#                                                                  time_distributed_46[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, None, None 0           add_4[0][0]
#                                                                  conv3d_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_50 (TimeDistri (None, 4, None, None 512         add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, None, None 512         add_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (None, 4, None, None 0           time_distributed_50[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, None, None 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_49 (TimeDistri (None, 4, None, None 8256        time_distributed_51[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 4, None, None 8256        activation_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (None, 4, None, None 256         time_distributed_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, None, None 256         conv3d_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (None, 4, None, None 0           time_distributed_53[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, None, None 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (None, 4, None, None 36928       time_distributed_54[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 4, None, None 110656      activation_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (None, 4, None, None 256         time_distributed_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, None, None 256         conv3d_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_57 (TimeDistri (None, 4, None, None 0           time_distributed_56[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, None, None 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (None, 4, None, None 8320        time_distributed_57[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 4, None, None 8320        activation_18[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 4, None, None 0           add_17[0][0]
#                                                                  time_distributed_55[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, None, None 0           add_5[0][0]
#                                                                  conv3d_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_59 (TimeDistri (None, 4, None, None 512         add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, None, None 512         add_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_60 (TimeDistri (None, 4, None, None 0           time_distributed_59[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, None, None 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_58 (TimeDistri (None, 4, None, None 16512       time_distributed_60[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 4, None, None 16512       activation_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_62 (TimeDistri (None, 4, None, None 512         time_distributed_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 4, None, None 512         conv3d_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_63 (TimeDistri (None, 4, None, None 0           time_distributed_62[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, None, None 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_61 (TimeDistri (None, 4, None, None 147584      time_distributed_63[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 4, None, None 442496      activation_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_65 (TimeDistri (None, 4, None, None 512         time_distributed_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, None, None 512         conv3d_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_66 (TimeDistri (None, 4, None, None 0           time_distributed_65[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4, None, None 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_67 (TimeDistri (None, 4, None, None 33024       add_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_64 (TimeDistri (None, 4, None, None 33024       time_distributed_66[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 4, None, None 33024       add_6[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 4, None, None 33024       activation_21[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 4, None, None 0           time_distributed_67[0][0]
#                                                                  time_distributed_64[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, None, None 0           conv3d_25[0][0]
#                                                                  conv3d_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_69 (TimeDistri (None, 4, None, None 1024        add_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, None, None 1024        add_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_70 (TimeDistri (None, 4, None, None 0           time_distributed_69[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 4, None, None 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_68 (TimeDistri (None, 4, None, None 32896       time_distributed_70[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 4, None, None 32896       activation_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_72 (TimeDistri (None, 4, None, None 512         time_distributed_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, None, None 512         conv3d_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_73 (TimeDistri (None, 4, None, None 0           time_distributed_72[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, None, None 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_71 (TimeDistri (None, 4, None, None 147584      time_distributed_73[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 4, None, None 442496      activation_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_75 (TimeDistri (None, 4, None, None 512         time_distributed_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 4, None, None 512         conv3d_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_76 (TimeDistri (None, 4, None, None 0           time_distributed_75[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, None, None 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_74 (TimeDistri (None, 4, None, None 33024       time_distributed_76[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 4, None, None 33024       activation_24[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 4, None, None 0           add_19[0][0]
#                                                                  time_distributed_74[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, None, None 0           add_7[0][0]
#                                                                  conv3d_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_78 (TimeDistri (None, 4, None, None 1024        add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 4, None, None 1024        add_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_79 (TimeDistri (None, 4, None, None 0           time_distributed_78[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 4, None, None 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_77 (TimeDistri (None, 4, None, None 32896       time_distributed_79[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 4, None, None 32896       activation_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_81 (TimeDistri (None, 4, None, None 512         time_distributed_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, None, None 512         conv3d_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_82 (TimeDistri (None, 4, None, None 0           time_distributed_81[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 4, None, None 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_80 (TimeDistri (None, 4, None, None 147584      time_distributed_82[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 4, None, None 442496      activation_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_84 (TimeDistri (None, 4, None, None 512         time_distributed_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, None, None 512         conv3d_30[0][0]
# __________________________________________________________________________________________________
# time_distributed_85 (TimeDistri (None, 4, None, None 0           time_distributed_84[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, None, None 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_83 (TimeDistri (None, 4, None, None 33024       time_distributed_85[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 4, None, None 33024       activation_27[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 4, None, None 0           add_20[0][0]
#                                                                  time_distributed_83[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 4, None, None 0           add_8[0][0]
#                                                                  conv3d_31[0][0]
# __________________________________________________________________________________________________
# time_distributed_87 (TimeDistri (None, 4, None, None 1024        add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 4, None, None 1024        add_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_88 (TimeDistri (None, 4, None, None 0           time_distributed_87[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 4, None, None 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_86 (TimeDistri (None, 4, None, None 65792       time_distributed_88[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 4, None, None 65792       activation_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_90 (TimeDistri (None, 4, None, None 1024        time_distributed_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, None, None 1024        conv3d_32[0][0]
# __________________________________________________________________________________________________
# time_distributed_91 (TimeDistri (None, 4, None, None 0           time_distributed_90[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 4, None, None 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_89 (TimeDistri (None, 4, None, None 590080      time_distributed_91[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 4, None, None 1769728     activation_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_93 (TimeDistri (None, 4, None, None 1024        time_distributed_89[0][0]
# __________________________________________________________________________________________________
# ...
# y [[0.49973717]]
# True positional value y 0.5
# t [[0.99774975]]
# True positional value t 1.0
# h [[0.18117604]]
# True positional value h 0.15625
# w [[0.20637494]]
# True positional value w 0.28125
# c [[0.9984334]]
# True positional value c 1.0
# Epoch 226/250
# 17731/17731 [==============================] - 387s 22ms/step - loss: 0.6722 - accuracy: 0.9642 - val_loss: 0.8094 - val_accuracy: 0.8929
#
# Epoch 00226: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[0.99999905]]
# True Cell type: Division
# x [[0.5005408]]
# True positional value x 0.5
# y [[0.5016909]]
# True positional value y 0.5
# t [[0.9986627]]
# True positional value t 1.0
# h [[0.5547234]]
# True positional value h 0.484375
# w [[0.4941243]]
# True positional value w 0.484375
# c [[0.99898607]]
# True positional value c 1.0
# Epoch 227/250
# 17731/17731 [==============================] - 387s 22ms/step - loss: 0.6718 - accuracy: 0.9637 - val_loss: 0.8094 - val_accuracy: 0.8951
#
# Epoch 00227: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Normal Probability: [[0.99999833]]
# True Cell type: Normal
# x [[0.49917442]]
# True positional value x 0.5
# y [[0.49832556]]
# True positional value y 0.5
# t [[0.9989214]]
# True positional value t 1.0
# h [[0.3119582]]
# True positional value h 0.34375
# w [[0.2655315]]
# True positional value w 0.265625
# c [[0.99893135]]
# True positional value c 1.0
# Epoch 228/250
# 17731/17731 [==============================] - 388s 22ms/step - loss: 0.6714 - accuracy: 0.9636 - val_loss: 0.8115 - val_accuracy: 0.8961
#
# Epoch 00228: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[1.]]
# True Cell type: Division
# x [[0.4999105]]
# True positional value x 0.5
# y [[0.50177884]]
# True positional value y 0.5
# t [[0.9987797]]
# True positional value t 1.0
# h [[0.4144429]]
# True positional value h 0.4375
# w [[0.5334728]]
# True positional value w 0.53125
# c [[0.99974614]]
# True positional value c 1.0
# Epoch 229/250
# 17731/17731 [==============================] - 387s 22ms/step - loss: 0.6709 - accuracy: 0.9662 - val_loss: 0.8105 - val_accuracy: 0.8983
#
# Epoch 00229: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[0.99999964]]
# True Cell type: Division
# x [[0.49998796]]
# True positional value x 0.5
# y [[0.498718]]
# True positional value y 0.5
# t [[0.998889]]
# True positional value t 1.0
# h [[0.31529796]]
# True positional value h 0.34375
# w [[0.49042788]]
# True positional value w 0.5
# c [[0.99924266]]
# True positional value c 1.0
# Epoch 230/250
# 17731/17731 [==============================] - 387s 22ms/step - loss: 0.6705 - accuracy: 0.9633 - val_loss: 0.8102 - val_accuracy: 0.8961
#
# Epoch 00230: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[1.]]
# True Cell type: Division
# x [[0.50259435]]
# True positional value x 0.5
# y [[0.49833804]]
# True positional value y 0.5
# t [[0.99855536]]
# True positional value t 1.0
# h [[0.56778616]]
# True positional value h 0.53125
# w [[0.52748907]]
# True positional value w 0.5
# c [[0.99960095]]
# True positional value c 1.0
# Epoch 231/250
# 17731/17731 [==============================] - 387s 22ms/step - loss: 0.6702 - accuracy: 0.9641 - val_loss: 0.8112 - val_accuracy: 0.8940
#
# Epoch 00231: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[0.99999976]]
# True Cell type: Division
# x [[0.5002031]]
# True positional value x 0.5
# y [[0.49932095]]
# True positional value y 0.5
# t [[0.9984529]]
# True positional value t 1.0
# h [[0.43480718]]
# True positional value h 0.46875
# w [[0.48283303]]
# True positional value w 0.46875
# c [[0.99945813]]
# True positional value c 1.0
# Epoch 232/250
# 17731/17731 [==============================] - 387s 22ms/step - loss: 0.6698 - accuracy: 0.9645 - val_loss: 0.8107 - val_accuracy: 0.8940
#
# Epoch 00232: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Normal Probability: [[0.9999982]]
# True Cell type: Normal
# x [[0.49904957]]
# True positional value x 0.5
# y [[0.49822035]]
# True positional value y 0.5
# t [[0.9989146]]
# True positional value t 1.0
# h [[0.3063805]]
# True positional value h 0.34375
# w [[0.26662236]]
# True positional value w 0.265625
# c [[0.99883896]]
# True positional value c 1.0
# Epoch 233/250
# 17731/17731 [==============================] - 387s 22ms/step - loss: 0.6692 - accuracy: 0.9629 - val_loss: 0.8102 - val_accuracy: 0.8940
#
# Epoch 00233: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Normal Probability: [[0.99991333]]
# True Cell type: Normal
# x [[0.49812222]]
# True positional value x 0.5
# y [[0.49896717]]
# True positional value y 0.5
# t [[0.9982407]]
# True positional value t 1.0
# h [[0.22750066]]
# True positional value h 0.140625
# w [[0.18098006]]
# True positional value w 0.140625
# c [[0.980757]]
# True positional value c 1.0
# Epoch 234/250
# 17731/17731 [==============================] - 388s 22ms/step - loss: 0.6688 - accuracy: 0.9671 - val_loss: 0.8091 - val_accuracy: 0.8972
#
# Epoch 00234: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[0.9981699]]
# True Cell type: Division
# x [[0.49958098]]
# True positional value x 0.5
# y [[0.49969643]]
# True positional value y 0.5
# t [[0.99705374]]
# True positional value t 1.0
# h [[0.23790504]]
# True positional value h 0.25
# w [[0.3029797]]
# True positional value w 0.21875
# c [[0.999213]]
# True positional value c 1.0
# Epoch 235/250
# 17731/17731 [==============================] - 388s 22ms/step - loss: 0.6683 - accuracy: 0.9646 - val_loss: 0.8104 - val_accuracy: 0.8940
#
# Epoch 00235: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[0.9988404]]
# True Cell type: Division
# x [[0.50023407]]
# True positional value x 0.5
# y [[0.49983996]]
# True positional value y 0.5
# t [[0.99733293]]
# True positional value t 1.0
# h [[0.21434619]]
# True positional value h 0.140625
# w [[0.23638277]]
# True positional value w 0.1875
# c [[0.99426043]]
# True positional value c 1.0
# Epoch 236/250
# 17731/17731 [==============================] - 389s 22ms/step - loss: 0.6680 - accuracy: 0.9646 - val_loss: 0.8101 - val_accuracy: 0.8940
#
# Epoch 00236: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[1.]]
# True Cell type: Division
# x [[0.5002305]]
# True positional value x 0.5
# y [[0.49856445]]
# True positional value y 0.5
# t [[0.99916565]]
# True positional value t 1.0
# h [[0.5647721]]
# True positional value h 0.546875
# w [[0.42975518]]
# True positional value w 0.484375
# c [[0.9979704]]
# True positional value c 1.0
# Epoch 237/250
# 17731/17731 [==============================] - 387s 22ms/step - loss: 0.6674 - accuracy: 0.9664 - val_loss: 0.8094 - val_accuracy: 0.8919
#
# Epoch 00237: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[0.99999917]]
# True Cell type: Division
# x [[0.49886733]]
# True positional value x 0.5
# y [[0.5008279]]
# True positional value y 0.5
# t [[0.99831176]]
# True positional value t 1.0
# h [[0.41868055]]
# True positional value h 0.390625
# w [[0.5270681]]
# True positional value w 0.578125
# c [[0.9988825]]
# True positional value c 1.0
# Epoch 238/250
# 17731/17731 [==============================] - 387s 22ms/step - loss: 0.6670 - accuracy: 0.9669 - val_loss: 0.8090 - val_accuracy: 0.8951
#
# Epoch 00238: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Normal Probability: [[0.9999089]]
# True Cell type: Normal
# x [[0.5037856]]
# True positional value x 0.5
# y [[0.50082994]]
# True positional value y 0.5
# t [[0.9985727]]
# True positional value t 1.0
# h [[0.22519211]]
# True positional value h 0.171875
# w [[0.31670696]]
# True positional value w 0.390625
# c [[0.9999311]]
# True positional value c 1.0
# Epoch 239/250
# 17731/17731 [==============================] - 387s 22ms/step - loss: 0.6666 - accuracy: 0.9657 - val_loss: 0.8082 - val_accuracy: 0.8940
#
# Epoch 00239: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[1.]]
# True Cell type: Division
# x [[0.49780944]]
# True positional value x 0.5
# y [[0.5018449]]
# True positional value y 0.5
# t [[0.9989247]]
# True positional value t 1.0
# h [[0.48078182]]
# True positional value h 0.515625
# w [[0.41310063]]
# True positional value w 0.390625
# c [[0.9947802]]
# True positional value c 1.0
# Epoch 240/250
# 17731/17731 [==============================] - 388s 22ms/step - loss: 0.6661 - accuracy: 0.9644 - val_loss: 0.8076 - val_accuracy: 0.8929
#
# Epoch 00240: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Normal Probability: [[0.99999976]]
# True Cell type: Normal
# x [[0.50041324]]
# True positional value x 0.5
# y [[0.50058943]]
# True positional value y 0.5
# t [[0.99889827]]
# True positional value t 1.0
# h [[0.22902824]]
# True positional value h 0.203125
# w [[0.2236819]]
# True positional value w 0.28125
# c [[0.9985268]]
# True positional value c 1.0
# Epoch 241/250
# 17731/17731 [==============================] - 386s 22ms/step - loss: 0.6657 - accuracy: 0.9653 - val_loss: 0.8081 - val_accuracy: 0.8940
#
# Epoch 00241: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Normal Probability: [[1.]]
# True Cell type: Normal
# x [[0.4958718]]
# True positional value x 0.5
# y [[0.49931502]]
# True positional value y 0.5
# t [[0.9992933]]
# True positional value t 1.0
# h [[0.30952492]]
# True positional value h 0.3125
# w [[0.29179394]]
# True positional value w 0.296875
# c [[0.9994653]]
# True positional value c 1.0
# Epoch 242/250
# 17731/17731 [==============================] - 388s 22ms/step - loss: 0.6654 - accuracy: 0.9670 - val_loss: 0.8081 - val_accuracy: 0.8951
#
# Epoch 00242: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[1.]]
# True Cell type: Division
# x [[0.500997]]
# True positional value x 0.5
# y [[0.5009924]]
# True positional value y 0.5
# t [[0.9987723]]
# True positional value t 1.0
# h [[0.27638644]]
# True positional value h 0.28125
# w [[0.40144297]]
# True positional value w 0.390625
# c [[0.9993818]]
# True positional value c 1.0
# Epoch 243/250
# 17731/17731 [==============================] - 386s 22ms/step - loss: 0.6649 - accuracy: 0.9684 - val_loss: 0.8078 - val_accuracy: 0.8929
#
# Epoch 00243: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[0.9999999]]
# True Cell type: Division
# x [[0.500727]]
# True positional value x 0.5
# y [[0.49922454]]
# True positional value y 0.5
# t [[0.9963813]]
# True positional value t 1.0
# h [[0.4010456]]
# True positional value h 0.390625
# w [[0.4958335]]
# True positional value w 0.5
# c [[0.9838144]]
# True positional value c 1.0
# Epoch 244/250
# 17731/17731 [==============================] - 387s 22ms/step - loss: 0.6644 - accuracy: 0.9659 - val_loss: 0.8065 - val_accuracy: 0.8951
#
# Epoch 00244: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[0.9999993]]
# True Cell type: Division
# x [[0.50047034]]
# True positional value x 0.5
# y [[0.49985692]]
# True positional value y 0.5
# t [[0.9992618]]
# True positional value t 1.0
# h [[0.5182192]]
# True positional value h 0.5
# w [[0.40041035]]
# True positional value w 0.40625
# c [[0.99965966]]
# True positional value c 1.0
# Epoch 245/250
# 17731/17731 [==============================] - 388s 22ms/step - loss: 0.6641 - accuracy: 0.9668 - val_loss: 0.8079 - val_accuracy: 0.8951
#
# Epoch 00245: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[1.]]
# True Cell type: Division
# x [[0.49979988]]
# True positional value x 0.5
# y [[0.49959472]]
# True positional value y 0.5
# t [[0.9987663]]
# True positional value t 1.0
# h [[0.2292244]]
# True positional value h 0.203125
# w [[0.3026005]]
# True positional value w 0.203125
# c [[0.99984765]]
# True positional value c 1.0
# Epoch 246/250
# 17731/17731 [==============================] - 386s 22ms/step - loss: 0.6637 - accuracy: 0.9654 - val_loss: 0.8070 - val_accuracy: 0.8951
#
# Epoch 00246: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[1.]]
# True Cell type: Division
# x [[0.5002853]]
# True positional value x 0.5
# y [[0.49831235]]
# True positional value y 0.5
# t [[0.9987348]]
# True positional value t 1.0
# h [[0.46413022]]
# True positional value h 0.59375
# w [[0.3743375]]
# True positional value w 0.4375
# c [[0.42908844]]
# True positional value c 1.0
# Epoch 247/250
# 17731/17731 [==============================] - 386s 22ms/step - loss: 0.6633 - accuracy: 0.9646 - val_loss: 0.8056 - val_accuracy: 0.8972
#
# Epoch 00247: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[1.]]
# True Cell type: Division
# x [[0.49906364]]
# True positional value x 0.5
# y [[0.5001099]]
# True positional value y 0.5
# t [[0.99897987]]
# True positional value t 1.0
# h [[0.42537087]]
# True positional value h 0.453125
# w [[0.43504018]]
# True positional value w 0.46875
# c [[0.999574]]
# True positional value c 1.0
# Epoch 248/250
# 17731/17731 [==============================] - 388s 22ms/step - loss: 0.6629 - accuracy: 0.9670 - val_loss: 0.8048 - val_accuracy: 0.8940
#
# Epoch 00248: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[0.99999845]]
# True Cell type: Division
# x [[0.4984113]]
# True positional value x 0.5
# y [[0.5041012]]
# True positional value y 0.5
# t [[0.99573416]]
# True positional value t 1.0
# h [[0.21131013]]
# True positional value h 0.390625
# w [[0.28660822]]
# True positional value w 0.328125
# c [[0.47876936]]
# True positional value c 1.0
# Epoch 249/250
# 17731/17731 [==============================] - 388s 22ms/step - loss: 0.6625 - accuracy: 0.9658 - val_loss: 0.8045 - val_accuracy: 0.8951
#
# Epoch 00249: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Normal Probability: [[0.9999999]]
# True Cell type: Normal
# x [[0.49874094]]
# True positional value x 0.5
# y [[0.50072217]]
# True positional value y 0.5
# t [[0.99910456]]
# True positional value t 1.0
# h [[0.25895694]]
# True positional value h 0.265625
# w [[0.28787643]]
# True positional value w 0.265625
# c [[0.99621224]]
# True positional value c 1.0
# Epoch 250/250
# 17731/17731 [==============================] - 388s 22ms/step - loss: 0.6622 - accuracy: 0.9660 - val_loss: 0.8054 - val_accuracy: 0.8961
#
# Epoch 00250: saving model to /home/sancere/Kepler/CurieDeepLearningModels/OneatModels/MicroscopeV1Models/micronetbin2d29f16s4.h5
# Predicted cell: Division Probability: [[1.]]
# True Cell type: Division
# x [[0.5009177]]
# True positional value x 0.5
# y [[0.5002598]]
# True positional value y 0.5
# t [[0.9986314]]
# True positional value t 1.0
# h [[0.2671591]]
# True positional value h 0.09375
# w [[0.3877488]]
# True positional value w 0.109375
# c [[0.9990275]]
# True positional value c 1.0
